# %%
import textblob
from textblob import TextBlob

# %%
text = "Hello everyone! Welcome to my blog post on Medium. We are studying Natural Language Processing."

# %%
TextBlob(text).words
# Out:
# WordList(['Hello', 'everyone', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing'])

# %%
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize

# %%
tokens = nltk.sent_tokenize(text)
print(tokens)
# Out:
# ['Hello everyone!', 'Welcome to my blog post on Medium.', 'We are studying Natural Language Processing.']

# %%
tokens_words = nltk.word_tokenize(text)
print(tokens_words)
# Out:
# ['Hello', 'everyone', '!', 'Welcome', 'to', 'my', 'blog', 'post', 'on', 'Medium', '.', 'We', 'are', 'studying', 'Natural', 'Language', 'Processing', '.']

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()
word = ("civilization")
ps.stem(word)
# Out:
# 'civil'

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer(language = "english")
word = "civilization"
stemmer.stem(word)
# Out:
# 'civil'

# %%
import nltk
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
# Lemmatize single word
print(lemmatizer.lemmatize("workers"))
print(lemmatizer.lemmatize("beeches"))
# Out:
# worker
# beech

# %%
text = "Let’s lemmatize a simple sentence. We first tokenize the sentence into words using nltk.word_tokenize and then we will call lemmatizer.lemmatize() on each word. "
word_list = nltk.word_tokenize(text)
print(word_list)
# Out:
# ['Let', '’', 's', 'lemmatize', 'a', 'simple', 'sentence', '.', 'We', 'first', 'tokenize', 'the', 'sentence', 'into', 'words', 'using', 'nltk.word_tokenize', 'and', 'then', 'we', 'will', 'call', 'lemmatizer.lemmatize', '(', ')', 'on', 'each', 'word', '.']

# %%
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(lemmatized_output)
# Out:
# Let ’ s lemmatize a simple sentence . We first tokenize the sentence into word using nltk.word_tokenize and then we will call lemmatizer.lemmatize ( ) on each word .

# %%
from textblob import TextBlob, Word

# %%
word = 'stripes'
w = Word(word)
w.lemmatize()
# Out:
# 'stripe'

# %%
text = "The striped bats are hanging on their feet for best"
sent = TextBlob(text)
" ". join([w.lemmatize() for w in sent.words])
# Out:
# 'The striped bat are hanging on their foot for best'

# %%
text = '''Those , have who information who are at still witnesses best of times BLANK the can contact Pastor ( Tel : or 05461 BLANK 885041 the Nachrichten 05461 ( 930010 / ) .
Königs in emphasized the of guests at the Textile Academy the where of opening the celebrated CTL The : &quot; and industry clothing has ahead decisive a renaissance it of .
to According police the BLANK , several residents Monday the in were BLANK BLANK area alleged officers police Sunday on .'''

# %%
text
# Out:
# 'Those , have who information who are at still witnesses best of times BLANK the can contact Pastor ( Tel : or 05461 BLANK 885041 the Nachrichten 05461 ( 930010 / ) .\nKönigs in emphasized the of guests at the Textile Academy the where of opening the celebrated CTL The : &quot; and industry clothing has ahead decisive a renaissance it of .\nto According police the BLANK , several residents Monday the in were BLANK BLANK area alleged officers police Sunday on .'

# %%
TextBlob(text).words
# Out:
# WordList(['Those', 'have', 'who', 'information', 'who', 'are', 'at', 'still', 'witnesses', 'best', 'of', 'times', 'BLANK', 'the', 'can', 'contact', 'Pastor', 'Tel', 'or', '05461', 'BLANK', '885041', 'the', 'Nachrichten', '05461', '930010', 'Königs', 'in', 'emphasized', 'the', 'of', 'guests', 'at', 'the', 'Textile', 'Academy', 'the', 'where', 'of', 'opening', 'the', 'celebrated', 'CTL', 'The', 'quot', 'and', 'industry', 'clothing', 'has', 'ahead', 'decisive', 'a', 'renaissance', 'it', 'of', 'to', 'According', 'police', 'the', 'BLANK', 'several', 'residents', 'Monday', 'the', 'in', 'were', 'BLANK', 'BLANK', 'area', 'alleged', 'officers', 'police', 'Sunday', 'on'])

# %%
tokens = nltk.sent_tokenize(text)
print(tokens)
# Out:
# ['Those , have who information who are at still witnesses best of times BLANK the can contact Pastor ( Tel : or 05461 BLANK 885041 the Nachrichten 05461 ( 930010 / ) .', 'Königs in emphasized the of guests at the Textile Academy the where of opening the celebrated CTL The : &quot; and industry clothing has ahead decisive a renaissance it of .', 'to According police the BLANK , several residents Monday the in were BLANK BLANK area alleged officers police Sunday on .']

# %%
tokens_words = nltk.word_tokenize(text)
print(tokens_words)
# Out:
# ['Those', ',', 'have', 'who', 'information', 'who', 'are', 'at', 'still', 'witnesses', 'best', 'of', 'times', 'BLANK', 'the', 'can', 'contact', 'Pastor', '(', 'Tel', ':', 'or', '05461', 'BLANK', '885041', 'the', 'Nachrichten', '05461', '(', '930010', '/', ')', '.', 'Königs', 'in', 'emphasized', 'the', 'of', 'guests', 'at', 'the', 'Textile', 'Academy', 'the', 'where', 'of', 'opening', 'the', 'celebrated', 'CTL', 'The', ':', '&', 'quot', ';', 'and', 'industry', 'clothing', 'has', 'ahead', 'decisive', 'a', 'renaissance', 'it', 'of', '.', 'to', 'According', 'police', 'the', 'BLANK', ',', 'several', 'residents', 'Monday', 'the', 'in', 'were', 'BLANK', 'BLANK', 'area', 'alleged', 'officers', 'police', 'Sunday', 'on', '.']

# %%
lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])
print(lemmatized_output)
# Out:
# Let ’ s lemmatize a simple sentence . We first tokenize the sentence into word using nltk.word_tokenize and then we will call lemmatizer.lemmatize ( ) on each word .

# %%
from razdel import tokenize

# %%
tokens = list(tokenize('Кружка-термос на 0.5л (50/64 см³, 516;...)'))

# %%
tokens
# Out:
# [Substring(0, 13, 'Кружка-термос'),
#  Substring(14, 16, 'на'),
#  Substring(17, 20, '0.5'),
#  Substring(20, 21, 'л'),
#  Substring(22, 23, '('),
#  Substring(23, 28, '50/64'),
#  Substring(29, 32, 'см³'),
#  Substring(32, 33, ','),
#  Substring(34, 37, '516'),
#  Substring(37, 38, ';'),
#  Substring(38, 41, '...'),
#  Substring(41, 42, ')')]

# %%
[_.text for _ in tokens]
# Out:
# ['Кружка-термос',
#  'на',
#  '0.5',
#  'л',
#  '(',
#  '50/64',
#  'см³',
#  ',',
#  '516',
#  ';',
#  '...',
#  ')']

# %%
 text = '''
... - "Так в чем же дело?" - "Не ра-ду-ют".
... И т. д. и т. п. В общем, вся газета
... '''

# %%
from razdel import sentenize

# %%
list(sentenize(text))
# Out:
# [Substring(1, 23, '- "Так в чем же дело?"'),
#  Substring(24, 40, '- "Не ра-ду-ют".'),
#  Substring(41, 56, 'И т. д. и т. п.'),
#  Substring(57, 76, 'В общем, вся газета')]

# %%
import pandas as pd

# %%
df = pd.read_json('bank_faq.json')

# %%
df
# Out:
#                                                          Депозит  \
# Рахмет         [{'вопрос': 'Какова минимальная сумма открытия...
# Чемпион        [{'вопрос': 'Какая минимальная сумма открытия ...
# МояЦель        [{'вопрос': 'Какова минимальная сумма открытия...
# другое         [{'вопрос': 'Если на мои счета наложен арест, ...
# картакарта                                                   NaN
# IronCard                                                     NaN
# TravelCard                                                   NaN
# ҮлкенгеҚұрмет                                                NaN
# JuniorBank                                                   NaN
# bccpay                                                       NaN
#
#                                                            Карта
# Рахмет                                                       NaN
# Чемпион                                                      NaN
# МояЦель                                                      NaN
# другое         [{'вопрос': 'Я получил/а пуш/смс о том, что мо...
# картакарта     [{'вопрос': 'Какой тип/вид пластика у #картака...
# IronCard       [{'вопрос': 'Какой тип/вид пластика у #IronCar...
# TravelCard     [{'вопрос': 'Какой тип/вид пластика у #Travel ...
# ҮлкенгеҚұрмет  [{'вопрос': 'Какой тип/вид пластика у #Үлкенге...
# JuniorBank     [{'вопрос': 'Какой тип/вид пластика у #JuniorB...
# bccpay         [{'вопрос': 'Какой тип/вид пластика у #BCCPAY ...

# %%
indexes = df.index.to_list()

# %%
questions = []
answers = []
for ind in indexes[:4]:
    for x in df.loc[ind]['Депозит']:
#         print(x['вопрос'])
        questions.append(x['вопрос'])
        answers.append(x['ответ'])
for ind in indexes[4:]:
    for x in df.loc[ind]['Карта']:
#         print(x['вопрос'])
        questions.append(x['вопрос'])
        answers.append(x['ответ'])

# %%
[_.text for _ ]
# Out:
# ['Какова минимальная сумма открытия для депозита "Рахмет" без права пополнения и снятия?',
#  'Разрешены ли дополнительные взносы для депозита "Рахмет"?',
#  'Можно ли осуществить досрочное расторжение депозита "Рахмет"?',
#  'Какие сроки и ставки возвращения применяются при досрочном расторжении депозита "Рахмет"?',
#  'Есть ли различия в ставках в зависимости от того, через что открывается депозит "Рахмет": через приложение или через отделение банка?',
#  'Как производится расчет вознаграждения по депозиту "Рахмет"?',
#  'Продлевается ли вклад "Рахмет" автоматически после окончания срока?',
#  'Допускается ли частичное изъятие средств с депозита "Рахмет"?',
#  'Как часто происходит капитализация по депозиту "Рахмет"?',
#  'Какова минимальная сумма для досрочного расторжения депозита "Рахмет"?',
#  'Какая минимальная сумма открытия для депозита "Чемпион" с правом пополнения и снятия?',
#  'Разрешены ли дополнительные взносы на депозит "Чемпион"?',
#  'Предусмотрено ли частичное изъятие средств с депозита "Чемпион"?',
#  'Можно ли провести досрочное расторжение депозита "Чемпион" и как это происходит?',
#  'Как рассчитывается вознаграждение при досрочном расторжении депозита "Чемпион"?',
#  'Какие условия продления (пролонгации) депозита "Чемпион"?',
#  'Как часто происходит капитализация по депозиту "Чемпион"?',
#  'Каковы ставки при открытии депозита "Чемпион" через приложение BCC.KZ на 13 и 24 месяца?',
#  'Есть ли разница в ставках при открытии депозита "Чемпион" через приложение по сравнению с открытием через отделение банка?',
#  'Как рассчитывается вознаграждение по депозиту "Чемпион"?',
#  'Какова минимальная сумма открытия для депозита "Моя Цель" с правом пополнения и без права снятия?',
#  'Могут ли вноситься дополнительные средства на депозит "Моя Цель" после его открытия?',
#  'Возможно ли частичное снятие с депозита "Моя Цель"?',
#  'Каковы условия досрочного расторжения депозита "Моя Цель"?',
#  'Предусматривается ли автоматическое продление депозита "Моя Цель"?',
#  'Как происходит капитализация по депозиту "Моя Цель"?',
#  'Какие ставки предлагаются при открытии депозита "Моя Цель" через приложение BCC.KZ на сроки 3, 6 и 12 месяцев?',
#  'Как рассчитывается вознаграждение по депозиту "Моя Цель"?',
#  'Если на мои счета наложен арест, вознаграждения по депозиту будут начисляться?',
#  'У моего родственника был депозит, он умер, что делать?',
#  'Я хочу доверить управление мои депозитом родственнику. Что нужно для этого сделать?',
#  'У меня есть депозит Рахмет/Рахмет+ в вашем Банке, и его срок окончания выпадает на выходной/праздничный день, мне нужно его закрыть, что необходимо предпринять?',
#  'Что случится, если я не подойду в назначенный срок по закрытию депозита Рахмет/Рахмет+?',
#  'Как можно закрыть депозит',
#  'Какие документы чтобы закрыть депозит',
#  'Как можно пополнить депозит через КАССА 24, Cash-in банкоматы и ИПТ БЦК?',
#  'Каковы условия пополнения депозита через мобильное приложение BCC.KZ?',
#  'Возможно ли пополнение депозита наличными через кассу в отделении БЦК?',
#  'Существует ли комиссия за пополнение депозита в БЦК?',
#  'Может ли третье лицо пополнить мой депозит?',
#  'Какой тип/вид пластика у #картакарта?',
#  'Какой вид карты у #картакарта?',
#  'В какой валюте ведется счет для #картакарта?',
#  'Какова стоимость выпуска карты #картакарта?',
#  'Возможен ли выпуск дополнительной карты для #картакарта?',
#  'Какова стоимость перевыпуска карты #картакарта при утере/краже/повреждении пластика?',
#  'Какова стоимость годового обслуживания карты #картакарта?',
#  'Каков срок действия пластика карты #картакарта?',
#  'Каков срок действия договора кредитного лимита для #картакарта?',
#  'Где можно использовать карту #картакарта?',
#  'Что такое #картакарта?',
#  'Я получу приветственный бонус?',
#  'Как заработать с #картакарта?',
#  'Что такое кешбэк?',
#  'Как выбирать любимые категории с повышенным кешбэком?',
#  'Могу ли я расплачиваться картой за границей?',
#  'Как пополнять карту?',
#  'Что если я получу карту с нулевым кредитным лимитом, что мне с ней делать и дадут ли мне лимит в будущем?',
#  'Зачем мне нужен кредитный лимит по #картакарта?',
#  'Как я узнаю, что мне установили кредитный лимит?',
#  'Как будут тратиться деньги, если у меня есть и личные деньги и кредитный лимит на карте?',
#  'Как включить и отключить режим рассрочки онлайн в мобильном приложении BCC.KZ?',
#  'Какие сроки рассрочки предусмотрены по карте?',
#  'Есть ли комиссия за рассрочку?',
#  'Я могу покупать в рассрочку за счет личных денег?',
#  'Я могу погашать задолженность по карте досрочно?',
#  'Я не резидент, я могу получить кредитный лимит по карте?',
#  'Как получить виртуальную карту?',
#  'На каком основании Банк увеличивает кредитный лимит без согласия клиента?',
#  'Я НЕ согласен с маленькой суммой лимита.',
#  'Я НЕ согласен с большой суммой лимита!',
#  'Что делать, если клиент обращается с просьбой аннулировать (обнулить) кредитный лимит?',
#  'Можно ли открыть карту в другой валюте, кроме тенге?',
#  'Есть ли целевое назначение кредитного лимита?',
#  'Обязательны ли пенсионные отчисления для рассмотрения?',
#  'Есть ли срок действия у кэшбека?',
#  'Можно ли рассмотреть и выпустить карту онлайн, без посещения отделении?',
#  'По карте имеется страховка?',
#  'Можно ли привлечь созаемщика для рассмотрение кредитного лимита?',
#  'Что такое льготный период по карте?',
#  'Что делать если КЛ не поступил?',
#  'За какие платежи мобильного приложения начисляется кэшбэк в BCC.KZ?',
#  'Возможно ли объединить кэшбэк по стандартным картам и по кредитной карте для быстрого накопления?',
#  'Как начисляется кэшбэк при рассрочке?',
#  'Возможно ли получить кредитный лимит при уже открытой карте без кредитного лимита путем открытия новой карты?',
#  'Какой тип/вид пластика у #IronCard?',
#  'Какой вид карты у #IronCard?',
#  'В каких валютах ведется счет для #IronCard?',
#  'Какова стоимость выпуска карты #IronCard для резидентов и нерезидентов РК?',
#  'Возможен ли выпуск дополнительной карты для #IronCard?',
#  'Какова стоимость перевыпуска карты #IronCard?',
#  'Какова стоимость годового обслуживания карты #IronCard?',
#  'Каков срок действия пластика карты #IronCard?',
#  'Доступны ли кредиты для #IronCard?',
#  'Где можно использовать карту #IronCard?',
#  'Какой тип/вид пластика у #Travel Card?',
#  'Какой вид карты у #Travel Card?',
#  'В каких валютах ведется счет для #Travel Card?',
#  'Какова стоимость выпуска карты #Travel Card для резидентов и нерезидентов РК?',
#  'Возможен ли выпуск дополнительной карты для #Travel Card?',
#  'Какова стоимость перевыпуска карты #Travel Card?',
#  'Какова стоимость годового обслуживания карты #Travel Card?',
#  'Каков срок действия пластика карты #Travel Card?',
#  'Доступны ли кредиты для #Travel Card?',
#  'Где можно использовать карту #Travel Card?',
#  'Какой тип/вид пластика у #ҮлкенгеҚұрмет?',
#  'Какой вид карты у #ҮлкенгеҚұрмет?',
#  'В какой валюте ведется счет для #ҮлкенгеҚұрмет?',
#  'Какова стоимость выпуска карты #ҮлкенгеҚұрмет?',
#  'Возможен ли выпуск дополнительной карты для #ҮлкенгеҚұрмет?',
#  'Какова стоимость перевыпуска карты #ҮлкенгеҚұрмет при утере/краже/повреждении пластика?',
#  'Какова стоимость годового обслуживания карты #ҮлкенгеҚұрмет?',
#  'Каков срок действия пластика карты #ҮлкенгеҚұрмет?',
#  'Доступны ли кредиты для #ҮлкенгеҚұрмет?',
#  'Где можно использовать карту #ҮлкенгеҚұрмет?',
#  'Какие банкоматы принимают Пенсионную карту #ҮлкенгеҚұрмет?',
#  'Могу ли я снимать деньги с Пенсионной карты #ҮлкенгеҚұрмет в банкомате другого Банка?',
#  'Взимается ли комиссия при снятии денег с Пенсионной карты в банкоматах за пределами Казахстана?',
#  'Могу ли я снять деньги в другой валюте с Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Для каких целей предназначена Пенсионная карта #ҮлкенгеҚұрмет?',
#  'Какие преимущества у Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Сколько времени занимает выпуск Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Где я могу ознакомиться с тарифами по Пенсионной карте #ҮлкенгеҚұрмет?',
#  'Что делать, если пенсионная выплата не поступила, несмотря на направленные реквизиты в ЦОН?',
#  'Когда обычно выплачивается пенсия?',
#  'Откроют ли мне Пенсионную карту #ҮлкенгеҚұрмет при наличии арестованных счетов и статуса бездействующего налогоплательщика?',
#  'Какой документ необходим для открытия Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Как узнать о поступлении пенсии на счет?',
#  'Как получить номер счета/IBAN для получения пенсионных выплат?',
#  'Какими способами можно пополнить Пенсионную карту #ҮлкенгеҚұрмет?',
#  'За покупку каких услуг я получаю кэшбек?',
#  'Как мне воспользоваться кэшбеком?',
#  'Сколько стоит перевыпуск Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Какой тип/вид пластика у #JuniorBank?',
#  'Какой вид карты у #JuniorBank?',
#  'В какой валюте ведется счет для #JuniorBank?',
#  'Какова стоимость выпуска карты #JuniorBank?',
#  'Возможен ли выпуск дополнительной карты для #JuniorBank?',
#  'Какова стоимость перевыпуска карты #JuniorBank?',
#  'Какова стоимость годового обслуживания карты #JuniorBank?',
#  'Каков срок действия пластика карты #JuniorBank?',
#  'Доступны ли кредиты для #JuniorBank?',
#  'Где можно использовать карту #JuniorBank?',
#  'Что такое Карта #Junior?',
#  "Что означает термин 'кэшбек'?",
#  'Может ли ребенок самостоятельно осуществить перевод денег?',
#  'Кто имеет право выпустить Карту #Junior?',
#  'Ограничиваются ли возможности выпуска Карты #Junior только родителями?',
#  'Существуют ли возрастные ограничения для открытия карты #Junior?',
#  'Какова стоимость карты #Junior?',
#  'Какие шаги следуют после выпуска виртуальной карты родителем/клиентом?',
#  'Как ребенку осуществлять платежи с помощью смартфона?',
#  'Может ли ребенок использовать и виртуальную, и пластиковую карту одновременно?',
#  'Нужно ли закрывать виртуальную карту при выпуске пластиковой?',
#  'Требуется ли открытие виртуальной карты, если у ребенка уже есть пластиковая карта #Junior?',
#  'Что представляет собой мобильное приложение Junior Bank для детей?',
#  'Видит ли ребенок в приложении Junior Bank средства на карте родителя/клиента?',
#  'Возможно ли для родителя/клиента просматривать карту ребенка в своем приложении BCC.KZ?',
#  'Каковы условия по кешбэку для карты #Junior?',
#  'Может ли родитель/клиент управлять средствами ребенка на карте #Junior?',
#  'Какие ограничения устанавливает банк на использование детских карт?',
#  'Как родитель может управлять картой ребенка?',
#  'Можно ли выпустить карту для детей нерезидентов?',
#  'Какой тип/вид пластика у #BCCPAY - зарплатная карта?',
#  'Какой вид карты у #BCCPAY - зарплатная карта?',
#  'В какой валюте ведется счет для #BCCPAY - зарплатная карта?',
#  'Какова стоимость выпуска карты #BCCPAY - зарплатная карта?',
#  'Возможен ли выпуск дополнительной карты для #BCCPAY - зарплатная карта?',
#  'Какова стоимость перевыпуска карты #BCCPAY - зарплатная карта при утере/краже/повреждении пластика?',
#  'Какова стоимость годового обслуживания карты #BCCPAY - зарплатная карта?',
#  'Каков срок действия пластика карты #BCCPAY - зарплатная карта?',
#  'Доступны ли кредиты для #BCCPAY - зарплатная карта?',
#  'Где можно использовать карту #BCCPAY - зарплатная карта?']

# %%
answers
# Out:
# ['Минимальная сумма открытия составляет 500,000 KZT.',
#  'Дополнительные взносы не допускаются.',
#  'По истечении 30 календарных дней с даты подачи заявления клиента, возвращение выплачивается по ставке вклада до востребования, действующего на дату расторжения Договора.',
#  'Ставки возвращения составляют 0.1% в тенге, долларе США, евро, и российском рубле.',
#  'Cтавки при открытии через приложение BCC.KZ для срока в 3, 6 и 12 месяцев составляют 17.2%, 17.2% и 15.7% соответственно. При открытии через отделение банка ставки составляют 16.1%, 16.1% и 14.6% соответственно.',
#  'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.',
#  'Вклады, открытые до 02.12.2020 года, продлеваются допускается. Вклады, открытые после 02.12.2020 года, автоматически переоформляются на вклад «Чемпион» со сроком размещения 13 месяцев.',
#  'Частичное изъятие не допускается.',
#  'Капитализация происходит 1-го числа каждого месяца.',
#  'Минимальная сумма для досрочного расторжения составляет 500 в тенге, 10 в долларах США, 15 в евро.',
#  'Минимальная сумма открытия составляет 1 000 KZT/RUB, 10 USD/EUR.',
#  'Да, дополнительные взносы допускаются.',
#  'Частичное изъятие разрешено без ограничений, но соблюдая минимальный неснижаемый остаток (1 000 KZT/RUB, 10 USD/EUR).',
#  'Досрочное расторжение возможно "День в день", то есть возвращение вклада в день подачи заявления на расторжение.',
#  'Вознаграждение вычисляется исходя из фактического периода размещения денег на вкладе, без пересчета ранее выплаченного вознаграждения.',
#  'Пролонгация возможна от 13 до 24 месяцев, но не более 2-х раз.',
#  'Капитализация происходит ежемесячно, 1-го числа каждого месяца.',
#  'Ставки составляют 14% и 8.65% в тенге, 0.75% и 0.75% в долларе США, 0.1% и 0.1% в евро, 0.1% и 0.1% в российском рубле соответственно для сроков в 13 и 24 месяца.',
#  'Да, ставки при открытии через приложение на 13 и 24 месяца чуть выше (14% и 8.65% в тенге) по сравнению с открытием через отделение банка (13.1% и 7.7% в тенге). Эффективные ставки также немного выше при открытии через приложение.',
#  'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.',
#  'Минимальная сумма открытия составляет 1 KZT.',
#  'Да, дополнительные взносы допускаются.',
#  'Частичное снятие не допускается.',
#  'Досрочное расторжение возможно "День в день". Если расторжение договора происходит до истечения одного месяца с даты зачисления первой суммы вклада на счет, вознаграждение не начисляется. При расторжении договора после истечения более одного месяца с даты зачисления первой суммы вклада на счет, удерживается штраф в размере 50% от начисленного вознаграждения.',
#  'Да, по вкладам «Моя цель» предусмотрено неограниченное количество пролонгаций.',
#  'Капитализация происходит ежемесячно, 1-го числа каждого месяца.',
#  'Ставки в тенге составляют 14.9% для сроков в 3 и 6 месяцев и 12.9% для срока в 12 месяцев.',
#  'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.',
#  'Проценты начисляется, даже если на депозит наложен арест. Вы сможете воспользоваться своим депозитом и начисленными процентами, как только арест будет снят.',
#  'Для того чтобы унаследовать вклад, нужно обратиться в ближайшее отделении Банка при себе иметь: Нотариально удостоверенная копия свидетельства о праве наследование счетом по закону и нотариально заверенная копия свидетельства о смерти Вкладчика Уведомление о смерти Вкладчика с ЦОН-а',
#  'Вам необходимо выдать доверенность, с указанием, какие именно действия по депозиту вы доверяете совершать родственнику. Доверенность может быть оформлена у нотариуса или консула от имени РК При обслуживании вашему родственнику всегда необходимо будет предоставлять оригинал доверенности и документ, удостоверяющий его личность',
#  'Так как дата окончания выпадает не на будний день, у Вас будет возможность закрыть вклад на следующий рабочий день. При себе необходимо иметь документ удостоверяющий личность.',
#  'Вклад автоматически пролонгируется, по ставке действующей на момент пролонгации. Как только Ваш вклад будет пролонгирован, Вы сможете снять средства с депозита по истечению такого же срока либо можно написать заявление для досрочного расторжения. По истечении 30 календарных дней с даты подачи заявления, вознаграждение выплачивается по ставке вклада «До востребования», действующего на дату расторжения Договора. А пролонгация по депозитам открытым с 04.12.2020 отсутствует возможность автоматической пролонгации вклада. В день истечения срока действия договора предусмотрено автоматическое переоформление на депозит "Чемпион", со сроком на 13 месяцев.',
#  'Депозит можно закрыть в любом отделении Банка ЦентрКредит в рабочее время или в мобильном приложении BCC.KZ',
#  'Для закрытия вклада при себе необходимо иметь удостоверние личности либо паспорт РК',
#  'Чтобы пополнить депозит, необходимо ввести ИИН вкладчика и последние 4 цифры счета. Комиссия за пополнение не взимается. Средства поступают на счет в течение 15 минут. Максимальная сумма для одного терминала составляет 500 000 тенге, при этом можно внести не более 40 купюр.',
#  'Пополнение депозита через приложение BCC.KZ осуществляется через переводы между своими счетами. Комиссия за перевод не взимается, и средства поступают на счет моментально.',
#  'Пополнение депозита наличными через кассу в отделении БЦК возможно без комиссии. Также пополнить счет может третье лицо.',
#  'Независимо от способа пополнения — через КАССА 24, Cash-in банкоматы, ИПТ БЦК, приложение BCC.KZ или наличными через кассу в отделении — комиссия составляет 0 тенге.',
#  'Третье лицо может пополнить депозит через кассу в отделении БЦК без комиссии.',
#  'Тип пластика у #картакарта - Visa Gold.',
#  '#картакарта является картой рассрочки/кредитной картой/дебетовой картой.',
#  'Валюта ведения счета для #картакарта - Тенге.',
#  'Стоимость выпуска карты #картакарта - 0 тенге.',
#  'Выпуск дополнительной карты для #картакарта невозможен.',
#  'Стоимость перевыпуска карты #картакарта составляет 0 тенге.',
#  'Годовое обслуживание карты #картакарта составляет 0 тенге.',
#  'Срок действия пластика карты #картакарта составляет 5 лет.',
#  'Срок действия договора кредитного лимита для #картакарта составляет 3 года.',
#  'Карту #картакарта можно использовать во всем мире.',
#  '#картакарта - это универсальная карта с кредитным лимитом, которая позволяет оплачивать покупки без процентов в льготный период, покупать в рассрочку без переплат у партнеров Банка и зарабатывать кешбэк.',
#  'За первую покупку по карте мы зачислим на ваш кешбэк-счет приветственный бонус - 10% от суммы покупки (максимум 1 000 Тенге).',
#  'Оплачивайте покупки картой и зарабатывайте кешбэк до 30%.',
#  'Кешбэк за покупки по карте — это вознаграждение от Банка и наших партнеров за использование карты, возвращающее определенную сумму за покупки.',
#  'В начале каждого месяца мы предлагаем новый набор категорий покупок с кешбэком до 10%. Выбор категорий можно делать в мобильном приложении BCC.KZ.',
#  'Картой можно пользоваться по всему миру.',
#  'Пополняйте карту с другой карты или счета, банковским переводом из другого банка, наличными через банкоматы, терминалы или кассу Банка. Пополнение карты - бесплатно!',
#  'С #картакарта вы зарабатываете деньги, когда их тратите. Покупайте за счет личных денег, получайте кешбэк до 30%, и Банк может пересмотреть размер лимита.',
#  'Кредитный лимит - это ваша личная заначка, когда личных денег на покупку оказалось недостаточно.',
#  'Вы получите уведомление от Банка.',
#  'Сначала используются ваши личные деньги, затем кредитный лимит.',
#  'Вы можете включать и отключать режим рассрочки онлайн в мобильном приложении BCC.KZ.',
#  'В сети партнеров Банка предусмотрены сроки рассрочки на 3, 6 или 12 месяцев в зависимости от условий договоренности с партнером.',
#  'Покупки у партнеров Банка осуществляются без процентов и комиссий.',
#  'Покупки в рассрочку возможны за счет кредитного лимита.',
#  'Погашать задолженность по карте досрочно можно в любое время без штрафов и посещения Банка для формирования графиков.',
#  'На данный момент кредитный лимит устанавливается только резидентам РК, но вы можете пользоваться картой за счет личных денег и получать кешбэк до 30%.',
#  'Теперь не нужно закрывать виртуальную #картакарта для открытия физической. Клиент может обратиться в отделение Банка для получения пластика и его привязки к счету виртуальной #картакарта.',
#  'Согласно Заявлению к Договору присоединения (по Кредитным карточкам), заключенному между Банком и клиентом, Банк имеет право без дополнительного согласия клиента изменять сумму кредитного лимита в сторону увеличения, с обязательным уведомлением клиента.',
#  'В мобильном приложении можно подать заявку на увеличение кредитного лимита (функционал доступен раз в 30 дней). Лимит может быть увеличен до 7 миллионов тенге.',
#  'Увеличение лимита - это показатель доверия Банка и запасные деньги, которые всегда будут под рукой.',
#  'Аннулирование только кредитного лимита без закрытия самой #картакарта невозможно. Рекомендуется рассказать о преимуществах #картакарта.',
#  'Открыть карту можно только в тенге.',
#  'Можно использовать на любые потребительские цели.',
#  'Можем рассмотреть без отчислений.',
#  'Срок действия кэшбека 1 год.',
#  'Если клиент открывает впервые #картакарта и хочет открыть виртуальную.',
#  'По картакарта страховка не предусмотрена.',
#  'Привлечь созаемщика для рассмотрение кредитного лимита не предусмотрено.',
#  'Это время, в течение которого вы можете пользоваться деньгами со своей кредитной карты и не платить проценты.',
#  'Зафиксируем обращение.',
#  'Оплата мобильной связи, коммунальные платежи, образование, интернет, TV, транспорт и билеты.',
#  'Объединить кэшбэк по стандартным картам и по кредитной карте для быстрого накопления невозможно.',
#  'На оплаты по рассрочке кэшбэк не начисляется.',
#  'Клиент может подать заявку на увеличение кредитного лимита в мобильном приложении (доступно раз в 30 дней), скоринговая система будет решать сумму кредитного лимита.',
#  'Тип пластика у #IronCard - Visa Infinite.',
#  '#IronCard является дебетовой картой.',
#  'Счет для #IronCard ведется в KZT (основной счет), USD, EUR, RUB.',
#  'Для резидентов РК стоимость выпуска составляет 30 000 тенге, для нерезидентов РК - 100 000 тенге. Гравировка индивидуального изображения стоит 5 000 тенге.',
#  'Выпуск дополнительной карты для #IronCard невозможен.',
#  'Перевыпуск карты по истечении срока действия - 0 тенге, по просьбе клиента или при утере - 80 000 тенге, по инициативе банка - 0 тенге.',
#  'Годовое обслуживание карты #IronCard составляет 10 000 KZT ежемесячно.',
#  'Срок действия пластика карты #IronCard составляет 8 лет.',
#  'Кредиты для карты #IronCard не предусмотрены.',
#  'Карту #IronCard можно использовать во всем мире.',
#  'Тип пластика у #Travel Card - Visa Signature.',
#  '#Travel Card является дебетовой картой.',
#  'Счет для #Travel Card ведется в KZT (основной счет), USD, EUR, RUB.',
#  'Для резидентов РК стоимость выпуска составляет 10 000 KZT, для нерезидентов РК - 50 000 KZT.',
#  'Выпуск дополнительной карты для #Travel Card невозможен.',
#  'Стоимость перевыпуска карты #Travel Card составляет 0 тенге.',
#  'Годовое обслуживание карты #Travel Card составляет 0 тенге.',
#  'Срок действия пластика карты #Travel Card составляет 8 лет.',
#  'Кредиты для карты #Travel Card не предусмотрены.',
#  'Карту #Travel Card можно использовать во всем мире.',
#  'Тип пластика у #ҮлкенгеҚұрмет - Visa Gold.',
#  '#ҮлкенгеҚұрмет является дебетовой картой.',
#  'Валюта ведения счета для #ҮлкенгеҚұрмет - Тенге.',
#  'Стоимость выпуска карты #ҮлкенгеҚұрмет - 0 тенге.',
#  'Выпуск дополнительной карты для #ҮлкенгеҚұрмет невозможен.',
#  'Стоимость перевыпуска карты #ҮлкенгеҚұрмет составляет 0 тенге.',
#  'Годовое обслуживание карты #ҮлкенгеҚұрмет составляет 0 тенге.',
#  'Срок действия пластика карты #ҮлкенгеҚұрмет составляет 3 года.',
#  'Кредиты для карты #ҮлкенгеҚұрмет не предусмотрены.',
#  'Карту #ҮлкенгеҚұрмет можно использовать во всем мире.',
#  'Пенсионная карта принимается в более чем 2 миллионах банкоматов по всему миру.',
#  'Вы можете снимать деньги с Пенсионной карты #ҮлкенгеҚұрмет в банкоматах других банков до 1 500 000 тенге в месяц бесплатно. За суммы свыше этого взимается комиссия 1% от суммы снятия.',
#  'При снятии денег с Пенсионной карты #ҮлкенгеҚұрмет в банкоматах за пределами Казахстана действуют те же условия: до 1 500 000 тенге в месяц без комиссии, сверх этого - комиссия 1% от суммы.',
#  'Вы можете снимать деньги в другой валюте с вашей Пенсионной карты #ҮлкенгеҚұрмет.',
#  'Пенсионная карта #ҮлкенгеҚұрмет предназначена для получения пенсионных выплат, осуществляемых через единый накопительный пенсионный фонд.',
#  'Преимущества включают автоматическую передачу реквизитов в ЦОН для экономии времени, cashback 3% за покупки в аптеках и 2% за продукты питания, а также бесплатную услугу смс-информирования о поступлении пенсии на карту.',
#  'Выпуск Пенсионной карты через отделение банка занимает всего 10 минут, так как карта является мгновенной.',
#  'Ознакомиться с тарифами по Пенсионной карте можно на официальном сайте Банка.',
#  'В таком случае необходимо обратиться в ЦОН по номеру 1414 для выяснения статуса выплаты.',
#  'Пенсия выплачивается ежемесячно с 1-го по 15-е число.',
#  'Даже при наличии арестованных счетов и статуса бездействующего налогоплательщика, вам будет открыта Пенсионная карта.',
#  'Для открытия Пенсионной карты требуется документ, удостоверяющий личность.',
#  'О поступлении пенсии на счет вам придет СМС-сообщение, или вы можете проверить это через мобильное приложение BCC.KZ.',
#  'Получить номер счета/IBAN можно через мобильное приложение BCC.KZ, выбрав Пенсионную карту и перейдя во вкладку Информация, либо через отделение Банка.',
#  'Пополнить Пенсионную карту можно через банкомат с функцией cash-in, платежный терминал, перевод на карту, кассу и другие способы.',
#  'Кэшбек начисляется за покупки в аптеках (3%) и за продукты питания (2%).',
#  'Кэшбек будет начислен на вашу Пенсионную карту, и вы можете контролировать информацию о нем в мобильном приложении BCC.KZ.',
#  'Перевыпуск Пенсионной карты осуществляется бесплатно.',
#  'Тип пластика у #JuniorBank - Visa Gold.',
#  '#JuniorBank является дебетовой картой.',
#  'Валюта ведения счета для #JuniorBank - Тенге.',
#  'Стоимость выпуска карты #JuniorBank - 0 тенге.',
#  'Выпуск дополнительной карты для #JuniorBank невозможен.',
#  'Стоимость перевыпуска карты #JuniorBank составляет 0 тенге.',
#  'Годовое обслуживание карты #JuniorBank составляет 0 тенге.',
#  'Срок действия пластика карты #JuniorBank составляет 8 лет.',
#  'Кредиты для карты #JuniorBank не предусмотрены.',
#  'Карту #JuniorBank можно использовать во всем мире.',
#  'Карта #Junior представляет собой детскую банковскую карту, доступную в двух форматах: виртуальная карта, выпускаемая дистанционно через приложение BCC.KZ родителем, и пластиковая карта мгновенного выпуска, оформляемая в любом отделении банка. Оба вида карт позволяют оплачивать покупки, совершать платежи и переводы, а также снимать деньги в специальных банкоматах.',
#  'Кэшбек представляет собой возврат определенного процента от суммы совершенной покупки по карте, который зачисляется обратно на счет карты.',
#  'Ребенок имеет возможность самостоятельно осуществлять переводы денег с карты на карту через Junior Bank, используя как номер телефона, так и номер карты.',
#  'Карту #Junior может выпустить любой клиент банка, у которого уже есть какая-либо карта БЦК.',
#  'Клиент банка может выпустить Карту #Junior не только для своих детей, но и для племянников, внуков, братьев и сестер, позволяя, например, бабушке оформить карту для внука или дяде - для племянника.',
#  'Карта #Junior предназначена для детей в возрасте от 6 до 18 лет.',
#  'Выпуск и обслуживание карты #Junior осуществляется бесплатно, также как и предоставление СМС/ПУШ-уведомлений как для ребенка, так и для родителя.',
#  'После выпуска виртуальной карты родителем/клиентом, на сотовый номер ребенка отправляется СМС-сообщение со ссылкой на скачивание мобильного приложения Junior Bank. Ребенок должен скачать приложение, зарегистрироваться в нем, используя свой номер телефона, подтвердить действие датой рождения и создать пароль для доступа в приложение.',
#  'Для осуществления платежей с помощью смартфона, ребенок должен использовать телефоны iPhone или Samsung с поддержкой NFC. Реквизиты карты можно запросить в приложении Junior Bank и добавить в электронные кошельки Apple Pay (iPhone) или Samsung Pay (Samsung).',
#  'Ребенок имеет возможность использовать как виртуальную, так и пластиковую карту, поскольку обе карты связаны с одним и тем же счетом, и баланс на них будет единым.',
#  'Нет необходимости закрывать виртуальную карту при выпуске пластиковой, так как ребенок может пользоваться обоими картами для различных целей: виртуальной для оплаты через Apple Pay/Samsung Pay и пластиковой для традиционных покупок.',
#  'Отсутствует необходимость в открытии виртуальной карты, если ребенок уже пользуется пластиковой картой #Junior. Однако, для привязки карты к Apple Pay/Samsung Pay, можно добавить реквизиты пластиковой карты в соответствующие электронные кошельки.',
#  'Мобильное приложение Junior Bank предоставляет ребенку информацию о его карте, доступных средствах, истории покупок, заработанном кешбэке, а также ожидаемых функциях, таких как платежи, переводы и выбор любимых категорий.',
#  'Ребенок имеет доступ только к информации о своей карте и доступных на ней средствах, не видя данных о карте родителя/клиента.',
#  'Родитель/клиент может видеть карту ребенка и операции, совершенные по ней, в своем мобильном приложении BCC.KZ.',
#  'При совершении покупок по карте #Junior начисляется гарантированный кэшбэк в размере 1% на любую сумму покупки, даже на минимальную в 10 тенге, при этом максимальная сумма кэшбэка в месяц составляет 10 000 тенге.',
#  'Родитель не имеет возможности совершать платежи, снимать деньги или переводить средства с детской карты обратно на свою.',
#  'Детские карты обладают автоматическими ограничениями, предотвращающими их использование в торговых точках категории 18+, таких как табачные лавки, алкомаркеты, религиозные магазины, казино, коммерческие спортивные организации, аренда автомобилей и прочее.',
#  'Родители имеют возможность управления картой ребенка посредством различных функций. Они могут блокировать или разблокировать карту в случае необходимости. Также родители могут настраивать лимиты трат по различным направлениям, включая снятие наличных в банкоматах, переводы с детских карт на другие карты, оплату покупок и покупки в интернете. Эти лимиты могут быть скорректированы как в сторону увеличения, так и уменьшения. Кроме того, родители могут сбросить и установить новый ПИН-код для карты ребенка. Дополнительно предусмотрена возможность настройки смс-уведомлений, которые будут поступать на телефон родителя о действиях, совершаемых с детской картой.',
#  'Выпуск карты для детей нерезидентов осуществим при условии, что у родителя или законного представителя ребенка имеется любая карта банка БЦК. Это предоставляет родителям возможность управления финансами своих детей, даже если они являются нерезидентами.',
#  'Тип пластика у #BCCPAY - зарплатная карта - Visa Gold.',
#  '#BCCPAY - зарплатная карта является дебетовой картой.',
#  'Валюта ведения счета для #BCCPAY - зарплатная карта - Тенге.',
#  'Стоимость выпуска карты #BCCPAY - зарплатная карта - 0 тенге.',
#  'Выпуск дополнительной карты для #BCCPAY - зарплатная карта невозможен.',
#  'Стоимость перевыпуска карты #BCCPAY - зарплатная карта составляет 0 тенге.',
#  'Годовое обслуживание карты #BCCPAY - зарплатная карта составляет 0 тенге.',
#  'Срок действия пластика карты #BCCPAY - зарплатная карта составляет 3 года.',
#  'Кредиты для карты #BCCPAY - зарплатная карта не предусмотрены.',
#  'Карту #BCCPAY - зарплатная карта можно использовать во всем мире.']

# %%
[list(TextBlob(x).words) for x in answers]
# Out:
# [['Минимальная', 'сумма', 'открытия', 'составляет', '500,000', 'KZT'],
#  ['Дополнительные', 'взносы', 'не', 'допускаются'],
#  ['По',
#   'истечении',
#   '30',
#   'календарных',
#   'дней',
#   'с',
#   'даты',
#   'подачи',
#   'заявления',
#   'клиента',
#   'возвращение',
#   'выплачивается',
#   'по',
#   'ставке',
#   'вклада',
#   'до',
#   'востребования',
#   'действующего',
#   'на',
#   'дату',
#   'расторжения',
#   'Договора'],
#  ['Ставки',
#   'возвращения',
#   'составляют',
#   '0.1',
#   'в',
#   'тенге',
#   'долларе',
#   'США',
#   'евро',
#   'и',
#   'российском',
#   'рубле'],
#  ['Cтавки',
#   'при',
#   'открытии',
#   'через',
#   'приложение',
#   'BCC.KZ',
#   'для',
#   'срока',
#   'в',
#   '3',
#   '6',
#   'и',
#   '12',
#   'месяцев',
#   'составляют',
#   '17.2',
#   '17.2',
#   'и',
#   '15.7',
#   'соответственно',
#   'При',
#   'открытии',
#   'через',
#   'отделение',
#   'банка',
#   'ставки',
#   'составляют',
#   '16.1',
#   '16.1',
#   'и',
#   '14.6',
#   'соответственно'],
#  ['Вознаграждение',
#   'рассчитывается',
#   'по',
#   'формуле',
#   'сумма',
#   'вклада',
#   'X',
#   'количество',
#   'дней',
#   'начисления',
#   'процентов',
#   'по',
#   'вкладу',
#   'в',
#   'месяце',
#   'X',
#   'номинальная',
#   'процентная',
#   'ставка',
#   '365',
#   'дней',
#   'сумма',
#   'вознаграждения'],
#  ['Вклады',
#   'открытые',
#   'до',
#   '02.12.2020',
#   'года',
#   'продлеваются',
#   'допускается',
#   'Вклады',
#   'открытые',
#   'после',
#   '02.12.2020',
#   'года',
#   'автоматически',
#   'переоформляются',
#   'на',
#   'вклад',
#   '«',
#   'Чемпион',
#   '»',
#   'со',
#   'сроком',
#   'размещения',
#   '13',
#   'месяцев'],
#  ['Частичное', 'изъятие', 'не', 'допускается'],
#  ['Капитализация', 'происходит', '1-го', 'числа', 'каждого', 'месяца'],
#  ['Минимальная',
#   'сумма',
#   'для',
#   'досрочного',
#   'расторжения',
#   'составляет',
#   '500',
#   'в',
#   'тенге',
#   '10',
#   'в',
#   'долларах',
#   'США',
#   '15',
#   'в',
#   'евро'],
#  ['Минимальная',
#   'сумма',
#   'открытия',
#   'составляет',
#   '1',
#   '000',
#   'KZT/RUB',
#   '10',
#   'USD/EUR'],
#  ['Да', 'дополнительные', 'взносы', 'допускаются'],
#  ['Частичное',
#   'изъятие',
#   'разрешено',
#   'без',
#   'ограничений',
#   'но',
#   'соблюдая',
#   'минимальный',
#   'неснижаемый',
#   'остаток',
#   '1',
#   '000',
#   'KZT/RUB',
#   '10',
#   'USD/EUR'],
#  ['Досрочное',
#   'расторжение',
#   'возможно',
#   'День',
#   'в',
#   'день',
#   'то',
#   'есть',
#   'возвращение',
#   'вклада',
#   'в',
#   'день',
#   'подачи',
#   'заявления',
#   'на',
#   'расторжение'],
#  ['Вознаграждение',
#   'вычисляется',
#   'исходя',
#   'из',
#   'фактического',
#   'периода',
#   'размещения',
#   'денег',
#   'на',
#   'вкладе',
#   'без',
#   'пересчета',
#   'ранее',
#   'выплаченного',
#   'вознаграждения'],
#  ['Пролонгация',
#   'возможна',
#   'от',
#   '13',
#   'до',
#   '24',
#   'месяцев',
#   'но',
#   'не',
#   'более',
#   '2-х',
#   'раз'],
#  ['Капитализация',
#   'происходит',
#   'ежемесячно',
#   '1-го',
#   'числа',
#   'каждого',
#   'месяца'],
#  ['Ставки',
#   'составляют',
#   '14',
#   'и',
#   '8.65',
#   'в',
#   'тенге',
#   '0.75',
#   'и',
#   '0.75',
#   'в',
#   'долларе',
#   'США',
#   '0.1',
#   'и',
#   '0.1',
#   'в',
#   'евро',
#   '0.1',
#   'и',
#   '0.1',
#   'в',
#   'российском',
#   'рубле',
#   'соответственно',
#   'для',
#   'сроков',
#   'в',
#   '13',
#   'и',
#   '24',
#   'месяца'],
#  ['Да',
#   'ставки',
#   'при',
#   'открытии',
#   'через',
#   'приложение',
#   'на',
#   '13',
#   'и',
#   '24',
#   'месяца',
#   'чуть',
#   'выше',
#   '14',
#   'и',
#   '8.65',
#   'в',
#   'тенге',
#   'по',
#   'сравнению',
#   'с',
#   'открытием',
#   'через',
#   'отделение',
#   'банка',
#   '13.1',
#   'и',
#   '7.7',
#   'в',
#   'тенге',
#   'Эффективные',
#   'ставки',
#   'также',
#   'немного',
#   'выше',
#   'при',
#   'открытии',
#   'через',
#   'приложение'],
#  ['Вознаграждение',
#   'рассчитывается',
#   'по',
#   'формуле',
#   'сумма',
#   'вклада',
#   'X',
#   'количество',
#   'дней',
#   'начисления',
#   'процентов',
#   'по',
#   'вкладу',
#   'в',
#   'месяце',
#   'X',
#   'номинальная',
#   'процентная',
#   'ставка',
#   '365',
#   'дней',
#   'сумма',
#   'вознаграждения'],
#  ['Минимальная', 'сумма', 'открытия', 'составляет', '1', 'KZT'],
#  ['Да', 'дополнительные', 'взносы', 'допускаются'],
#  ['Частичное', 'снятие', 'не', 'допускается'],
#  ['Досрочное',
#   'расторжение',
#   'возможно',
#   'День',
#   'в',
#   'день',
#   'Если',
#   'расторжение',
#   'договора',
#   'происходит',
#   'до',
#   'истечения',
#   'одного',
#   'месяца',
#   'с',
#   'даты',
#   'зачисления',
#   'первой',
#   'суммы',
#   'вклада',
#   'на',
#   'счет',
#   'вознаграждение',
#   'не',
#   'начисляется',
#   'При',
#   'расторжении',
#   'договора',
#   'после',
#   'истечения',
#   'более',
#   'одного',
#   'месяца',
#   'с',
#   'даты',
#   'зачисления',
#   'первой',
#   'суммы',
#   'вклада',
#   'на',
#   'счет',
#   'удерживается',
#   'штраф',
#   'в',
#   'размере',
#   '50',
#   'от',
#   'начисленного',
#   'вознаграждения'],
#  ['Да',
#   'по',
#   'вкладам',
#   '«',
#   'Моя',
#   'цель',
#   '»',
#   'предусмотрено',
#   'неограниченное',
#   'количество',
#   'пролонгаций'],
#  ['Капитализация',
#   'происходит',
#   'ежемесячно',
#   '1-го',
#   'числа',
#   'каждого',
#   'месяца'],
#  ['Ставки',
#   'в',
#   'тенге',
#   'составляют',
#   '14.9',
#   'для',
#   'сроков',
#   'в',
#   '3',
#   'и',
#   '6',
#   'месяцев',
#   'и',
#   '12.9',
#   'для',
#   'срока',
#   'в',
#   '12',
#   'месяцев'],
#  ['Вознаграждение',
#   'рассчитывается',
#   'по',
#   'формуле',
#   'сумма',
#   'вклада',
#   'X',
#   'количество',
#   'дней',
#   'начисления',
#   'процентов',
#   'по',
#   'вкладу',
#   'в',
#   'месяце',
#   'X',
#   'номинальная',
#   'процентная',
#   'ставка',
#   '365',
#   'дней',
#   'сумма',
#   'вознаграждения'],
#  ['Проценты',
#   'начисляется',
#   'даже',
#   'если',
#   'на',
#   'депозит',
#   'наложен',
#   'арест',
#   'Вы',
#   'сможете',
#   'воспользоваться',
#   'своим',
#   'депозитом',
#   'и',
#   'начисленными',
#   'процентами',
#   'как',
#   'только',
#   'арест',
#   'будет',
#   'снят'],
#  ['Для',
#   'того',
#   'чтобы',
#   'унаследовать',
#   'вклад',
#   'нужно',
#   'обратиться',
#   'в',
#   'ближайшее',
#   'отделении',
#   'Банка',
#   'при',
#   'себе',
#   'иметь',
#   'Нотариально',
#   'удостоверенная',
#   'копия',
#   'свидетельства',
#   'о',
#   'праве',
#   'наследование',
#   'счетом',
#   'по',
#   'закону',
#   'и',
#   'нотариально',
#   'заверенная',
#   'копия',
#   'свидетельства',
#   'о',
#   'смерти',
#   'Вкладчика',
#   'Уведомление',
#   'о',
#   'смерти',
#   'Вкладчика',
#   'с',
#   'ЦОН-а'],
#  ['Вам',
#   'необходимо',
#   'выдать',
#   'доверенность',
#   'с',
#   'указанием',
#   'какие',
#   'именно',
#   'действия',
#   'по',
#   'депозиту',
#   'вы',
#   'доверяете',
#   'совершать',
#   'родственнику',
#   'Доверенность',
#   'может',
#   'быть',
#   'оформлена',
#   'у',
#   'нотариуса',
#   'или',
#   'консула',
#   'от',
#   'имени',
#   'РК',
#   'При',
#   'обслуживании',
#   'вашему',
#   'родственнику',
#   'всегда',
#   'необходимо',
#   'будет',
#   'предоставлять',
#   'оригинал',
#   'доверенности',
#   'и',
#   'документ',
#   'удостоверяющий',
#   'его',
#   'личность'],
#  ['Так',
#   'как',
#   'дата',
#   'окончания',
#   'выпадает',
#   'не',
#   'на',
#   'будний',
#   'день',
#   'у',
#   'Вас',
#   'будет',
#   'возможность',
#   'закрыть',
#   'вклад',
#   'на',
#   'следующий',
#   'рабочий',
#   'день',
#   'При',
#   'себе',
#   'необходимо',
#   'иметь',
#   'документ',
#   'удостоверяющий',
#   'личность'],
#  ['Вклад',
#   'автоматически',
#   'пролонгируется',
#   'по',
#   'ставке',
#   'действующей',
#   'на',
#   'момент',
#   'пролонгации',
#   'Как',
#   'только',
#   'Ваш',
#   'вклад',
#   'будет',
#   'пролонгирован',
#   'Вы',
#   'сможете',
#   'снять',
#   'средства',
#   'с',
#   'депозита',
#   'по',
#   'истечению',
#   'такого',
#   'же',
#   'срока',
#   'либо',
#   'можно',
#   'написать',
#   'заявление',
#   'для',
#   'досрочного',
#   'расторжения',
#   'По',
#   'истечении',
#   '30',
#   'календарных',
#   'дней',
#   'с',
#   'даты',
#   'подачи',
#   'заявления',
#   'вознаграждение',
#   'выплачивается',
#   'по',
#   'ставке',
#   'вклада',
#   '«',
#   'До',
#   'востребования',
#   '»',
#   'действующего',
#   'на',
#   'дату',
#   'расторжения',
#   'Договора',
#   'А',
#   'пролонгация',
#   'по',
#   'депозитам',
#   'открытым',
#   'с',
#   '04.12.2020',
#   'отсутствует',
#   'возможность',
#   'автоматической',
#   'пролонгации',
#   'вклада',
#   'В',
#   'день',
#   'истечения',
#   'срока',
#   'действия',
#   'договора',
#   'предусмотрено',
#   'автоматическое',
#   'переоформление',
#   'на',
#   'депозит',
#   'Чемпион',
#   'со',
#   'сроком',
#   'на',
#   '13',
#   'месяцев'],
#  ['Депозит',
#   'можно',
#   'закрыть',
#   'в',
#   'любом',
#   'отделении',
#   'Банка',
#   'ЦентрКредит',
#   'в',
#   'рабочее',
#   'время',
#   'или',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['Для',
#   'закрытия',
#   'вклада',
#   'при',
#   'себе',
#   'необходимо',
#   'иметь',
#   'удостоверние',
#   'личности',
#   'либо',
#   'паспорт',
#   'РК'],
#  ['Чтобы',
#   'пополнить',
#   'депозит',
#   'необходимо',
#   'ввести',
#   'ИИН',
#   'вкладчика',
#   'и',
#   'последние',
#   '4',
#   'цифры',
#   'счета',
#   'Комиссия',
#   'за',
#   'пополнение',
#   'не',
#   'взимается',
#   'Средства',
#   'поступают',
#   'на',
#   'счет',
#   'в',
#   'течение',
#   '15',
#   'минут',
#   'Максимальная',
#   'сумма',
#   'для',
#   'одного',
#   'терминала',
#   'составляет',
#   '500',
#   '000',
#   'тенге',
#   'при',
#   'этом',
#   'можно',
#   'внести',
#   'не',
#   'более',
#   '40',
#   'купюр'],
#  ['Пополнение',
#   'депозита',
#   'через',
#   'приложение',
#   'BCC.KZ',
#   'осуществляется',
#   'через',
#   'переводы',
#   'между',
#   'своими',
#   'счетами',
#   'Комиссия',
#   'за',
#   'перевод',
#   'не',
#   'взимается',
#   'и',
#   'средства',
#   'поступают',
#   'на',
#   'счет',
#   'моментально'],
#  ['Пополнение',
#   'депозита',
#   'наличными',
#   'через',
#   'кассу',
#   'в',
#   'отделении',
#   'БЦК',
#   'возможно',
#   'без',
#   'комиссии',
#   'Также',
#   'пополнить',
#   'счет',
#   'может',
#   'третье',
#   'лицо'],
#  ['Независимо',
#   'от',
#   'способа',
#   'пополнения',
#   '—',
#   'через',
#   'КАССА',
#   '24',
#   'Cash-in',
#   'банкоматы',
#   'ИПТ',
#   'БЦК',
#   'приложение',
#   'BCC.KZ',
#   'или',
#   'наличными',
#   'через',
#   'кассу',
#   'в',
#   'отделении',
#   '—',
#   'комиссия',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Третье',
#   'лицо',
#   'может',
#   'пополнить',
#   'депозит',
#   'через',
#   'кассу',
#   'в',
#   'отделении',
#   'БЦК',
#   'без',
#   'комиссии'],
#  ['Тип', 'пластика', 'у', 'картакарта', 'Visa', 'Gold'],
#  ['картакарта',
#   'является',
#   'картой',
#   'рассрочки/кредитной',
#   'картой/дебетовой',
#   'картой'],
#  ['Валюта', 'ведения', 'счета', 'для', 'картакарта', 'Тенге'],
#  ['Стоимость', 'выпуска', 'карты', 'картакарта', '0', 'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'картакарта', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'картакарта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'картакарта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'картакарта',
#   'составляет',
#   '5',
#   'лет'],
#  ['Срок',
#   'действия',
#   'договора',
#   'кредитного',
#   'лимита',
#   'для',
#   'картакарта',
#   'составляет',
#   '3',
#   'года'],
#  ['Карту', 'картакарта', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['картакарта',
#   'это',
#   'универсальная',
#   'карта',
#   'с',
#   'кредитным',
#   'лимитом',
#   'которая',
#   'позволяет',
#   'оплачивать',
#   'покупки',
#   'без',
#   'процентов',
#   'в',
#   'льготный',
#   'период',
#   'покупать',
#   'в',
#   'рассрочку',
#   'без',
#   'переплат',
#   'у',
#   'партнеров',
#   'Банка',
#   'и',
#   'зарабатывать',
#   'кешбэк'],
#  ['За',
#   'первую',
#   'покупку',
#   'по',
#   'карте',
#   'мы',
#   'зачислим',
#   'на',
#   'ваш',
#   'кешбэк-счет',
#   'приветственный',
#   'бонус',
#   '10',
#   'от',
#   'суммы',
#   'покупки',
#   'максимум',
#   '1',
#   '000',
#   'Тенге'],
#  ['Оплачивайте',
#   'покупки',
#   'картой',
#   'и',
#   'зарабатывайте',
#   'кешбэк',
#   'до',
#   '30'],
#  ['Кешбэк',
#   'за',
#   'покупки',
#   'по',
#   'карте',
#   '—',
#   'это',
#   'вознаграждение',
#   'от',
#   'Банка',
#   'и',
#   'наших',
#   'партнеров',
#   'за',
#   'использование',
#   'карты',
#   'возвращающее',
#   'определенную',
#   'сумму',
#   'за',
#   'покупки'],
#  ['В',
#   'начале',
#   'каждого',
#   'месяца',
#   'мы',
#   'предлагаем',
#   'новый',
#   'набор',
#   'категорий',
#   'покупок',
#   'с',
#   'кешбэком',
#   'до',
#   '10',
#   'Выбор',
#   'категорий',
#   'можно',
#   'делать',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['Картой', 'можно', 'пользоваться', 'по', 'всему', 'миру'],
#  ['Пополняйте',
#   'карту',
#   'с',
#   'другой',
#   'карты',
#   'или',
#   'счета',
#   'банковским',
#   'переводом',
#   'из',
#   'другого',
#   'банка',
#   'наличными',
#   'через',
#   'банкоматы',
#   'терминалы',
#   'или',
#   'кассу',
#   'Банка',
#   'Пополнение',
#   'карты',
#   'бесплатно'],
#  ['С',
#   'картакарта',
#   'вы',
#   'зарабатываете',
#   'деньги',
#   'когда',
#   'их',
#   'тратите',
#   'Покупайте',
#   'за',
#   'счет',
#   'личных',
#   'денег',
#   'получайте',
#   'кешбэк',
#   'до',
#   '30',
#   'и',
#   'Банк',
#   'может',
#   'пересмотреть',
#   'размер',
#   'лимита'],
#  ['Кредитный',
#   'лимит',
#   'это',
#   'ваша',
#   'личная',
#   'заначка',
#   'когда',
#   'личных',
#   'денег',
#   'на',
#   'покупку',
#   'оказалось',
#   'недостаточно'],
#  ['Вы', 'получите', 'уведомление', 'от', 'Банка'],
#  ['Сначала',
#   'используются',
#   'ваши',
#   'личные',
#   'деньги',
#   'затем',
#   'кредитный',
#   'лимит'],
#  ['Вы',
#   'можете',
#   'включать',
#   'и',
#   'отключать',
#   'режим',
#   'рассрочки',
#   'онлайн',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['В',
#   'сети',
#   'партнеров',
#   'Банка',
#   'предусмотрены',
#   'сроки',
#   'рассрочки',
#   'на',
#   '3',
#   '6',
#   'или',
#   '12',
#   'месяцев',
#   'в',
#   'зависимости',
#   'от',
#   'условий',
#   'договоренности',
#   'с',
#   'партнером'],
#  ['Покупки',
#   'у',
#   'партнеров',
#   'Банка',
#   'осуществляются',
#   'без',
#   'процентов',
#   'и',
#   'комиссий'],
#  ['Покупки',
#   'в',
#   'рассрочку',
#   'возможны',
#   'за',
#   'счет',
#   'кредитного',
#   'лимита'],
#  ['Погашать',
#   'задолженность',
#   'по',
#   'карте',
#   'досрочно',
#   'можно',
#   'в',
#   'любое',
#   'время',
#   'без',
#   'штрафов',
#   'и',
#   'посещения',
#   'Банка',
#   'для',
#   'формирования',
#   'графиков'],
#  ['На',
#   'данный',
#   'момент',
#   'кредитный',
#   'лимит',
#   'устанавливается',
#   'только',
#   'резидентам',
#   'РК',
#   'но',
#   'вы',
#   'можете',
#   'пользоваться',
#   'картой',
#   'за',
#   'счет',
#   'личных',
#   'денег',
#   'и',
#   'получать',
#   'кешбэк',
#   'до',
#   '30'],
#  ['Теперь',
#   'не',
#   'нужно',
#   'закрывать',
#   'виртуальную',
#   'картакарта',
#   'для',
#   'открытия',
#   'физической',
#   'Клиент',
#   'может',
#   'обратиться',
#   'в',
#   'отделение',
#   'Банка',
#   'для',
#   'получения',
#   'пластика',
#   'и',
#   'его',
#   'привязки',
#   'к',
#   'счету',
#   'виртуальной',
#   'картакарта'],
#  ['Согласно',
#   'Заявлению',
#   'к',
#   'Договору',
#   'присоединения',
#   'по',
#   'Кредитным',
#   'карточкам',
#   'заключенному',
#   'между',
#   'Банком',
#   'и',
#   'клиентом',
#   'Банк',
#   'имеет',
#   'право',
#   'без',
#   'дополнительного',
#   'согласия',
#   'клиента',
#   'изменять',
#   'сумму',
#   'кредитного',
#   'лимита',
#   'в',
#   'сторону',
#   'увеличения',
#   'с',
#   'обязательным',
#   'уведомлением',
#   'клиента'],
#  ['В',
#   'мобильном',
#   'приложении',
#   'можно',
#   'подать',
#   'заявку',
#   'на',
#   'увеличение',
#   'кредитного',
#   'лимита',
#   'функционал',
#   'доступен',
#   'раз',
#   'в',
#   '30',
#   'дней',
#   'Лимит',
#   'может',
#   'быть',
#   'увеличен',
#   'до',
#   '7',
#   'миллионов',
#   'тенге'],
#  ['Увеличение',
#   'лимита',
#   'это',
#   'показатель',
#   'доверия',
#   'Банка',
#   'и',
#   'запасные',
#   'деньги',
#   'которые',
#   'всегда',
#   'будут',
#   'под',
#   'рукой'],
#  ['Аннулирование',
#   'только',
#   'кредитного',
#   'лимита',
#   'без',
#   'закрытия',
#   'самой',
#   'картакарта',
#   'невозможно',
#   'Рекомендуется',
#   'рассказать',
#   'о',
#   'преимуществах',
#   'картакарта'],
#  ['Открыть', 'карту', 'можно', 'только', 'в', 'тенге'],
#  ['Можно', 'использовать', 'на', 'любые', 'потребительские', 'цели'],
#  ['Можем', 'рассмотреть', 'без', 'отчислений'],
#  ['Срок', 'действия', 'кэшбека', '1', 'год'],
#  ['Если',
#   'клиент',
#   'открывает',
#   'впервые',
#   'картакарта',
#   'и',
#   'хочет',
#   'открыть',
#   'виртуальную'],
#  ['По', 'картакарта', 'страховка', 'не', 'предусмотрена'],
#  ['Привлечь',
#   'созаемщика',
#   'для',
#   'рассмотрение',
#   'кредитного',
#   'лимита',
#   'не',
#   'предусмотрено'],
#  ['Это',
#   'время',
#   'в',
#   'течение',
#   'которого',
#   'вы',
#   'можете',
#   'пользоваться',
#   'деньгами',
#   'со',
#   'своей',
#   'кредитной',
#   'карты',
#   'и',
#   'не',
#   'платить',
#   'проценты'],
#  ['Зафиксируем', 'обращение'],
#  ['Оплата',
#   'мобильной',
#   'связи',
#   'коммунальные',
#   'платежи',
#   'образование',
#   'интернет',
#   'TV',
#   'транспорт',
#   'и',
#   'билеты'],
#  ['Объединить',
#   'кэшбэк',
#   'по',
#   'стандартным',
#   'картам',
#   'и',
#   'по',
#   'кредитной',
#   'карте',
#   'для',
#   'быстрого',
#   'накопления',
#   'невозможно'],
#  ['На', 'оплаты', 'по', 'рассрочке', 'кэшбэк', 'не', 'начисляется'],
#  ['Клиент',
#   'может',
#   'подать',
#   'заявку',
#   'на',
#   'увеличение',
#   'кредитного',
#   'лимита',
#   'в',
#   'мобильном',
#   'приложении',
#   'доступно',
#   'раз',
#   'в',
#   '30',
#   'дней',
#   'скоринговая',
#   'система',
#   'будет',
#   'решать',
#   'сумму',
#   'кредитного',
#   'лимита'],
#  ['Тип', 'пластика', 'у', 'IronCard', 'Visa', 'Infinite'],
#  ['IronCard', 'является', 'дебетовой', 'картой'],
#  ['Счет',
#   'для',
#   'IronCard',
#   'ведется',
#   'в',
#   'KZT',
#   'основной',
#   'счет',
#   'USD',
#   'EUR',
#   'RUB'],
#  ['Для',
#   'резидентов',
#   'РК',
#   'стоимость',
#   'выпуска',
#   'составляет',
#   '30',
#   '000',
#   'тенге',
#   'для',
#   'нерезидентов',
#   'РК',
#   '100',
#   '000',
#   'тенге',
#   'Гравировка',
#   'индивидуального',
#   'изображения',
#   'стоит',
#   '5',
#   '000',
#   'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'IronCard', 'невозможен'],
#  ['Перевыпуск',
#   'карты',
#   'по',
#   'истечении',
#   'срока',
#   'действия',
#   '0',
#   'тенге',
#   'по',
#   'просьбе',
#   'клиента',
#   'или',
#   'при',
#   'утере',
#   '80',
#   '000',
#   'тенге',
#   'по',
#   'инициативе',
#   'банка',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'IronCard',
#   'составляет',
#   '10',
#   '000',
#   'KZT',
#   'ежемесячно'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'IronCard',
#   'составляет',
#   '8',
#   'лет'],
#  ['Кредиты', 'для', 'карты', 'IronCard', 'не', 'предусмотрены'],
#  ['Карту', 'IronCard', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Тип', 'пластика', 'у', 'Travel', 'Card', 'Visa', 'Signature'],
#  ['Travel', 'Card', 'является', 'дебетовой', 'картой'],
#  ['Счет',
#   'для',
#   'Travel',
#   'Card',
#   'ведется',
#   'в',
#   'KZT',
#   'основной',
#   'счет',
#   'USD',
#   'EUR',
#   'RUB'],
#  ['Для',
#   'резидентов',
#   'РК',
#   'стоимость',
#   'выпуска',
#   'составляет',
#   '10',
#   '000',
#   'KZT',
#   'для',
#   'нерезидентов',
#   'РК',
#   '50',
#   '000',
#   'KZT'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'Travel', 'Card', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'Travel',
#   'Card',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'Travel',
#   'Card',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'Travel',
#   'Card',
#   'составляет',
#   '8',
#   'лет'],
#  ['Кредиты', 'для', 'карты', 'Travel', 'Card', 'не', 'предусмотрены'],
#  ['Карту', 'Travel', 'Card', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Тип', 'пластика', 'у', 'ҮлкенгеҚұрмет', 'Visa', 'Gold'],
#  ['ҮлкенгеҚұрмет', 'является', 'дебетовой', 'картой'],
#  ['Валюта', 'ведения', 'счета', 'для', 'ҮлкенгеҚұрмет', 'Тенге'],
#  ['Стоимость', 'выпуска', 'карты', 'ҮлкенгеҚұрмет', '0', 'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'ҮлкенгеҚұрмет', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'составляет',
#   '3',
#   'года'],
#  ['Кредиты', 'для', 'карты', 'ҮлкенгеҚұрмет', 'не', 'предусмотрены'],
#  ['Карту', 'ҮлкенгеҚұрмет', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Пенсионная',
#   'карта',
#   'принимается',
#   'в',
#   'более',
#   'чем',
#   '2',
#   'миллионах',
#   'банкоматов',
#   'по',
#   'всему',
#   'миру'],
#  ['Вы',
#   'можете',
#   'снимать',
#   'деньги',
#   'с',
#   'Пенсионной',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'в',
#   'банкоматах',
#   'других',
#   'банков',
#   'до',
#   '1',
#   '500',
#   '000',
#   'тенге',
#   'в',
#   'месяц',
#   'бесплатно',
#   'За',
#   'суммы',
#   'свыше',
#   'этого',
#   'взимается',
#   'комиссия',
#   '1',
#   'от',
#   'суммы',
#   'снятия'],
#  ['При',
#   'снятии',
#   'денег',
#   'с',
#   'Пенсионной',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'в',
#   'банкоматах',
#   'за',
#   'пределами',
#   'Казахстана',
#   'действуют',
#   'те',
#   'же',
#   'условия',
#   'до',
#   '1',
#   '500',
#   '000',
#   'тенге',
#   'в',
#   'месяц',
#   'без',
#   'комиссии',
#   'сверх',
#   'этого',
#   'комиссия',
#   '1',
#   'от',
#   'суммы'],
#  ['Вы',
#   'можете',
#   'снимать',
#   'деньги',
#   'в',
#   'другой',
#   'валюте',
#   'с',
#   'вашей',
#   'Пенсионной',
#   'карты',
#   'ҮлкенгеҚұрмет'],
#  ['Пенсионная',
#   'карта',
#   'ҮлкенгеҚұрмет',
#   'предназначена',
#   'для',
#   'получения',
#   'пенсионных',
#   'выплат',
#   'осуществляемых',
#   'через',
#   'единый',
#   'накопительный',
#   'пенсионный',
#   'фонд'],
#  ['Преимущества',
#   'включают',
#   'автоматическую',
#   'передачу',
#   'реквизитов',
#   'в',
#   'ЦОН',
#   'для',
#   'экономии',
#   'времени',
#   'cashback',
#   '3',
#   'за',
#   'покупки',
#   'в',
#   'аптеках',
#   'и',
#   '2',
#   'за',
#   'продукты',
#   'питания',
#   'а',
#   'также',
#   'бесплатную',
#   'услугу',
#   'смс-информирования',
#   'о',
#   'поступлении',
#   'пенсии',
#   'на',
#   'карту'],
#  ['Выпуск',
#   'Пенсионной',
#   'карты',
#   'через',
#   'отделение',
#   'банка',
#   'занимает',
#   'всего',
#   '10',
#   'минут',
#   'так',
#   'как',
#   'карта',
#   'является',
#   'мгновенной'],
#  ['Ознакомиться',
#   'с',
#   'тарифами',
#   'по',
#   'Пенсионной',
#   'карте',
#   'можно',
#   'на',
#   'официальном',
#   'сайте',
#   'Банка'],
#  ['В',
#   'таком',
#   'случае',
#   'необходимо',
#   'обратиться',
#   'в',
#   'ЦОН',
#   'по',
#   'номеру',
#   '1414',
#   'для',
#   'выяснения',
#   'статуса',
#   'выплаты'],
#  ['Пенсия', 'выплачивается', 'ежемесячно', 'с', '1-го', 'по', '15-е', 'число'],
#  ['Даже',
#   'при',
#   'наличии',
#   'арестованных',
#   'счетов',
#   'и',
#   'статуса',
#   'бездействующего',
#   'налогоплательщика',
#   'вам',
#   'будет',
#   'открыта',
#   'Пенсионная',
#   'карта'],
#  ['Для',
#   'открытия',
#   'Пенсионной',
#   'карты',
#   'требуется',
#   'документ',
#   'удостоверяющий',
#   'личность'],
#  ['О',
#   'поступлении',
#   'пенсии',
#   'на',
#   'счет',
#   'вам',
#   'придет',
#   'СМС-сообщение',
#   'или',
#   'вы',
#   'можете',
#   'проверить',
#   'это',
#   'через',
#   'мобильное',
#   'приложение',
#   'BCC.KZ'],
#  ['Получить',
#   'номер',
#   'счета/IBAN',
#   'можно',
#   'через',
#   'мобильное',
#   'приложение',
#   'BCC.KZ',
#   'выбрав',
#   'Пенсионную',
#   'карту',
#   'и',
#   'перейдя',
#   'во',
#   'вкладку',
#   'Информация',
#   'либо',
#   'через',
#   'отделение',
#   'Банка'],
#  ['Пополнить',
#   'Пенсионную',
#   'карту',
#   'можно',
#   'через',
#   'банкомат',
#   'с',
#   'функцией',
#   'cash-in',
#   'платежный',
#   'терминал',
#   'перевод',
#   'на',
#   'карту',
#   'кассу',
#   'и',
#   'другие',
#   'способы'],
#  ['Кэшбек',
#   'начисляется',
#   'за',
#   'покупки',
#   'в',
#   'аптеках',
#   '3',
#   'и',
#   'за',
#   'продукты',
#   'питания',
#   '2'],
#  ['Кэшбек',
#   'будет',
#   'начислен',
#   'на',
#   'вашу',
#   'Пенсионную',
#   'карту',
#   'и',
#   'вы',
#   'можете',
#   'контролировать',
#   'информацию',
#   'о',
#   'нем',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['Перевыпуск', 'Пенсионной', 'карты', 'осуществляется', 'бесплатно'],
#  ['Тип', 'пластика', 'у', 'JuniorBank', 'Visa', 'Gold'],
#  ['JuniorBank', 'является', 'дебетовой', 'картой'],
#  ['Валюта', 'ведения', 'счета', 'для', 'JuniorBank', 'Тенге'],
#  ['Стоимость', 'выпуска', 'карты', 'JuniorBank', '0', 'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'JuniorBank', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'JuniorBank',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'JuniorBank',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'JuniorBank',
#   'составляет',
#   '8',
#   'лет'],
#  ['Кредиты', 'для', 'карты', 'JuniorBank', 'не', 'предусмотрены'],
#  ['Карту', 'JuniorBank', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Карта',
#   'Junior',
#   'представляет',
#   'собой',
#   'детскую',
#   'банковскую',
#   'карту',
#   'доступную',
#   'в',
#   'двух',
#   'форматах',
#   'виртуальная',
#   'карта',
#   'выпускаемая',
#   'дистанционно',
#   'через',
#   'приложение',
#   'BCC.KZ',
#   'родителем',
#   'и',
#   'пластиковая',
#   'карта',
#   'мгновенного',
#   'выпуска',
#   'оформляемая',
#   'в',
#   'любом',
#   'отделении',
#   'банка',
#   'Оба',
#   'вида',
#   'карт',
#   'позволяют',
#   'оплачивать',
#   'покупки',
#   'совершать',
#   'платежи',
#   'и',
#   'переводы',
#   'а',
#   'также',
#   'снимать',
#   'деньги',
#   'в',
#   'специальных',
#   'банкоматах'],
#  ['Кэшбек',
#   'представляет',
#   'собой',
#   'возврат',
#   'определенного',
#   'процента',
#   'от',
#   'суммы',
#   'совершенной',
#   'покупки',
#   'по',
#   'карте',
#   'который',
#   'зачисляется',
#   'обратно',
#   'на',
#   'счет',
#   'карты'],
#  ['Ребенок',
#   'имеет',
#   'возможность',
#   'самостоятельно',
#   'осуществлять',
#   'переводы',
#   'денег',
#   'с',
#   'карты',
#   'на',
#   'карту',
#   'через',
#   'Junior',
#   'Bank',
#   'используя',
#   'как',
#   'номер',
#   'телефона',
#   'так',
#   'и',
#   'номер',
#   'карты'],
#  ['Карту',
#   'Junior',
#   'может',
#   'выпустить',
#   'любой',
#   'клиент',
#   'банка',
#   'у',
#   'которого',
#   'уже',
#   'есть',
#   'какая-либо',
#   'карта',
#   'БЦК'],
#  ['Клиент',
#   'банка',
#   'может',
#   'выпустить',
#   'Карту',
#   'Junior',
#   'не',
#   'только',
#   'для',
#   'своих',
#   'детей',
#   'но',
#   'и',
#   'для',
#   'племянников',
#   'внуков',
#   'братьев',
#   'и',
#   'сестер',
#   'позволяя',
#   'например',
#   'бабушке',
#   'оформить',
#   'карту',
#   'для',
#   'внука',
#   'или',
#   'дяде',
#   'для',
#   'племянника'],
#  ['Карта',
#   'Junior',
#   'предназначена',
#   'для',
#   'детей',
#   'в',
#   'возрасте',
#   'от',
#   '6',
#   'до',
#   '18',
#   'лет'],
#  ['Выпуск',
#   'и',
#   'обслуживание',
#   'карты',
#   'Junior',
#   'осуществляется',
#   'бесплатно',
#   'также',
#   'как',
#   'и',
#   'предоставление',
#   'СМС/ПУШ-уведомлений',
#   'как',
#   'для',
#   'ребенка',
#   'так',
#   'и',
#   'для',
#   'родителя'],
#  ['После',
#   'выпуска',
#   'виртуальной',
#   'карты',
#   'родителем/клиентом',
#   'на',
#   'сотовый',
#   'номер',
#   'ребенка',
#   'отправляется',
#   'СМС-сообщение',
#   'со',
#   'ссылкой',
#   'на',
#   'скачивание',
#   'мобильного',
#   'приложения',
#   'Junior',
#   'Bank',
#   'Ребенок',
#   'должен',
#   'скачать',
#   'приложение',
#   'зарегистрироваться',
#   'в',
#   'нем',
#   'используя',
#   'свой',
#   'номер',
#   'телефона',
#   'подтвердить',
#   'действие',
#   'датой',
#   'рождения',
#   'и',
#   'создать',
#   'пароль',
#   'для',
#   'доступа',
#   'в',
#   'приложение'],
#  ['Для',
#   'осуществления',
#   'платежей',
#   'с',
#   'помощью',
#   'смартфона',
#   'ребенок',
#   'должен',
#   'использовать',
#   'телефоны',
#   'iPhone',
#   'или',
#   'Samsung',
#   'с',
#   'поддержкой',
#   'NFC',
#   'Реквизиты',
#   'карты',
#   'можно',
#   'запросить',
#   'в',
#   'приложении',
#   'Junior',
#   'Bank',
#   'и',
#   'добавить',
#   'в',
#   'электронные',
#   'кошельки',
#   'Apple',
#   'Pay',
#   'iPhone',
#   'или',
#   'Samsung',
#   'Pay',
#   'Samsung'],
#  ['Ребенок',
#   'имеет',
#   'возможность',
#   'использовать',
#   'как',
#   'виртуальную',
#   'так',
#   'и',
#   'пластиковую',
#   'карту',
#   'поскольку',
#   'обе',
#   'карты',
#   'связаны',
#   'с',
#   'одним',
#   'и',
#   'тем',
#   'же',
#   'счетом',
#   'и',
#   'баланс',
#   'на',
#   'них',
#   'будет',
#   'единым'],
#  ['Нет',
#   'необходимости',
#   'закрывать',
#   'виртуальную',
#   'карту',
#   'при',
#   'выпуске',
#   'пластиковой',
#   'так',
#   'как',
#   'ребенок',
#   'может',
#   'пользоваться',
#   'обоими',
#   'картами',
#   'для',
#   'различных',
#   'целей',
#   'виртуальной',
#   'для',
#   'оплаты',
#   'через',
#   'Apple',
#   'Pay/Samsung',
#   'Pay',
#   'и',
#   'пластиковой',
#   'для',
#   'традиционных',
#   'покупок'],
#  ['Отсутствует',
#   'необходимость',
#   'в',
#   'открытии',
#   'виртуальной',
#   'карты',
#   'если',
#   'ребенок',
#   'уже',
#   'пользуется',
#   'пластиковой',
#   'картой',
#   'Junior',
#   'Однако',
#   'для',
#   'привязки',
#   'карты',
#   'к',
#   'Apple',
#   'Pay/Samsung',
#   'Pay',
#   'можно',
#   'добавить',
#   'реквизиты',
#   'пластиковой',
#   'карты',
#   'в',
#   'соответствующие',
#   'электронные',
#   'кошельки'],
#  ['Мобильное',
#   'приложение',
#   'Junior',
#   'Bank',
#   'предоставляет',
#   'ребенку',
#   'информацию',
#   'о',
#   'его',
#   'карте',
#   'доступных',
#   'средствах',
#   'истории',
#   'покупок',
#   'заработанном',
#   'кешбэке',
#   'а',
#   'также',
#   'ожидаемых',
#   'функциях',
#   'таких',
#   'как',
#   'платежи',
#   'переводы',
#   'и',
#   'выбор',
#   'любимых',
#   'категорий'],
#  ['Ребенок',
#   'имеет',
#   'доступ',
#   'только',
#   'к',
#   'информации',
#   'о',
#   'своей',
#   'карте',
#   'и',
#   'доступных',
#   'на',
#   'ней',
#   'средствах',
#   'не',
#   'видя',
#   'данных',
#   'о',
#   'карте',
#   'родителя/клиента'],
#  ['Родитель/клиент',
#   'может',
#   'видеть',
#   'карту',
#   'ребенка',
#   'и',
#   'операции',
#   'совершенные',
#   'по',
#   'ней',
#   'в',
#   'своем',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['При',
#   'совершении',
#   'покупок',
#   'по',
#   'карте',
#   'Junior',
#   'начисляется',
#   'гарантированный',
#   'кэшбэк',
#   'в',
#   'размере',
#   '1',
#   'на',
#   'любую',
#   'сумму',
#   'покупки',
#   'даже',
#   'на',
#   'минимальную',
#   'в',
#   '10',
#   'тенге',
#   'при',
#   'этом',
#   'максимальная',
#   'сумма',
#   'кэшбэка',
#   'в',
#   'месяц',
#   'составляет',
#   '10',
#   '000',
#   'тенге'],
#  ['Родитель',
#   'не',
#   'имеет',
#   'возможности',
#   'совершать',
#   'платежи',
#   'снимать',
#   'деньги',
#   'или',
#   'переводить',
#   'средства',
#   'с',
#   'детской',
#   'карты',
#   'обратно',
#   'на',
#   'свою'],
#  ['Детские',
#   'карты',
#   'обладают',
#   'автоматическими',
#   'ограничениями',
#   'предотвращающими',
#   'их',
#   'использование',
#   'в',
#   'торговых',
#   'точках',
#   'категории',
#   '18',
#   'таких',
#   'как',
#   'табачные',
#   'лавки',
#   'алкомаркеты',
#   'религиозные',
#   'магазины',
#   'казино',
#   'коммерческие',
#   'спортивные',
#   'организации',
#   'аренда',
#   'автомобилей',
#   'и',
#   'прочее'],
#  ['Родители',
#   'имеют',
#   'возможность',
#   'управления',
#   'картой',
#   'ребенка',
#   'посредством',
#   'различных',
#   'функций',
#   'Они',
#   'могут',
#   'блокировать',
#   'или',
#   'разблокировать',
#   'карту',
#   'в',
#   'случае',
#   'необходимости',
#   'Также',
#   'родители',
#   'могут',
#   'настраивать',
#   'лимиты',
#   'трат',
#   'по',
#   'различным',
#   'направлениям',
#   'включая',
#   'снятие',
#   'наличных',
#   'в',
#   'банкоматах',
#   'переводы',
#   'с',
#   'детских',
#   'карт',
#   'на',
#   'другие',
#   'карты',
#   'оплату',
#   'покупок',
#   'и',
#   'покупки',
#   'в',
#   'интернете',
#   'Эти',
#   'лимиты',
#   'могут',
#   'быть',
#   'скорректированы',
#   'как',
#   'в',
#   'сторону',
#   'увеличения',
#   'так',
#   'и',
#   'уменьшения',
#   'Кроме',
#   'того',
#   'родители',
#   'могут',
#   'сбросить',
#   'и',
#   'установить',
#   'новый',
#   'ПИН-код',
#   'для',
#   'карты',
#   'ребенка',
#   'Дополнительно',
#   'предусмотрена',
#   'возможность',
#   'настройки',
#   'смс-уведомлений',
#   'которые',
#   'будут',
#   'поступать',
#   'на',
#   'телефон',
#   'родителя',
#   'о',
#   'действиях',
#   'совершаемых',
#   'с',
#   'детской',
#   'картой'],
#  ['Выпуск',
#   'карты',
#   'для',
#   'детей',
#   'нерезидентов',
#   'осуществим',
#   'при',
#   'условии',
#   'что',
#   'у',
#   'родителя',
#   'или',
#   'законного',
#   'представителя',
#   'ребенка',
#   'имеется',
#   'любая',
#   'карта',
#   'банка',
#   'БЦК',
#   'Это',
#   'предоставляет',
#   'родителям',
#   'возможность',
#   'управления',
#   'финансами',
#   'своих',
#   'детей',
#   'даже',
#   'если',
#   'они',
#   'являются',
#   'нерезидентами'],
#  ['Тип', 'пластика', 'у', 'BCCPAY', 'зарплатная', 'карта', 'Visa', 'Gold'],
#  ['BCCPAY', 'зарплатная', 'карта', 'является', 'дебетовой', 'картой'],
#  ['Валюта',
#   'ведения',
#   'счета',
#   'для',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'Тенге'],
#  ['Стоимость',
#   'выпуска',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   '0',
#   'тенге'],
#  ['Выпуск',
#   'дополнительной',
#   'карты',
#   'для',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'составляет',
#   '3',
#   'года'],
#  ['Кредиты',
#   'для',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'не',
#   'предусмотрены'],
#  ['Карту',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'можно',
#   'использовать',
#   'во',
#   'всем',
#   'мире']]

# %%
[list(TextBlob(x).words) for x in answers]
# Out:
# [['Минимальная', 'сумма', 'открытия', 'составляет', '500,000', 'KZT'],
#  ['Дополнительные', 'взносы', 'не', 'допускаются'],
#  ['По',
#   'истечении',
#   '30',
#   'календарных',
#   'дней',
#   'с',
#   'даты',
#   'подачи',
#   'заявления',
#   'клиента',
#   'возвращение',
#   'выплачивается',
#   'по',
#   'ставке',
#   'вклада',
#   'до',
#   'востребования',
#   'действующего',
#   'на',
#   'дату',
#   'расторжения',
#   'Договора'],
#  ['Ставки',
#   'возвращения',
#   'составляют',
#   '0.1',
#   'в',
#   'тенге',
#   'долларе',
#   'США',
#   'евро',
#   'и',
#   'российском',
#   'рубле'],
#  ['Cтавки',
#   'при',
#   'открытии',
#   'через',
#   'приложение',
#   'BCC.KZ',
#   'для',
#   'срока',
#   'в',
#   '3',
#   '6',
#   'и',
#   '12',
#   'месяцев',
#   'составляют',
#   '17.2',
#   '17.2',
#   'и',
#   '15.7',
#   'соответственно',
#   'При',
#   'открытии',
#   'через',
#   'отделение',
#   'банка',
#   'ставки',
#   'составляют',
#   '16.1',
#   '16.1',
#   'и',
#   '14.6',
#   'соответственно'],
#  ['Вознаграждение',
#   'рассчитывается',
#   'по',
#   'формуле',
#   'сумма',
#   'вклада',
#   'X',
#   'количество',
#   'дней',
#   'начисления',
#   'процентов',
#   'по',
#   'вкладу',
#   'в',
#   'месяце',
#   'X',
#   'номинальная',
#   'процентная',
#   'ставка',
#   '365',
#   'дней',
#   'сумма',
#   'вознаграждения'],
#  ['Вклады',
#   'открытые',
#   'до',
#   '02.12.2020',
#   'года',
#   'продлеваются',
#   'допускается',
#   'Вклады',
#   'открытые',
#   'после',
#   '02.12.2020',
#   'года',
#   'автоматически',
#   'переоформляются',
#   'на',
#   'вклад',
#   '«',
#   'Чемпион',
#   '»',
#   'со',
#   'сроком',
#   'размещения',
#   '13',
#   'месяцев'],
#  ['Частичное', 'изъятие', 'не', 'допускается'],
#  ['Капитализация', 'происходит', '1-го', 'числа', 'каждого', 'месяца'],
#  ['Минимальная',
#   'сумма',
#   'для',
#   'досрочного',
#   'расторжения',
#   'составляет',
#   '500',
#   'в',
#   'тенге',
#   '10',
#   'в',
#   'долларах',
#   'США',
#   '15',
#   'в',
#   'евро'],
#  ['Минимальная',
#   'сумма',
#   'открытия',
#   'составляет',
#   '1',
#   '000',
#   'KZT/RUB',
#   '10',
#   'USD/EUR'],
#  ['Да', 'дополнительные', 'взносы', 'допускаются'],
#  ['Частичное',
#   'изъятие',
#   'разрешено',
#   'без',
#   'ограничений',
#   'но',
#   'соблюдая',
#   'минимальный',
#   'неснижаемый',
#   'остаток',
#   '1',
#   '000',
#   'KZT/RUB',
#   '10',
#   'USD/EUR'],
#  ['Досрочное',
#   'расторжение',
#   'возможно',
#   'День',
#   'в',
#   'день',
#   'то',
#   'есть',
#   'возвращение',
#   'вклада',
#   'в',
#   'день',
#   'подачи',
#   'заявления',
#   'на',
#   'расторжение'],
#  ['Вознаграждение',
#   'вычисляется',
#   'исходя',
#   'из',
#   'фактического',
#   'периода',
#   'размещения',
#   'денег',
#   'на',
#   'вкладе',
#   'без',
#   'пересчета',
#   'ранее',
#   'выплаченного',
#   'вознаграждения'],
#  ['Пролонгация',
#   'возможна',
#   'от',
#   '13',
#   'до',
#   '24',
#   'месяцев',
#   'но',
#   'не',
#   'более',
#   '2-х',
#   'раз'],
#  ['Капитализация',
#   'происходит',
#   'ежемесячно',
#   '1-го',
#   'числа',
#   'каждого',
#   'месяца'],
#  ['Ставки',
#   'составляют',
#   '14',
#   'и',
#   '8.65',
#   'в',
#   'тенге',
#   '0.75',
#   'и',
#   '0.75',
#   'в',
#   'долларе',
#   'США',
#   '0.1',
#   'и',
#   '0.1',
#   'в',
#   'евро',
#   '0.1',
#   'и',
#   '0.1',
#   'в',
#   'российском',
#   'рубле',
#   'соответственно',
#   'для',
#   'сроков',
#   'в',
#   '13',
#   'и',
#   '24',
#   'месяца'],
#  ['Да',
#   'ставки',
#   'при',
#   'открытии',
#   'через',
#   'приложение',
#   'на',
#   '13',
#   'и',
#   '24',
#   'месяца',
#   'чуть',
#   'выше',
#   '14',
#   'и',
#   '8.65',
#   'в',
#   'тенге',
#   'по',
#   'сравнению',
#   'с',
#   'открытием',
#   'через',
#   'отделение',
#   'банка',
#   '13.1',
#   'и',
#   '7.7',
#   'в',
#   'тенге',
#   'Эффективные',
#   'ставки',
#   'также',
#   'немного',
#   'выше',
#   'при',
#   'открытии',
#   'через',
#   'приложение'],
#  ['Вознаграждение',
#   'рассчитывается',
#   'по',
#   'формуле',
#   'сумма',
#   'вклада',
#   'X',
#   'количество',
#   'дней',
#   'начисления',
#   'процентов',
#   'по',
#   'вкладу',
#   'в',
#   'месяце',
#   'X',
#   'номинальная',
#   'процентная',
#   'ставка',
#   '365',
#   'дней',
#   'сумма',
#   'вознаграждения'],
#  ['Минимальная', 'сумма', 'открытия', 'составляет', '1', 'KZT'],
#  ['Да', 'дополнительные', 'взносы', 'допускаются'],
#  ['Частичное', 'снятие', 'не', 'допускается'],
#  ['Досрочное',
#   'расторжение',
#   'возможно',
#   'День',
#   'в',
#   'день',
#   'Если',
#   'расторжение',
#   'договора',
#   'происходит',
#   'до',
#   'истечения',
#   'одного',
#   'месяца',
#   'с',
#   'даты',
#   'зачисления',
#   'первой',
#   'суммы',
#   'вклада',
#   'на',
#   'счет',
#   'вознаграждение',
#   'не',
#   'начисляется',
#   'При',
#   'расторжении',
#   'договора',
#   'после',
#   'истечения',
#   'более',
#   'одного',
#   'месяца',
#   'с',
#   'даты',
#   'зачисления',
#   'первой',
#   'суммы',
#   'вклада',
#   'на',
#   'счет',
#   'удерживается',
#   'штраф',
#   'в',
#   'размере',
#   '50',
#   'от',
#   'начисленного',
#   'вознаграждения'],
#  ['Да',
#   'по',
#   'вкладам',
#   '«',
#   'Моя',
#   'цель',
#   '»',
#   'предусмотрено',
#   'неограниченное',
#   'количество',
#   'пролонгаций'],
#  ['Капитализация',
#   'происходит',
#   'ежемесячно',
#   '1-го',
#   'числа',
#   'каждого',
#   'месяца'],
#  ['Ставки',
#   'в',
#   'тенге',
#   'составляют',
#   '14.9',
#   'для',
#   'сроков',
#   'в',
#   '3',
#   'и',
#   '6',
#   'месяцев',
#   'и',
#   '12.9',
#   'для',
#   'срока',
#   'в',
#   '12',
#   'месяцев'],
#  ['Вознаграждение',
#   'рассчитывается',
#   'по',
#   'формуле',
#   'сумма',
#   'вклада',
#   'X',
#   'количество',
#   'дней',
#   'начисления',
#   'процентов',
#   'по',
#   'вкладу',
#   'в',
#   'месяце',
#   'X',
#   'номинальная',
#   'процентная',
#   'ставка',
#   '365',
#   'дней',
#   'сумма',
#   'вознаграждения'],
#  ['Проценты',
#   'начисляется',
#   'даже',
#   'если',
#   'на',
#   'депозит',
#   'наложен',
#   'арест',
#   'Вы',
#   'сможете',
#   'воспользоваться',
#   'своим',
#   'депозитом',
#   'и',
#   'начисленными',
#   'процентами',
#   'как',
#   'только',
#   'арест',
#   'будет',
#   'снят'],
#  ['Для',
#   'того',
#   'чтобы',
#   'унаследовать',
#   'вклад',
#   'нужно',
#   'обратиться',
#   'в',
#   'ближайшее',
#   'отделении',
#   'Банка',
#   'при',
#   'себе',
#   'иметь',
#   'Нотариально',
#   'удостоверенная',
#   'копия',
#   'свидетельства',
#   'о',
#   'праве',
#   'наследование',
#   'счетом',
#   'по',
#   'закону',
#   'и',
#   'нотариально',
#   'заверенная',
#   'копия',
#   'свидетельства',
#   'о',
#   'смерти',
#   'Вкладчика',
#   'Уведомление',
#   'о',
#   'смерти',
#   'Вкладчика',
#   'с',
#   'ЦОН-а'],
#  ['Вам',
#   'необходимо',
#   'выдать',
#   'доверенность',
#   'с',
#   'указанием',
#   'какие',
#   'именно',
#   'действия',
#   'по',
#   'депозиту',
#   'вы',
#   'доверяете',
#   'совершать',
#   'родственнику',
#   'Доверенность',
#   'может',
#   'быть',
#   'оформлена',
#   'у',
#   'нотариуса',
#   'или',
#   'консула',
#   'от',
#   'имени',
#   'РК',
#   'При',
#   'обслуживании',
#   'вашему',
#   'родственнику',
#   'всегда',
#   'необходимо',
#   'будет',
#   'предоставлять',
#   'оригинал',
#   'доверенности',
#   'и',
#   'документ',
#   'удостоверяющий',
#   'его',
#   'личность'],
#  ['Так',
#   'как',
#   'дата',
#   'окончания',
#   'выпадает',
#   'не',
#   'на',
#   'будний',
#   'день',
#   'у',
#   'Вас',
#   'будет',
#   'возможность',
#   'закрыть',
#   'вклад',
#   'на',
#   'следующий',
#   'рабочий',
#   'день',
#   'При',
#   'себе',
#   'необходимо',
#   'иметь',
#   'документ',
#   'удостоверяющий',
#   'личность'],
#  ['Вклад',
#   'автоматически',
#   'пролонгируется',
#   'по',
#   'ставке',
#   'действующей',
#   'на',
#   'момент',
#   'пролонгации',
#   'Как',
#   'только',
#   'Ваш',
#   'вклад',
#   'будет',
#   'пролонгирован',
#   'Вы',
#   'сможете',
#   'снять',
#   'средства',
#   'с',
#   'депозита',
#   'по',
#   'истечению',
#   'такого',
#   'же',
#   'срока',
#   'либо',
#   'можно',
#   'написать',
#   'заявление',
#   'для',
#   'досрочного',
#   'расторжения',
#   'По',
#   'истечении',
#   '30',
#   'календарных',
#   'дней',
#   'с',
#   'даты',
#   'подачи',
#   'заявления',
#   'вознаграждение',
#   'выплачивается',
#   'по',
#   'ставке',
#   'вклада',
#   '«',
#   'До',
#   'востребования',
#   '»',
#   'действующего',
#   'на',
#   'дату',
#   'расторжения',
#   'Договора',
#   'А',
#   'пролонгация',
#   'по',
#   'депозитам',
#   'открытым',
#   'с',
#   '04.12.2020',
#   'отсутствует',
#   'возможность',
#   'автоматической',
#   'пролонгации',
#   'вклада',
#   'В',
#   'день',
#   'истечения',
#   'срока',
#   'действия',
#   'договора',
#   'предусмотрено',
#   'автоматическое',
#   'переоформление',
#   'на',
#   'депозит',
#   'Чемпион',
#   'со',
#   'сроком',
#   'на',
#   '13',
#   'месяцев'],
#  ['Депозит',
#   'можно',
#   'закрыть',
#   'в',
#   'любом',
#   'отделении',
#   'Банка',
#   'ЦентрКредит',
#   'в',
#   'рабочее',
#   'время',
#   'или',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['Для',
#   'закрытия',
#   'вклада',
#   'при',
#   'себе',
#   'необходимо',
#   'иметь',
#   'удостоверние',
#   'личности',
#   'либо',
#   'паспорт',
#   'РК'],
#  ['Чтобы',
#   'пополнить',
#   'депозит',
#   'необходимо',
#   'ввести',
#   'ИИН',
#   'вкладчика',
#   'и',
#   'последние',
#   '4',
#   'цифры',
#   'счета',
#   'Комиссия',
#   'за',
#   'пополнение',
#   'не',
#   'взимается',
#   'Средства',
#   'поступают',
#   'на',
#   'счет',
#   'в',
#   'течение',
#   '15',
#   'минут',
#   'Максимальная',
#   'сумма',
#   'для',
#   'одного',
#   'терминала',
#   'составляет',
#   '500',
#   '000',
#   'тенге',
#   'при',
#   'этом',
#   'можно',
#   'внести',
#   'не',
#   'более',
#   '40',
#   'купюр'],
#  ['Пополнение',
#   'депозита',
#   'через',
#   'приложение',
#   'BCC.KZ',
#   'осуществляется',
#   'через',
#   'переводы',
#   'между',
#   'своими',
#   'счетами',
#   'Комиссия',
#   'за',
#   'перевод',
#   'не',
#   'взимается',
#   'и',
#   'средства',
#   'поступают',
#   'на',
#   'счет',
#   'моментально'],
#  ['Пополнение',
#   'депозита',
#   'наличными',
#   'через',
#   'кассу',
#   'в',
#   'отделении',
#   'БЦК',
#   'возможно',
#   'без',
#   'комиссии',
#   'Также',
#   'пополнить',
#   'счет',
#   'может',
#   'третье',
#   'лицо'],
#  ['Независимо',
#   'от',
#   'способа',
#   'пополнения',
#   '—',
#   'через',
#   'КАССА',
#   '24',
#   'Cash-in',
#   'банкоматы',
#   'ИПТ',
#   'БЦК',
#   'приложение',
#   'BCC.KZ',
#   'или',
#   'наличными',
#   'через',
#   'кассу',
#   'в',
#   'отделении',
#   '—',
#   'комиссия',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Третье',
#   'лицо',
#   'может',
#   'пополнить',
#   'депозит',
#   'через',
#   'кассу',
#   'в',
#   'отделении',
#   'БЦК',
#   'без',
#   'комиссии'],
#  ['Тип', 'пластика', 'у', 'картакарта', 'Visa', 'Gold'],
#  ['картакарта',
#   'является',
#   'картой',
#   'рассрочки/кредитной',
#   'картой/дебетовой',
#   'картой'],
#  ['Валюта', 'ведения', 'счета', 'для', 'картакарта', 'Тенге'],
#  ['Стоимость', 'выпуска', 'карты', 'картакарта', '0', 'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'картакарта', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'картакарта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'картакарта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'картакарта',
#   'составляет',
#   '5',
#   'лет'],
#  ['Срок',
#   'действия',
#   'договора',
#   'кредитного',
#   'лимита',
#   'для',
#   'картакарта',
#   'составляет',
#   '3',
#   'года'],
#  ['Карту', 'картакарта', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['картакарта',
#   'это',
#   'универсальная',
#   'карта',
#   'с',
#   'кредитным',
#   'лимитом',
#   'которая',
#   'позволяет',
#   'оплачивать',
#   'покупки',
#   'без',
#   'процентов',
#   'в',
#   'льготный',
#   'период',
#   'покупать',
#   'в',
#   'рассрочку',
#   'без',
#   'переплат',
#   'у',
#   'партнеров',
#   'Банка',
#   'и',
#   'зарабатывать',
#   'кешбэк'],
#  ['За',
#   'первую',
#   'покупку',
#   'по',
#   'карте',
#   'мы',
#   'зачислим',
#   'на',
#   'ваш',
#   'кешбэк-счет',
#   'приветственный',
#   'бонус',
#   '10',
#   'от',
#   'суммы',
#   'покупки',
#   'максимум',
#   '1',
#   '000',
#   'Тенге'],
#  ['Оплачивайте',
#   'покупки',
#   'картой',
#   'и',
#   'зарабатывайте',
#   'кешбэк',
#   'до',
#   '30'],
#  ['Кешбэк',
#   'за',
#   'покупки',
#   'по',
#   'карте',
#   '—',
#   'это',
#   'вознаграждение',
#   'от',
#   'Банка',
#   'и',
#   'наших',
#   'партнеров',
#   'за',
#   'использование',
#   'карты',
#   'возвращающее',
#   'определенную',
#   'сумму',
#   'за',
#   'покупки'],
#  ['В',
#   'начале',
#   'каждого',
#   'месяца',
#   'мы',
#   'предлагаем',
#   'новый',
#   'набор',
#   'категорий',
#   'покупок',
#   'с',
#   'кешбэком',
#   'до',
#   '10',
#   'Выбор',
#   'категорий',
#   'можно',
#   'делать',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['Картой', 'можно', 'пользоваться', 'по', 'всему', 'миру'],
#  ['Пополняйте',
#   'карту',
#   'с',
#   'другой',
#   'карты',
#   'или',
#   'счета',
#   'банковским',
#   'переводом',
#   'из',
#   'другого',
#   'банка',
#   'наличными',
#   'через',
#   'банкоматы',
#   'терминалы',
#   'или',
#   'кассу',
#   'Банка',
#   'Пополнение',
#   'карты',
#   'бесплатно'],
#  ['С',
#   'картакарта',
#   'вы',
#   'зарабатываете',
#   'деньги',
#   'когда',
#   'их',
#   'тратите',
#   'Покупайте',
#   'за',
#   'счет',
#   'личных',
#   'денег',
#   'получайте',
#   'кешбэк',
#   'до',
#   '30',
#   'и',
#   'Банк',
#   'может',
#   'пересмотреть',
#   'размер',
#   'лимита'],
#  ['Кредитный',
#   'лимит',
#   'это',
#   'ваша',
#   'личная',
#   'заначка',
#   'когда',
#   'личных',
#   'денег',
#   'на',
#   'покупку',
#   'оказалось',
#   'недостаточно'],
#  ['Вы', 'получите', 'уведомление', 'от', 'Банка'],
#  ['Сначала',
#   'используются',
#   'ваши',
#   'личные',
#   'деньги',
#   'затем',
#   'кредитный',
#   'лимит'],
#  ['Вы',
#   'можете',
#   'включать',
#   'и',
#   'отключать',
#   'режим',
#   'рассрочки',
#   'онлайн',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['В',
#   'сети',
#   'партнеров',
#   'Банка',
#   'предусмотрены',
#   'сроки',
#   'рассрочки',
#   'на',
#   '3',
#   '6',
#   'или',
#   '12',
#   'месяцев',
#   'в',
#   'зависимости',
#   'от',
#   'условий',
#   'договоренности',
#   'с',
#   'партнером'],
#  ['Покупки',
#   'у',
#   'партнеров',
#   'Банка',
#   'осуществляются',
#   'без',
#   'процентов',
#   'и',
#   'комиссий'],
#  ['Покупки',
#   'в',
#   'рассрочку',
#   'возможны',
#   'за',
#   'счет',
#   'кредитного',
#   'лимита'],
#  ['Погашать',
#   'задолженность',
#   'по',
#   'карте',
#   'досрочно',
#   'можно',
#   'в',
#   'любое',
#   'время',
#   'без',
#   'штрафов',
#   'и',
#   'посещения',
#   'Банка',
#   'для',
#   'формирования',
#   'графиков'],
#  ['На',
#   'данный',
#   'момент',
#   'кредитный',
#   'лимит',
#   'устанавливается',
#   'только',
#   'резидентам',
#   'РК',
#   'но',
#   'вы',
#   'можете',
#   'пользоваться',
#   'картой',
#   'за',
#   'счет',
#   'личных',
#   'денег',
#   'и',
#   'получать',
#   'кешбэк',
#   'до',
#   '30'],
#  ['Теперь',
#   'не',
#   'нужно',
#   'закрывать',
#   'виртуальную',
#   'картакарта',
#   'для',
#   'открытия',
#   'физической',
#   'Клиент',
#   'может',
#   'обратиться',
#   'в',
#   'отделение',
#   'Банка',
#   'для',
#   'получения',
#   'пластика',
#   'и',
#   'его',
#   'привязки',
#   'к',
#   'счету',
#   'виртуальной',
#   'картакарта'],
#  ['Согласно',
#   'Заявлению',
#   'к',
#   'Договору',
#   'присоединения',
#   'по',
#   'Кредитным',
#   'карточкам',
#   'заключенному',
#   'между',
#   'Банком',
#   'и',
#   'клиентом',
#   'Банк',
#   'имеет',
#   'право',
#   'без',
#   'дополнительного',
#   'согласия',
#   'клиента',
#   'изменять',
#   'сумму',
#   'кредитного',
#   'лимита',
#   'в',
#   'сторону',
#   'увеличения',
#   'с',
#   'обязательным',
#   'уведомлением',
#   'клиента'],
#  ['В',
#   'мобильном',
#   'приложении',
#   'можно',
#   'подать',
#   'заявку',
#   'на',
#   'увеличение',
#   'кредитного',
#   'лимита',
#   'функционал',
#   'доступен',
#   'раз',
#   'в',
#   '30',
#   'дней',
#   'Лимит',
#   'может',
#   'быть',
#   'увеличен',
#   'до',
#   '7',
#   'миллионов',
#   'тенге'],
#  ['Увеличение',
#   'лимита',
#   'это',
#   'показатель',
#   'доверия',
#   'Банка',
#   'и',
#   'запасные',
#   'деньги',
#   'которые',
#   'всегда',
#   'будут',
#   'под',
#   'рукой'],
#  ['Аннулирование',
#   'только',
#   'кредитного',
#   'лимита',
#   'без',
#   'закрытия',
#   'самой',
#   'картакарта',
#   'невозможно',
#   'Рекомендуется',
#   'рассказать',
#   'о',
#   'преимуществах',
#   'картакарта'],
#  ['Открыть', 'карту', 'можно', 'только', 'в', 'тенге'],
#  ['Можно', 'использовать', 'на', 'любые', 'потребительские', 'цели'],
#  ['Можем', 'рассмотреть', 'без', 'отчислений'],
#  ['Срок', 'действия', 'кэшбека', '1', 'год'],
#  ['Если',
#   'клиент',
#   'открывает',
#   'впервые',
#   'картакарта',
#   'и',
#   'хочет',
#   'открыть',
#   'виртуальную'],
#  ['По', 'картакарта', 'страховка', 'не', 'предусмотрена'],
#  ['Привлечь',
#   'созаемщика',
#   'для',
#   'рассмотрение',
#   'кредитного',
#   'лимита',
#   'не',
#   'предусмотрено'],
#  ['Это',
#   'время',
#   'в',
#   'течение',
#   'которого',
#   'вы',
#   'можете',
#   'пользоваться',
#   'деньгами',
#   'со',
#   'своей',
#   'кредитной',
#   'карты',
#   'и',
#   'не',
#   'платить',
#   'проценты'],
#  ['Зафиксируем', 'обращение'],
#  ['Оплата',
#   'мобильной',
#   'связи',
#   'коммунальные',
#   'платежи',
#   'образование',
#   'интернет',
#   'TV',
#   'транспорт',
#   'и',
#   'билеты'],
#  ['Объединить',
#   'кэшбэк',
#   'по',
#   'стандартным',
#   'картам',
#   'и',
#   'по',
#   'кредитной',
#   'карте',
#   'для',
#   'быстрого',
#   'накопления',
#   'невозможно'],
#  ['На', 'оплаты', 'по', 'рассрочке', 'кэшбэк', 'не', 'начисляется'],
#  ['Клиент',
#   'может',
#   'подать',
#   'заявку',
#   'на',
#   'увеличение',
#   'кредитного',
#   'лимита',
#   'в',
#   'мобильном',
#   'приложении',
#   'доступно',
#   'раз',
#   'в',
#   '30',
#   'дней',
#   'скоринговая',
#   'система',
#   'будет',
#   'решать',
#   'сумму',
#   'кредитного',
#   'лимита'],
#  ['Тип', 'пластика', 'у', 'IronCard', 'Visa', 'Infinite'],
#  ['IronCard', 'является', 'дебетовой', 'картой'],
#  ['Счет',
#   'для',
#   'IronCard',
#   'ведется',
#   'в',
#   'KZT',
#   'основной',
#   'счет',
#   'USD',
#   'EUR',
#   'RUB'],
#  ['Для',
#   'резидентов',
#   'РК',
#   'стоимость',
#   'выпуска',
#   'составляет',
#   '30',
#   '000',
#   'тенге',
#   'для',
#   'нерезидентов',
#   'РК',
#   '100',
#   '000',
#   'тенге',
#   'Гравировка',
#   'индивидуального',
#   'изображения',
#   'стоит',
#   '5',
#   '000',
#   'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'IronCard', 'невозможен'],
#  ['Перевыпуск',
#   'карты',
#   'по',
#   'истечении',
#   'срока',
#   'действия',
#   '0',
#   'тенге',
#   'по',
#   'просьбе',
#   'клиента',
#   'или',
#   'при',
#   'утере',
#   '80',
#   '000',
#   'тенге',
#   'по',
#   'инициативе',
#   'банка',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'IronCard',
#   'составляет',
#   '10',
#   '000',
#   'KZT',
#   'ежемесячно'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'IronCard',
#   'составляет',
#   '8',
#   'лет'],
#  ['Кредиты', 'для', 'карты', 'IronCard', 'не', 'предусмотрены'],
#  ['Карту', 'IronCard', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Тип', 'пластика', 'у', 'Travel', 'Card', 'Visa', 'Signature'],
#  ['Travel', 'Card', 'является', 'дебетовой', 'картой'],
#  ['Счет',
#   'для',
#   'Travel',
#   'Card',
#   'ведется',
#   'в',
#   'KZT',
#   'основной',
#   'счет',
#   'USD',
#   'EUR',
#   'RUB'],
#  ['Для',
#   'резидентов',
#   'РК',
#   'стоимость',
#   'выпуска',
#   'составляет',
#   '10',
#   '000',
#   'KZT',
#   'для',
#   'нерезидентов',
#   'РК',
#   '50',
#   '000',
#   'KZT'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'Travel', 'Card', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'Travel',
#   'Card',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'Travel',
#   'Card',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'Travel',
#   'Card',
#   'составляет',
#   '8',
#   'лет'],
#  ['Кредиты', 'для', 'карты', 'Travel', 'Card', 'не', 'предусмотрены'],
#  ['Карту', 'Travel', 'Card', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Тип', 'пластика', 'у', 'ҮлкенгеҚұрмет', 'Visa', 'Gold'],
#  ['ҮлкенгеҚұрмет', 'является', 'дебетовой', 'картой'],
#  ['Валюта', 'ведения', 'счета', 'для', 'ҮлкенгеҚұрмет', 'Тенге'],
#  ['Стоимость', 'выпуска', 'карты', 'ҮлкенгеҚұрмет', '0', 'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'ҮлкенгеҚұрмет', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'составляет',
#   '3',
#   'года'],
#  ['Кредиты', 'для', 'карты', 'ҮлкенгеҚұрмет', 'не', 'предусмотрены'],
#  ['Карту', 'ҮлкенгеҚұрмет', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Пенсионная',
#   'карта',
#   'принимается',
#   'в',
#   'более',
#   'чем',
#   '2',
#   'миллионах',
#   'банкоматов',
#   'по',
#   'всему',
#   'миру'],
#  ['Вы',
#   'можете',
#   'снимать',
#   'деньги',
#   'с',
#   'Пенсионной',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'в',
#   'банкоматах',
#   'других',
#   'банков',
#   'до',
#   '1',
#   '500',
#   '000',
#   'тенге',
#   'в',
#   'месяц',
#   'бесплатно',
#   'За',
#   'суммы',
#   'свыше',
#   'этого',
#   'взимается',
#   'комиссия',
#   '1',
#   'от',
#   'суммы',
#   'снятия'],
#  ['При',
#   'снятии',
#   'денег',
#   'с',
#   'Пенсионной',
#   'карты',
#   'ҮлкенгеҚұрмет',
#   'в',
#   'банкоматах',
#   'за',
#   'пределами',
#   'Казахстана',
#   'действуют',
#   'те',
#   'же',
#   'условия',
#   'до',
#   '1',
#   '500',
#   '000',
#   'тенге',
#   'в',
#   'месяц',
#   'без',
#   'комиссии',
#   'сверх',
#   'этого',
#   'комиссия',
#   '1',
#   'от',
#   'суммы'],
#  ['Вы',
#   'можете',
#   'снимать',
#   'деньги',
#   'в',
#   'другой',
#   'валюте',
#   'с',
#   'вашей',
#   'Пенсионной',
#   'карты',
#   'ҮлкенгеҚұрмет'],
#  ['Пенсионная',
#   'карта',
#   'ҮлкенгеҚұрмет',
#   'предназначена',
#   'для',
#   'получения',
#   'пенсионных',
#   'выплат',
#   'осуществляемых',
#   'через',
#   'единый',
#   'накопительный',
#   'пенсионный',
#   'фонд'],
#  ['Преимущества',
#   'включают',
#   'автоматическую',
#   'передачу',
#   'реквизитов',
#   'в',
#   'ЦОН',
#   'для',
#   'экономии',
#   'времени',
#   'cashback',
#   '3',
#   'за',
#   'покупки',
#   'в',
#   'аптеках',
#   'и',
#   '2',
#   'за',
#   'продукты',
#   'питания',
#   'а',
#   'также',
#   'бесплатную',
#   'услугу',
#   'смс-информирования',
#   'о',
#   'поступлении',
#   'пенсии',
#   'на',
#   'карту'],
#  ['Выпуск',
#   'Пенсионной',
#   'карты',
#   'через',
#   'отделение',
#   'банка',
#   'занимает',
#   'всего',
#   '10',
#   'минут',
#   'так',
#   'как',
#   'карта',
#   'является',
#   'мгновенной'],
#  ['Ознакомиться',
#   'с',
#   'тарифами',
#   'по',
#   'Пенсионной',
#   'карте',
#   'можно',
#   'на',
#   'официальном',
#   'сайте',
#   'Банка'],
#  ['В',
#   'таком',
#   'случае',
#   'необходимо',
#   'обратиться',
#   'в',
#   'ЦОН',
#   'по',
#   'номеру',
#   '1414',
#   'для',
#   'выяснения',
#   'статуса',
#   'выплаты'],
#  ['Пенсия', 'выплачивается', 'ежемесячно', 'с', '1-го', 'по', '15-е', 'число'],
#  ['Даже',
#   'при',
#   'наличии',
#   'арестованных',
#   'счетов',
#   'и',
#   'статуса',
#   'бездействующего',
#   'налогоплательщика',
#   'вам',
#   'будет',
#   'открыта',
#   'Пенсионная',
#   'карта'],
#  ['Для',
#   'открытия',
#   'Пенсионной',
#   'карты',
#   'требуется',
#   'документ',
#   'удостоверяющий',
#   'личность'],
#  ['О',
#   'поступлении',
#   'пенсии',
#   'на',
#   'счет',
#   'вам',
#   'придет',
#   'СМС-сообщение',
#   'или',
#   'вы',
#   'можете',
#   'проверить',
#   'это',
#   'через',
#   'мобильное',
#   'приложение',
#   'BCC.KZ'],
#  ['Получить',
#   'номер',
#   'счета/IBAN',
#   'можно',
#   'через',
#   'мобильное',
#   'приложение',
#   'BCC.KZ',
#   'выбрав',
#   'Пенсионную',
#   'карту',
#   'и',
#   'перейдя',
#   'во',
#   'вкладку',
#   'Информация',
#   'либо',
#   'через',
#   'отделение',
#   'Банка'],
#  ['Пополнить',
#   'Пенсионную',
#   'карту',
#   'можно',
#   'через',
#   'банкомат',
#   'с',
#   'функцией',
#   'cash-in',
#   'платежный',
#   'терминал',
#   'перевод',
#   'на',
#   'карту',
#   'кассу',
#   'и',
#   'другие',
#   'способы'],
#  ['Кэшбек',
#   'начисляется',
#   'за',
#   'покупки',
#   'в',
#   'аптеках',
#   '3',
#   'и',
#   'за',
#   'продукты',
#   'питания',
#   '2'],
#  ['Кэшбек',
#   'будет',
#   'начислен',
#   'на',
#   'вашу',
#   'Пенсионную',
#   'карту',
#   'и',
#   'вы',
#   'можете',
#   'контролировать',
#   'информацию',
#   'о',
#   'нем',
#   'в',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['Перевыпуск', 'Пенсионной', 'карты', 'осуществляется', 'бесплатно'],
#  ['Тип', 'пластика', 'у', 'JuniorBank', 'Visa', 'Gold'],
#  ['JuniorBank', 'является', 'дебетовой', 'картой'],
#  ['Валюта', 'ведения', 'счета', 'для', 'JuniorBank', 'Тенге'],
#  ['Стоимость', 'выпуска', 'карты', 'JuniorBank', '0', 'тенге'],
#  ['Выпуск', 'дополнительной', 'карты', 'для', 'JuniorBank', 'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'JuniorBank',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'JuniorBank',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'JuniorBank',
#   'составляет',
#   '8',
#   'лет'],
#  ['Кредиты', 'для', 'карты', 'JuniorBank', 'не', 'предусмотрены'],
#  ['Карту', 'JuniorBank', 'можно', 'использовать', 'во', 'всем', 'мире'],
#  ['Карта',
#   'Junior',
#   'представляет',
#   'собой',
#   'детскую',
#   'банковскую',
#   'карту',
#   'доступную',
#   'в',
#   'двух',
#   'форматах',
#   'виртуальная',
#   'карта',
#   'выпускаемая',
#   'дистанционно',
#   'через',
#   'приложение',
#   'BCC.KZ',
#   'родителем',
#   'и',
#   'пластиковая',
#   'карта',
#   'мгновенного',
#   'выпуска',
#   'оформляемая',
#   'в',
#   'любом',
#   'отделении',
#   'банка',
#   'Оба',
#   'вида',
#   'карт',
#   'позволяют',
#   'оплачивать',
#   'покупки',
#   'совершать',
#   'платежи',
#   'и',
#   'переводы',
#   'а',
#   'также',
#   'снимать',
#   'деньги',
#   'в',
#   'специальных',
#   'банкоматах'],
#  ['Кэшбек',
#   'представляет',
#   'собой',
#   'возврат',
#   'определенного',
#   'процента',
#   'от',
#   'суммы',
#   'совершенной',
#   'покупки',
#   'по',
#   'карте',
#   'который',
#   'зачисляется',
#   'обратно',
#   'на',
#   'счет',
#   'карты'],
#  ['Ребенок',
#   'имеет',
#   'возможность',
#   'самостоятельно',
#   'осуществлять',
#   'переводы',
#   'денег',
#   'с',
#   'карты',
#   'на',
#   'карту',
#   'через',
#   'Junior',
#   'Bank',
#   'используя',
#   'как',
#   'номер',
#   'телефона',
#   'так',
#   'и',
#   'номер',
#   'карты'],
#  ['Карту',
#   'Junior',
#   'может',
#   'выпустить',
#   'любой',
#   'клиент',
#   'банка',
#   'у',
#   'которого',
#   'уже',
#   'есть',
#   'какая-либо',
#   'карта',
#   'БЦК'],
#  ['Клиент',
#   'банка',
#   'может',
#   'выпустить',
#   'Карту',
#   'Junior',
#   'не',
#   'только',
#   'для',
#   'своих',
#   'детей',
#   'но',
#   'и',
#   'для',
#   'племянников',
#   'внуков',
#   'братьев',
#   'и',
#   'сестер',
#   'позволяя',
#   'например',
#   'бабушке',
#   'оформить',
#   'карту',
#   'для',
#   'внука',
#   'или',
#   'дяде',
#   'для',
#   'племянника'],
#  ['Карта',
#   'Junior',
#   'предназначена',
#   'для',
#   'детей',
#   'в',
#   'возрасте',
#   'от',
#   '6',
#   'до',
#   '18',
#   'лет'],
#  ['Выпуск',
#   'и',
#   'обслуживание',
#   'карты',
#   'Junior',
#   'осуществляется',
#   'бесплатно',
#   'также',
#   'как',
#   'и',
#   'предоставление',
#   'СМС/ПУШ-уведомлений',
#   'как',
#   'для',
#   'ребенка',
#   'так',
#   'и',
#   'для',
#   'родителя'],
#  ['После',
#   'выпуска',
#   'виртуальной',
#   'карты',
#   'родителем/клиентом',
#   'на',
#   'сотовый',
#   'номер',
#   'ребенка',
#   'отправляется',
#   'СМС-сообщение',
#   'со',
#   'ссылкой',
#   'на',
#   'скачивание',
#   'мобильного',
#   'приложения',
#   'Junior',
#   'Bank',
#   'Ребенок',
#   'должен',
#   'скачать',
#   'приложение',
#   'зарегистрироваться',
#   'в',
#   'нем',
#   'используя',
#   'свой',
#   'номер',
#   'телефона',
#   'подтвердить',
#   'действие',
#   'датой',
#   'рождения',
#   'и',
#   'создать',
#   'пароль',
#   'для',
#   'доступа',
#   'в',
#   'приложение'],
#  ['Для',
#   'осуществления',
#   'платежей',
#   'с',
#   'помощью',
#   'смартфона',
#   'ребенок',
#   'должен',
#   'использовать',
#   'телефоны',
#   'iPhone',
#   'или',
#   'Samsung',
#   'с',
#   'поддержкой',
#   'NFC',
#   'Реквизиты',
#   'карты',
#   'можно',
#   'запросить',
#   'в',
#   'приложении',
#   'Junior',
#   'Bank',
#   'и',
#   'добавить',
#   'в',
#   'электронные',
#   'кошельки',
#   'Apple',
#   'Pay',
#   'iPhone',
#   'или',
#   'Samsung',
#   'Pay',
#   'Samsung'],
#  ['Ребенок',
#   'имеет',
#   'возможность',
#   'использовать',
#   'как',
#   'виртуальную',
#   'так',
#   'и',
#   'пластиковую',
#   'карту',
#   'поскольку',
#   'обе',
#   'карты',
#   'связаны',
#   'с',
#   'одним',
#   'и',
#   'тем',
#   'же',
#   'счетом',
#   'и',
#   'баланс',
#   'на',
#   'них',
#   'будет',
#   'единым'],
#  ['Нет',
#   'необходимости',
#   'закрывать',
#   'виртуальную',
#   'карту',
#   'при',
#   'выпуске',
#   'пластиковой',
#   'так',
#   'как',
#   'ребенок',
#   'может',
#   'пользоваться',
#   'обоими',
#   'картами',
#   'для',
#   'различных',
#   'целей',
#   'виртуальной',
#   'для',
#   'оплаты',
#   'через',
#   'Apple',
#   'Pay/Samsung',
#   'Pay',
#   'и',
#   'пластиковой',
#   'для',
#   'традиционных',
#   'покупок'],
#  ['Отсутствует',
#   'необходимость',
#   'в',
#   'открытии',
#   'виртуальной',
#   'карты',
#   'если',
#   'ребенок',
#   'уже',
#   'пользуется',
#   'пластиковой',
#   'картой',
#   'Junior',
#   'Однако',
#   'для',
#   'привязки',
#   'карты',
#   'к',
#   'Apple',
#   'Pay/Samsung',
#   'Pay',
#   'можно',
#   'добавить',
#   'реквизиты',
#   'пластиковой',
#   'карты',
#   'в',
#   'соответствующие',
#   'электронные',
#   'кошельки'],
#  ['Мобильное',
#   'приложение',
#   'Junior',
#   'Bank',
#   'предоставляет',
#   'ребенку',
#   'информацию',
#   'о',
#   'его',
#   'карте',
#   'доступных',
#   'средствах',
#   'истории',
#   'покупок',
#   'заработанном',
#   'кешбэке',
#   'а',
#   'также',
#   'ожидаемых',
#   'функциях',
#   'таких',
#   'как',
#   'платежи',
#   'переводы',
#   'и',
#   'выбор',
#   'любимых',
#   'категорий'],
#  ['Ребенок',
#   'имеет',
#   'доступ',
#   'только',
#   'к',
#   'информации',
#   'о',
#   'своей',
#   'карте',
#   'и',
#   'доступных',
#   'на',
#   'ней',
#   'средствах',
#   'не',
#   'видя',
#   'данных',
#   'о',
#   'карте',
#   'родителя/клиента'],
#  ['Родитель/клиент',
#   'может',
#   'видеть',
#   'карту',
#   'ребенка',
#   'и',
#   'операции',
#   'совершенные',
#   'по',
#   'ней',
#   'в',
#   'своем',
#   'мобильном',
#   'приложении',
#   'BCC.KZ'],
#  ['При',
#   'совершении',
#   'покупок',
#   'по',
#   'карте',
#   'Junior',
#   'начисляется',
#   'гарантированный',
#   'кэшбэк',
#   'в',
#   'размере',
#   '1',
#   'на',
#   'любую',
#   'сумму',
#   'покупки',
#   'даже',
#   'на',
#   'минимальную',
#   'в',
#   '10',
#   'тенге',
#   'при',
#   'этом',
#   'максимальная',
#   'сумма',
#   'кэшбэка',
#   'в',
#   'месяц',
#   'составляет',
#   '10',
#   '000',
#   'тенге'],
#  ['Родитель',
#   'не',
#   'имеет',
#   'возможности',
#   'совершать',
#   'платежи',
#   'снимать',
#   'деньги',
#   'или',
#   'переводить',
#   'средства',
#   'с',
#   'детской',
#   'карты',
#   'обратно',
#   'на',
#   'свою'],
#  ['Детские',
#   'карты',
#   'обладают',
#   'автоматическими',
#   'ограничениями',
#   'предотвращающими',
#   'их',
#   'использование',
#   'в',
#   'торговых',
#   'точках',
#   'категории',
#   '18',
#   'таких',
#   'как',
#   'табачные',
#   'лавки',
#   'алкомаркеты',
#   'религиозные',
#   'магазины',
#   'казино',
#   'коммерческие',
#   'спортивные',
#   'организации',
#   'аренда',
#   'автомобилей',
#   'и',
#   'прочее'],
#  ['Родители',
#   'имеют',
#   'возможность',
#   'управления',
#   'картой',
#   'ребенка',
#   'посредством',
#   'различных',
#   'функций',
#   'Они',
#   'могут',
#   'блокировать',
#   'или',
#   'разблокировать',
#   'карту',
#   'в',
#   'случае',
#   'необходимости',
#   'Также',
#   'родители',
#   'могут',
#   'настраивать',
#   'лимиты',
#   'трат',
#   'по',
#   'различным',
#   'направлениям',
#   'включая',
#   'снятие',
#   'наличных',
#   'в',
#   'банкоматах',
#   'переводы',
#   'с',
#   'детских',
#   'карт',
#   'на',
#   'другие',
#   'карты',
#   'оплату',
#   'покупок',
#   'и',
#   'покупки',
#   'в',
#   'интернете',
#   'Эти',
#   'лимиты',
#   'могут',
#   'быть',
#   'скорректированы',
#   'как',
#   'в',
#   'сторону',
#   'увеличения',
#   'так',
#   'и',
#   'уменьшения',
#   'Кроме',
#   'того',
#   'родители',
#   'могут',
#   'сбросить',
#   'и',
#   'установить',
#   'новый',
#   'ПИН-код',
#   'для',
#   'карты',
#   'ребенка',
#   'Дополнительно',
#   'предусмотрена',
#   'возможность',
#   'настройки',
#   'смс-уведомлений',
#   'которые',
#   'будут',
#   'поступать',
#   'на',
#   'телефон',
#   'родителя',
#   'о',
#   'действиях',
#   'совершаемых',
#   'с',
#   'детской',
#   'картой'],
#  ['Выпуск',
#   'карты',
#   'для',
#   'детей',
#   'нерезидентов',
#   'осуществим',
#   'при',
#   'условии',
#   'что',
#   'у',
#   'родителя',
#   'или',
#   'законного',
#   'представителя',
#   'ребенка',
#   'имеется',
#   'любая',
#   'карта',
#   'банка',
#   'БЦК',
#   'Это',
#   'предоставляет',
#   'родителям',
#   'возможность',
#   'управления',
#   'финансами',
#   'своих',
#   'детей',
#   'даже',
#   'если',
#   'они',
#   'являются',
#   'нерезидентами'],
#  ['Тип', 'пластика', 'у', 'BCCPAY', 'зарплатная', 'карта', 'Visa', 'Gold'],
#  ['BCCPAY', 'зарплатная', 'карта', 'является', 'дебетовой', 'картой'],
#  ['Валюта',
#   'ведения',
#   'счета',
#   'для',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'Тенге'],
#  ['Стоимость',
#   'выпуска',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   '0',
#   'тенге'],
#  ['Выпуск',
#   'дополнительной',
#   'карты',
#   'для',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'невозможен'],
#  ['Стоимость',
#   'перевыпуска',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Годовое',
#   'обслуживание',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'составляет',
#   '0',
#   'тенге'],
#  ['Срок',
#   'действия',
#   'пластика',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'составляет',
#   '3',
#   'года'],
#  ['Кредиты',
#   'для',
#   'карты',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'не',
#   'предусмотрены'],
#  ['Карту',
#   'BCCPAY',
#   'зарплатная',
#   'карта',
#   'можно',
#   'использовать',
#   'во',
#   'всем',
#   'мире']]

# %% [markdown]
# # START

# %%
import json

# %%
with open('bank_faq.json', encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# {'Депозит': {'Рахмет': [{'вопрос': 'Какова минимальная сумма открытия для депозита "Рахмет" без права пополнения и снятия?',
#     'ответ': 'Минимальная сумма открытия составляет 500,000 KZT.'},
#    {'вопрос': 'Разрешены ли дополнительные взносы для депозита "Рахмет"?',
#     'ответ': 'Дополнительные взносы не допускаются.'},
#    {'вопрос': 'Можно ли осуществить досрочное расторжение депозита "Рахмет"?',
#     'ответ': 'По истечении 30 календарных дней с даты подачи заявления клиента, возвращение выплачивается по ставке вклада до востребования, действующего на дату расторжения Договора.'},
#    {'вопрос': 'Какие сроки и ставки возвращения применяются при досрочном расторжении депозита "Рахмет"?',
#     'ответ': 'Ставки возвращения составляют 0.1% в тенге, долларе США, евро, и российском рубле.'},
#    {'вопрос': 'Есть ли различия в ставках в зависимости от того, через что открывается депозит "Рахмет": через приложение или через отделение банка?',
#     'ответ': 'Cтавки при открытии через приложение BCC.KZ для срока в 3, 6 и 12 месяцев составляют 17.2%, 17.2% и 15.7% соответственно. При открытии через отделение банка ставки составляют 16.1%, 16.1% и 14.6% соответственно.'},
#    {'вопрос': 'Как производится расчет вознаграждения по депозиту "Рахмет"?',
#     'ответ': 'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.'},
#    {'вопрос': 'Продлевается ли вклад "Рахмет" автоматически после окончания срока?',
#     'ответ': 'Вклады, открытые до 02.12.2020 года, продлеваются допускается. Вклады, открытые после 02.12.2020 года, автоматически переоформляются на вклад «Чемпион» со сроком размещения 13 месяцев.'},
#    {'вопрос': 'Допускается ли частичное изъятие средств с депозита "Рахмет"?',
#     'ответ': 'Частичное изъятие не допускается.'},
#    {'вопрос': 'Как часто происходит капитализация по депозиту "Рахмет"?',
#     'ответ': 'Капитализация происходит 1-го числа каждого месяца.'},
#    {'вопрос': 'Какова минимальная сумма для досрочного расторжения депозита "Рахмет"?',
#     'ответ': 'Минимальная сумма для досрочного расторжения составляет 500 в тенге, 10 в долларах США, 15 в евро.'}],
#   'Чемпион': [{'вопрос': 'Какая минимальная сумма открытия для депозита "Чемпион" с правом пополнения и снятия?',
#     'ответ': 'Минимальная сумма открытия составляет 1 000 KZT/RUB, 10 USD/EUR.'},
#    {'вопрос': 'Разрешены ли дополнительные взносы на депозит "Чемпион"?',
#     'ответ': 'Да, дополнительные взносы допускаются.'},
#    {'вопрос': 'Предусмотрено ли частичное изъятие средств с депозита "Чемпион"?',
#     'ответ': 'Частичное изъятие разрешено без ограничений, но соблюдая минимальный неснижаемый остаток (1 000 KZT/RUB, 10 USD/EUR).'},
#    {'вопрос': 'Можно ли провести досрочное расторжение депозита "Чемпион" и как это происходит?',
#     'ответ': 'Досрочное расторжение возможно "День в день", то есть возвращение вклада в день подачи заявления на расторжение.'},
#    {'вопрос': 'Как рассчитывается вознаграждение при досрочном расторжении депозита "Чемпион"?',
#     'ответ': 'Вознаграждение вычисляется исходя из фактического периода размещения денег на вкладе, без пересчета ранее выплаченного вознаграждения.'},
#    {'вопрос': 'Какие условия продления (пролонгации) депозита "Чемпион"?',
#     'ответ': 'Пролонгация возможна от 13 до 24 месяцев, но не более 2-х раз.'},
#    {'вопрос': 'Как часто происходит капитализация по депозиту "Чемпион"?',
#     'ответ': 'Капитализация происходит ежемесячно, 1-го числа каждого месяца.'},
#    {'вопрос': 'Каковы ставки при открытии депозита "Чемпион" через приложение BCC.KZ на 13 и 24 месяца?',
#     'ответ': 'Ставки составляют 14% и 8.65% в тенге, 0.75% и 0.75% в долларе США, 0.1% и 0.1% в евро, 0.1% и 0.1% в российском рубле соответственно для сроков в 13 и 24 месяца.'},
#    {'вопрос': 'Есть ли разница в ставках при открытии депозита "Чемпион" через приложение по сравнению с открытием через отделение банка?',
#     'ответ': 'Да, ставки при открытии через приложение на 13 и 24 месяца чуть выше (14% и 8.65% в тенге) по сравнению с открытием через отделение банка (13.1% и 7.7% в тенге). Эффективные ставки также немного выше при открытии через приложение.'},
#    {'вопрос': 'Как рассчитывается вознаграждение по депозиту "Чемпион"?',
#     'ответ': 'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.'}],
#   'МояЦель': [{'вопрос': 'Какова минимальная сумма открытия для депозита "Моя Цель" с правом пополнения и без права снятия?',
#     'ответ': 'Минимальная сумма открытия составляет 1 KZT.'},
#    {'вопрос': 'Могут ли вноситься дополнительные средства на депозит "Моя Цель" после его открытия?',
#     'ответ': 'Да, дополнительные взносы допускаются.'},
#    {'вопрос': 'Возможно ли частичное снятие с депозита "Моя Цель"?',
#     'ответ': 'Частичное снятие не допускается.'},
#    {'вопрос': 'Каковы условия досрочного расторжения депозита "Моя Цель"?',
#     'ответ': 'Досрочное расторжение возможно "День в день". Если расторжение договора происходит до истечения одного месяца с даты зачисления первой суммы вклада на счет, вознаграждение не начисляется. При расторжении договора после истечения более одного месяца с даты зачисления первой суммы вклада на счет, удерживается штраф в размере 50% от начисленного вознаграждения.'},
#    {'вопрос': 'Предусматривается ли автоматическое продление депозита "Моя Цель"?',
#     'ответ': 'Да, по вкладам «Моя цель» предусмотрено неограниченное количество пролонгаций.'},
#    {'вопрос': 'Как происходит капитализация по депозиту "Моя Цель"?',
#     'ответ': 'Капитализация происходит ежемесячно, 1-го числа каждого месяца.'},
#    {'вопрос': 'Какие ставки предлагаются при открытии депозита "Моя Цель" через приложение BCC.KZ на сроки 3, 6 и 12 месяцев?',
#     'ответ': 'Ставки в тенге составляют 14.9% для сроков в 3 и 6 месяцев и 12.9% для срока в 12 месяцев.'},
#    {'вопрос': 'Как рассчитывается вознаграждение по депозиту "Моя Цель"?',
#     'ответ': 'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.'}],
#   'другое': [{'вопрос': 'Если на мои счета наложен арест, вознаграждения по депозиту будут начисляться?',
#     'ответ': 'Проценты начисляется, даже если на депозит наложен арест. Вы сможете воспользоваться своим депозитом и начисленными процентами, как только арест будет снят.'},
#    {'вопрос': 'У моего родственника был депозит, он умер, что делать?',
#     'ответ': 'Для того чтобы унаследовать вклад, нужно обратиться в ближайшее отделении Банка при себе иметь: Нотариально удостоверенная копия свидетельства о праве наследование счетом по закону и нотариально заверенная копия свидетельства о смерти Вкладчика Уведомление о смерти Вкладчика с ЦОН-а'},
#    {'вопрос': 'Я хочу доверить управление мои депозитом родственнику. Что нужно для этого сделать?',
#     'ответ': 'Вам необходимо выдать доверенность, с указанием, какие именно действия по депозиту вы доверяете совершать родственнику. Доверенность может быть оформлена у нотариуса или консула от имени РК При обслуживании вашему родственнику всегда необходимо будет предоставлять оригинал доверенности и документ, удостоверяющий его личность'},
#    {'вопрос': 'У меня есть депозит Рахмет/Рахмет+ в вашем Банке, и его срок окончания выпадает на выходной/праздничный день, мне нужно его закрыть, что необходимо предпринять?',
#     'ответ': 'Так как дата окончания выпадает не на будний день, у Вас будет возможность закрыть вклад на следующий рабочий день. При себе необходимо иметь документ удостоверяющий личность.'},
#    {'вопрос': 'Что случится, если я не подойду в назначенный срок по закрытию депозита Рахмет/Рахмет+?',
#     'ответ': 'Вклад автоматически пролонгируется, по ставке действующей на момент пролонгации. Как только Ваш вклад будет пролонгирован, Вы сможете снять средства с депозита по истечению такого же срока либо можно написать заявление для досрочного расторжения. По истечении 30 календарных дней с даты подачи заявления, вознаграждение выплачивается по ставке вклада «До востребования», действующего на дату расторжения Договора. А пролонгация по депозитам открытым с 04.12.2020 отсутствует возможность автоматической пролонгации вклада. В день истечения срока действия договора предусмотрено автоматическое переоформление на депозит "Чемпион", со сроком на 13 месяцев.'},
#    {'вопрос': 'Как можно закрыть депозит',
#     'ответ': 'Депозит можно закрыть в любом отделении Банка ЦентрКредит в рабочее время или в мобильном приложении BCC.KZ'},
#    {'вопрос': 'Какие документы чтобы закрыть депозит',
#     'ответ': 'Для закрытия вклада при себе необходимо иметь удостоверние личности либо паспорт РК'},
#    {'вопрос': 'Как можно пополнить депозит через КАССА 24, Cash-in банкоматы и ИПТ БЦК?',
#     'ответ': 'Чтобы пополнить депозит, необходимо ввести ИИН вкладчика и последние 4 цифры счета. Комиссия за пополнение не взимается. Средства поступают на счет в течение 15 минут. Максимальная сумма для одного терминала составляет 500 000 тенге, при этом можно внести не более 40 купюр.'},
#    {'вопрос': 'Каковы условия пополнения депозита через мобильное приложение BCC.KZ?',
#     'ответ': 'Пополнение депозита через приложение BCC.KZ осуществляется через переводы между своими счетами. Комиссия за перевод не взимается, и средства поступают на счет моментально.'},
#    {'вопрос': 'Возможно ли пополнение депозита наличными через кассу в отделении БЦК?',
#     'ответ': 'Пополнение депозита наличными через кассу в отделении БЦК возможно без комиссии. Также пополнить счет может третье лицо.'},
#    {'вопрос': 'Существует ли комиссия за пополнение депозита в БЦК?',
#     'ответ': 'Независимо от способа пополнения — через КАССА 24, Cash-in банкоматы, ИПТ БЦК, приложение BCC.KZ или наличными через кассу в отделении — комиссия составляет 0 тенге.'},
#    {'вопрос': 'Может ли третье лицо пополнить мой депозит?',
#     'ответ': 'Третье лицо может пополнить депозит через кассу в отделении БЦК без комиссии.'}]},
#  'Карта': {'картакарта': [{'вопрос': 'Какой тип/вид пластика у #картакарта?',
#     'ответ': 'Тип пластика у #картакарта - Visa Gold.'},
#    {'вопрос': 'Какой вид карты у #картакарта?',
#     'ответ': '#картакарта является картой рассрочки/кредитной картой/дебетовой картой.'},
#    {'вопрос': 'В какой валюте ведется счет для #картакарта?',
#     'ответ': 'Валюта ведения счета для #картакарта - Тенге.'},
#    {'вопрос': 'Какова стоимость выпуска карты #картакарта?',
#     'ответ': 'Стоимость выпуска карты #картакарта - 0 тенге.'},
#    {'вопрос': 'Возможен ли выпуск дополнительной карты для #картакарта?',
#     'ответ': 'Выпуск дополнительной карты для #картакарта невозможен.'},
#    {'вопрос': 'Какова стоимость перевыпуска карты #картакарта при утере/краже/повреждении пластика?',
#     'ответ': 'Стоимость перевыпуска карты #картакарта составляет 0 тенге.'},
#    {'вопрос': 'Какова стоимость годового обслуживания карты #картакарта?',
#     'ответ': 'Годовое обслуживание карты #картакарта составляет 0 тенге.'},
#    {'вопрос': 'Каков срок действия пластика карты #картакарта?',
#     'ответ': 'Срок действия пластика карты #картакарта составляет 5 лет.'},
#    {'вопрос': 'Каков срок действия договора кредитного лимита для #картакарта?',
#     'ответ': 'Срок действия договора кредитного лимита для #картакарта составляет 3 года.'},
#    {'вопрос': 'Где можно использовать карту #картакарта?',
#     'ответ': 'Карту #картакарта можно использовать во всем мире.'},
#    {'вопрос': 'Что такое #картакарта?',
#     'ответ': '#картакарта - это универсальная карта с кредитным лимитом, которая позволяет оплачивать покупки без процентов в льготный период, покупать в рассрочку без переплат у партнеров Банка и зарабатывать кешбэк.'},
#    {'вопрос': 'Я получу приветственный бонус?',
#     'ответ': 'За первую покупку по карте мы зачислим на ваш кешбэк-счет приветственный бонус - 10% от суммы покупки (максимум 1 000 Тенге).'},
#    {'вопрос': 'Как заработать с #картакарта?',
#     'ответ': 'Оплачивайте покупки картой и зарабатывайте кешбэк до 30%.'},
#    {'вопрос': 'Что такое кешбэк?',
#     'ответ': 'Кешбэк за покупки по карте — это вознаграждение от Банка и наших партнеров за использование карты, возвращающее определенную сумму за покупки.'},
#    {'вопрос': 'Как выбирать любимые категории с повышенным кешбэком?',
#     'ответ': 'В начале каждого месяца мы предлагаем новый набор категорий покупок с кешбэком до 10%. Выбор категорий можно делать в мобильном приложении BCC.KZ.'},
#    {'вопрос': 'Могу ли я расплачиваться картой за границей?',
#     'ответ': 'Картой можно пользоваться по всему миру.'},
#    {'вопрос': 'Как пополнять карту?',
#     'ответ': 'Пополняйте карту с другой карты или счета, банковским переводом из другого банка, наличными через банкоматы, терминалы или кассу Банка. Пополнение карты - бесплатно!'},
#    {'вопрос': 'Что если я получу карту с нулевым кредитным лимитом, что мне с ней делать и дадут ли мне лимит в будущем?',
#     'ответ': 'С #картакарта вы зарабатываете деньги, когда их тратите. Покупайте за счет личных денег, получайте кешбэк до 30%, и Банк может пересмотреть размер лимита.'},
#    {'вопрос': 'Зачем мне нужен кредитный лимит по #картакарта?',
#     'ответ': 'Кредитный лимит - это ваша личная заначка, когда личных денег на покупку оказалось недостаточно.'},
#    {'вопрос': 'Как я узнаю, что мне установили кредитный лимит?',
#     'ответ': 'Вы получите уведомление от Банка.'},
#    {'вопрос': 'Как будут тратиться деньги, если у меня есть и личные деньги и кредитный лимит на карте?',
#     'ответ': 'Сначала используются ваши личные деньги, затем кредитный лимит.'},
#    {'вопрос': 'Как включить и отключить режим рассрочки онлайн в мобильном приложении BCC.KZ?',
#     'ответ': 'Вы можете включать и отключать режим рассрочки онлайн в мобильном приложении BCC.KZ.'},
#    {'вопрос': 'Какие сроки рассрочки предусмотрены по карте?',
#     'ответ': 'В сети партнеров Банка предусмотрены сроки рассрочки на 3, 6 или 12 месяцев в зависимости от условий договоренности с партнером.'},
#    {'вопрос': 'Есть ли комиссия за рассрочку?',
#     'ответ': 'Покупки у партнеров Банка осуществляются без процентов и комиссий.'},
#    {'вопрос': 'Я могу покупать в рассрочку за счет личных денег?',
#     'ответ': 'Покупки в рассрочку возможны за счет кредитного лимита.'},
#    {'вопрос': 'Я могу погашать задолженность по карте досрочно?',
#     'ответ': 'Погашать задолженность по карте досрочно можно в любое время без штрафов и посещения Банка для формирования графиков.'},
#    {'вопрос': 'Я не резидент, я могу получить кредитный лимит по карте?',
#     'ответ': 'На данный момент кредитный лимит устанавливается только резидентам РК, но вы можете пользоваться картой за счет личных денег и получать кешбэк до 30%.'},
#    {'вопрос': 'Как получить виртуальную карту?',
#     'ответ': 'Теперь не нужно закрывать виртуальную #картакарта для открытия физической. Клиент может обратиться в отделение Банка для получения пластика и его привязки к счету виртуальной #картакарта.'},
#    {'вопрос': 'На каком основании Банк увеличивает кредитный лимит без согласия клиента?',
#     'ответ': 'Согласно Заявлению к Договору присоединения (по Кредитным карточкам), заключенному между Банком и клиентом, Банк имеет право без дополнительного согласия клиента изменять сумму кредитного лимита в сторону увеличения, с обязательным уведомлением клиента.'},
#    {'вопрос': 'Я НЕ согласен с маленькой суммой лимита.',
#     'ответ': 'В мобильном приложении можно подать заявку на увеличение кредитного лимита (функционал доступен раз в 30 дней). Лимит может быть увеличен до 7 миллионов тенге.'},
#    {'вопрос': 'Я НЕ согласен с большой суммой лимита!',
#     'ответ': 'Увеличение лимита - это показатель доверия Банка и запасные деньги, которые всегда будут под рукой.'},
#    {'вопрос': 'Что делать, если клиент обращается с просьбой аннулировать (обнулить) кредитный лимит?',
#     'ответ': 'Аннулирование только кредитного лимита без закрытия самой #картакарта невозможно. Рекомендуется рассказать о преимуществах #картакарта.'},
#    {'вопрос': 'Можно ли открыть карту в другой валюте, кроме тенге?',
#     'ответ': 'Открыть карту можно только в тенге.'},
#    {'вопрос': 'Есть ли целевое назначение кредитного лимита?',
#     'ответ': 'Можно использовать на любые потребительские цели.'},
#    {'вопрос': 'Обязательны ли пенсионные отчисления для рассмотрения?',
#     'ответ': 'Можем рассмотреть без отчислений.'},
#    {'вопрос': 'Есть ли срок действия у кэшбека?',
#     'ответ': 'Срок действия кэшбека 1 год.'},
#    {'вопрос': 'Можно ли рассмотреть и выпустить карту онлайн, без посещения отделении?',
#     'ответ': 'Если клиент открывает впервые #картакарта и хочет открыть виртуальную.'},
#    {'вопрос': 'По карте имеется страховка?',
#     'ответ': 'По картакарта страховка не предусмотрена.'},
#    {'вопрос': 'Можно ли привлечь созаемщика для рассмотрение кредитного лимита?',
#     'ответ': 'Привлечь созаемщика для рассмотрение кредитного лимита не предусмотрено.'},
#    {'вопрос': 'Что такое льготный период по карте?',
#     'ответ': 'Это время, в течение которого вы можете пользоваться деньгами со своей кредитной карты и не платить проценты.'},
#    {'вопрос': 'Что делать если КЛ не поступил?',
#     'ответ': 'Зафиксируем обращение.'},
#    {'вопрос': 'За какие платежи мобильного приложения начисляется кэшбэк в BCC.KZ?',
#     'ответ': 'Оплата мобильной связи, коммунальные платежи, образование, интернет, TV, транспорт и билеты.'},
#    {'вопрос': 'Возможно ли объединить кэшбэк по стандартным картам и по кредитной карте для быстрого накопления?',
#     'ответ': 'Объединить кэшбэк по стандартным картам и по кредитной карте для быстрого накопления невозможно.'},
#    {'вопрос': 'Как начисляется кэшбэк при рассрочке?',
#     'ответ': 'На оплаты по рассрочке кэшбэк не начисляется.'},
#    {'вопрос': 'Возможно ли получить кредитный лимит при уже открытой карте без кредитного лимита путем открытия новой карты?',
#     'ответ': 'Клиент может подать заявку на увеличение кредитного лимита в мобильном приложении (доступно раз в 30 дней), скоринговая система будет решать сумму кредитного лимита.'}],
#   'IronCard': [{'вопрос': 'Какой тип/вид пластика у #IronCard?',
#     'ответ': 'Тип пластика у #IronCard - Visa Infinite.'},
#    {'вопрос': 'Какой вид карты у #IronCard?',
#     'ответ': '#IronCard является дебетовой картой.'},
#    {'вопрос': 'В каких валютах ведется счет для #IronCard?',
#     'ответ': 'Счет для #IronCard ведется в KZT (основной счет), USD, EUR, RUB.'},
#    {'вопрос': 'Какова стоимость выпуска карты #IronCard для резидентов и нерезидентов РК?',
#     'ответ': 'Для резидентов РК стоимость выпуска составляет 30 000 тенге, для нерезидентов РК - 100 000 тенге. Гравировка индивидуального изображения стоит 5 000 тенге.'},
#    {'вопрос': 'Возможен ли выпуск дополнительной карты для #IronCard?',
#     'ответ': 'Выпуск дополнительной карты для #IronCard невозможен.'},
#    {'вопрос': 'Какова стоимость перевыпуска карты #IronCard?',
#     'ответ': 'Перевыпуск карты по истечении срока действия - 0 тенге, по просьбе клиента или при утере - 80 000 тенге, по инициативе банка - 0 тенге.'},
#    {'вопрос': 'Какова стоимость годового обслуживания карты #IronCard?',
#     'ответ': 'Годовое обслуживание карты #IronCard составляет 10 000 KZT ежемесячно.'},
#    {'вопрос': 'Каков срок действия пластика карты #IronCard?',
#     'ответ': 'Срок действия пластика карты #IronCard составляет 8 лет.'},
#    {'вопрос': 'Доступны ли кредиты для #IronCard?',
#     'ответ': 'Кредиты для карты #IronCard не предусмотрены.'},
#    {'вопрос': 'Где можно использовать карту #IronCard?',
#     'ответ': 'Карту #IronCard можно использовать во всем мире.'}],
#   'TravelCard': [{'вопрос': 'Какой тип/вид пластика у #Travel Card?',
#     'ответ': 'Тип пластика у #Travel Card - Visa Signature.'},
#    {'вопрос': 'Какой вид карты у #Travel Card?',
#     'ответ': '#Travel Card является дебетовой картой.'},
#    {'вопрос': 'В каких валютах ведется счет для #Travel Card?',
#     'ответ': 'Счет для #Travel Card ведется в KZT (основной счет), USD, EUR, RUB.'},
#    {'вопрос': 'Какова стоимость выпуска карты #Travel Card для резидентов и нерезидентов РК?',
#     'ответ': 'Для резидентов РК стоимость выпуска составляет 10 000 KZT, для нерезидентов РК - 50 000 KZT.'},
#    {'вопрос': 'Возможен ли выпуск дополнительной карты для #Travel Card?',
#     'ответ': 'Выпуск дополнительной карты для #Travel Card невозможен.'},
#    {'вопрос': 'Какова стоимость перевыпуска карты #Travel Card?',
#     'ответ': 'Стоимость перевыпуска карты #Travel Card составляет 0 тенге.'},
#    {'вопрос': 'Какова стоимость годового обслуживания карты #Travel Card?',
#     'ответ': 'Годовое обслуживание карты #Travel Card составляет 0 тенге.'},
#    {'вопрос': 'Каков срок действия пластика карты #Travel Card?',
#     'ответ': 'Срок действия пластика карты #Travel Card составляет 8 лет.'},
#    {'вопрос': 'Доступны ли кредиты для #Travel Card?',
#     'ответ': 'Кредиты для карты #Travel Card не предусмотрены.'},
#    {'вопрос': 'Где можно использовать карту #Travel Card?',
#     'ответ': 'Карту #Travel Card можно использовать во всем мире.'}],
#   'ҮлкенгеҚұрмет': [{'вопрос': 'Какой тип/вид пластика у #ҮлкенгеҚұрмет?',
#     'ответ': 'Тип пластика у #ҮлкенгеҚұрмет - Visa Gold.'},
#    {'вопрос': 'Какой вид карты у #ҮлкенгеҚұрмет?',
#     'ответ': '#ҮлкенгеҚұрмет является дебетовой картой.'},
#    {'вопрос': 'В какой валюте ведется счет для #ҮлкенгеҚұрмет?',
#     'ответ': 'Валюта ведения счета для #ҮлкенгеҚұрмет - Тенге.'},
#    {'вопрос': 'Какова стоимость выпуска карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Стоимость выпуска карты #ҮлкенгеҚұрмет - 0 тенге.'},
#    {'вопрос': 'Возможен ли выпуск дополнительной карты для #ҮлкенгеҚұрмет?',
#     'ответ': 'Выпуск дополнительной карты для #ҮлкенгеҚұрмет невозможен.'},
#    {'вопрос': 'Какова стоимость перевыпуска карты #ҮлкенгеҚұрмет при утере/краже/повреждении пластика?',
#     'ответ': 'Стоимость перевыпуска карты #ҮлкенгеҚұрмет составляет 0 тенге.'},
#    {'вопрос': 'Какова стоимость годового обслуживания карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Годовое обслуживание карты #ҮлкенгеҚұрмет составляет 0 тенге.'},
#    {'вопрос': 'Каков срок действия пластика карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Срок действия пластика карты #ҮлкенгеҚұрмет составляет 3 года.'},
#    {'вопрос': 'Доступны ли кредиты для #ҮлкенгеҚұрмет?',
#     'ответ': 'Кредиты для карты #ҮлкенгеҚұрмет не предусмотрены.'},
#    {'вопрос': 'Где можно использовать карту #ҮлкенгеҚұрмет?',
#     'ответ': 'Карту #ҮлкенгеҚұрмет можно использовать во всем мире.'},
#    {'вопрос': 'Какие банкоматы принимают Пенсионную карту #ҮлкенгеҚұрмет?',
#     'ответ': 'Пенсионная карта принимается в более чем 2 миллионах банкоматов по всему миру.'},
#    {'вопрос': 'Могу ли я снимать деньги с Пенсионной карты #ҮлкенгеҚұрмет в банкомате другого Банка?',
#     'ответ': 'Вы можете снимать деньги с Пенсионной карты #ҮлкенгеҚұрмет в банкоматах других банков до 1 500 000 тенге в месяц бесплатно. За суммы свыше этого взимается комиссия 1% от суммы снятия.'},
#    {'вопрос': 'Взимается ли комиссия при снятии денег с Пенсионной карты в банкоматах за пределами Казахстана?',
#     'ответ': 'При снятии денег с Пенсионной карты #ҮлкенгеҚұрмет в банкоматах за пределами Казахстана действуют те же условия: до 1 500 000 тенге в месяц без комиссии, сверх этого - комиссия 1% от суммы.'},
#    {'вопрос': 'Могу ли я снять деньги в другой валюте с Пенсионной карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Вы можете снимать деньги в другой валюте с вашей Пенсионной карты #ҮлкенгеҚұрмет.'},
#    {'вопрос': 'Для каких целей предназначена Пенсионная карта #ҮлкенгеҚұрмет?',
#     'ответ': 'Пенсионная карта #ҮлкенгеҚұрмет предназначена для получения пенсионных выплат, осуществляемых через единый накопительный пенсионный фонд.'},
#    {'вопрос': 'Какие преимущества у Пенсионной карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Преимущества включают автоматическую передачу реквизитов в ЦОН для экономии времени, cashback 3% за покупки в аптеках и 2% за продукты питания, а также бесплатную услугу смс-информирования о поступлении пенсии на карту.'},
#    {'вопрос': 'Сколько времени занимает выпуск Пенсионной карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Выпуск Пенсионной карты через отделение банка занимает всего 10 минут, так как карта является мгновенной.'},
#    {'вопрос': 'Где я могу ознакомиться с тарифами по Пенсионной карте #ҮлкенгеҚұрмет?',
#     'ответ': 'Ознакомиться с тарифами по Пенсионной карте можно на официальном сайте Банка.'},
#    {'вопрос': 'Что делать, если пенсионная выплата не поступила, несмотря на направленные реквизиты в ЦОН?',
#     'ответ': 'В таком случае необходимо обратиться в ЦОН по номеру 1414 для выяснения статуса выплаты.'},
#    {'вопрос': 'Когда обычно выплачивается пенсия?',
#     'ответ': 'Пенсия выплачивается ежемесячно с 1-го по 15-е число.'},
#    {'вопрос': 'Откроют ли мне Пенсионную карту #ҮлкенгеҚұрмет при наличии арестованных счетов и статуса бездействующего налогоплательщика?',
#     'ответ': 'Даже при наличии арестованных счетов и статуса бездействующего налогоплательщика, вам будет открыта Пенсионная карта.'},
#    {'вопрос': 'Какой документ необходим для открытия Пенсионной карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Для открытия Пенсионной карты требуется документ, удостоверяющий личность.'},
#    {'вопрос': 'Как узнать о поступлении пенсии на счет?',
#     'ответ': 'О поступлении пенсии на счет вам придет СМС-сообщение, или вы можете проверить это через мобильное приложение BCC.KZ.'},
#    {'вопрос': 'Как получить номер счета/IBAN для получения пенсионных выплат?',
#     'ответ': 'Получить номер счета/IBAN можно через мобильное приложение BCC.KZ, выбрав Пенсионную карту и перейдя во вкладку Информация, либо через отделение Банка.'},
#    {'вопрос': 'Какими способами можно пополнить Пенсионную карту #ҮлкенгеҚұрмет?',
#     'ответ': 'Пополнить Пенсионную карту можно через банкомат с функцией cash-in, платежный терминал, перевод на карту, кассу и другие способы.'},
#    {'вопрос': 'За покупку каких услуг я получаю кэшбек?',
#     'ответ': 'Кэшбек начисляется за покупки в аптеках (3%) и за продукты питания (2%).'},
#    {'вопрос': 'Как мне воспользоваться кэшбеком?',
#     'ответ': 'Кэшбек будет начислен на вашу Пенсионную карту, и вы можете контролировать информацию о нем в мобильном приложении BCC.KZ.'},
#    {'вопрос': 'Сколько стоит перевыпуск Пенсионной карты #ҮлкенгеҚұрмет?',
#     'ответ': 'Перевыпуск Пенсионной карты осуществляется бесплатно.'}],
#   'JuniorBank': [{'вопрос': 'Какой тип/вид пластика у #JuniorBank?',
#     'ответ': 'Тип пластика у #JuniorBank - Visa Gold.'},
#    {'вопрос': 'Какой вид карты у #JuniorBank?',
#     'ответ': '#JuniorBank является дебетовой картой.'},
#    {'вопрос': 'В какой валюте ведется счет для #JuniorBank?',
#     'ответ': 'Валюта ведения счета для #JuniorBank - Тенге.'},
#    {'вопрос': 'Какова стоимость выпуска карты #JuniorBank?',
#     'ответ': 'Стоимость выпуска карты #JuniorBank - 0 тенге.'},
#    {'вопрос': 'Возможен ли выпуск дополнительной карты для #JuniorBank?',
#     'ответ': 'Выпуск дополнительной карты для #JuniorBank невозможен.'},
#    {'вопрос': 'Какова стоимость перевыпуска карты #JuniorBank?',
#     'ответ': 'Стоимость перевыпуска карты #JuniorBank составляет 0 тенге.'},
#    {'вопрос': 'Какова стоимость годового обслуживания карты #JuniorBank?',
#     'ответ': 'Годовое обслуживание карты #JuniorBank составляет 0 тенге.'},
#    {'вопрос': 'Каков срок действия пластика карты #JuniorBank?',
#     'ответ': 'Срок действия пластика карты #JuniorBank составляет 8 лет.'},
#    {'вопрос': 'Доступны ли кредиты для #JuniorBank?',
#     'ответ': 'Кредиты для карты #JuniorBank не предусмотрены.'},
#    {'вопрос': 'Где можно использовать карту #JuniorBank?',
#     'ответ': 'Карту #JuniorBank можно использовать во всем мире.'},
#    {'вопрос': 'Что такое Карта #Junior?',
#     'ответ': 'Карта #Junior представляет собой детскую банковскую карту, доступную в двух форматах: виртуальная карта, выпускаемая дистанционно через приложение BCC.KZ родителем, и пластиковая карта мгновенного выпуска, оформляемая в любом отделении банка. Оба вида карт позволяют оплачивать покупки, совершать платежи и переводы, а также снимать деньги в специальных банкоматах.'},
#    {'вопрос': "Что означает термин 'кэшбек'?",
#     'ответ': 'Кэшбек представляет собой возврат определенного процента от суммы совершенной покупки по карте, который зачисляется обратно на счет карты.'},
#    {'вопрос': 'Может ли ребенок самостоятельно осуществить перевод денег?',
#     'ответ': 'Ребенок имеет возможность самостоятельно осуществлять переводы денег с карты на карту через Junior Bank, используя как номер телефона, так и номер карты.'},
#    {'вопрос': 'Кто имеет право выпустить Карту #Junior?',
#     'ответ': 'Карту #Junior может выпустить любой клиент банка, у которого уже есть какая-либо карта БЦК.'},
#    {'вопрос': 'Ограничиваются ли возможности выпуска Карты #Junior только родителями?',
#     'ответ': 'Клиент банка может выпустить Карту #Junior не только для своих детей, но и для племянников, внуков, братьев и сестер, позволяя, например, бабушке оформить карту для внука или дяде - для племянника.'},
#    {'вопрос': 'Существуют ли возрастные ограничения для открытия карты #Junior?',
#     'ответ': 'Карта #Junior предназначена для детей в возрасте от 6 до 18 лет.'},
#    {'вопрос': 'Какова стоимость карты #Junior?',
#     'ответ': 'Выпуск и обслуживание карты #Junior осуществляется бесплатно, также как и предоставление СМС/ПУШ-уведомлений как для ребенка, так и для родителя.'},
#    {'вопрос': 'Какие шаги следуют после выпуска виртуальной карты родителем/клиентом?',
#     'ответ': 'После выпуска виртуальной карты родителем/клиентом, на сотовый номер ребенка отправляется СМС-сообщение со ссылкой на скачивание мобильного приложения Junior Bank. Ребенок должен скачать приложение, зарегистрироваться в нем, используя свой номер телефона, подтвердить действие датой рождения и создать пароль для доступа в приложение.'},
#    {'вопрос': 'Как ребенку осуществлять платежи с помощью смартфона?',
#     'ответ': 'Для осуществления платежей с помощью смартфона, ребенок должен использовать телефоны iPhone или Samsung с поддержкой NFC. Реквизиты карты можно запросить в приложении Junior Bank и добавить в электронные кошельки Apple Pay (iPhone) или Samsung Pay (Samsung).'},
#    {'вопрос': 'Может ли ребенок использовать и виртуальную, и пластиковую карту одновременно?',
#     'ответ': 'Ребенок имеет возможность использовать как виртуальную, так и пластиковую карту, поскольку обе карты связаны с одним и тем же счетом, и баланс на них будет единым.'},
#    {'вопрос': 'Нужно ли закрывать виртуальную карту при выпуске пластиковой?',
#     'ответ': 'Нет необходимости закрывать виртуальную карту при выпуске пластиковой, так как ребенок может пользоваться обоими картами для различных целей: виртуальной для оплаты через Apple Pay/Samsung Pay и пластиковой для традиционных покупок.'},
#    {'вопрос': 'Требуется ли открытие виртуальной карты, если у ребенка уже есть пластиковая карта #Junior?',
#     'ответ': 'Отсутствует необходимость в открытии виртуальной карты, если ребенок уже пользуется пластиковой картой #Junior. Однако, для привязки карты к Apple Pay/Samsung Pay, можно добавить реквизиты пластиковой карты в соответствующие электронные кошельки.'},
#    {'вопрос': 'Что представляет собой мобильное приложение Junior Bank для детей?',
#     'ответ': 'Мобильное приложение Junior Bank предоставляет ребенку информацию о его карте, доступных средствах, истории покупок, заработанном кешбэке, а также ожидаемых функциях, таких как платежи, переводы и выбор любимых категорий.'},
#    {'вопрос': 'Видит ли ребенок в приложении Junior Bank средства на карте родителя/клиента?',
#     'ответ': 'Ребенок имеет доступ только к информации о своей карте и доступных на ней средствах, не видя данных о карте родителя/клиента.'},
#    {'вопрос': 'Возможно ли для родителя/клиента просматривать карту ребенка в своем приложении BCC.KZ?',
#     'ответ': 'Родитель/клиент может видеть карту ребенка и операции, совершенные по ней, в своем мобильном приложении BCC.KZ.'},
#    {'вопрос': 'Каковы условия по кешбэку для карты #Junior?',
#     'ответ': 'При совершении покупок по карте #Junior начисляется гарантированный кэшбэк в размере 1% на любую сумму покупки, даже на минимальную в 10 тенге, при этом максимальная сумма кэшбэка в месяц составляет 10 000 тенге.'},
#    {'вопрос': 'Может ли родитель/клиент управлять средствами ребенка на карте #Junior?',
#     'ответ': 'Родитель не имеет возможности совершать платежи, снимать деньги или переводить средства с детской карты обратно на свою.'},
#    {'вопрос': 'Какие ограничения устанавливает банк на использование детских карт?',
#     'ответ': 'Детские карты обладают автоматическими ограничениями, предотвращающими их использование в торговых точках категории 18+, таких как табачные лавки, алкомаркеты, религиозные магазины, казино, коммерческие спортивные организации, аренда автомобилей и прочее.'},
#    {'вопрос': 'Как родитель может управлять картой ребенка?',
#     'ответ': 'Родители имеют возможность управления картой ребенка посредством различных функций. Они могут блокировать или разблокировать карту в случае необходимости. Также родители могут настраивать лимиты трат по различным направлениям, включая снятие наличных в банкоматах, переводы с детских карт на другие карты, оплату покупок и покупки в интернете. Эти лимиты могут быть скорректированы как в сторону увеличения, так и уменьшения. Кроме того, родители могут сбросить и установить новый ПИН-код для карты ребенка. Дополнительно предусмотрена возможность настройки смс-уведомлений, которые будут поступать на телефон родителя о действиях, совершаемых с детской картой.'},
#    {'вопрос': 'Можно ли выпустить карту для детей нерезидентов?',
#     'ответ': 'Выпуск карты для детей нерезидентов осуществим при условии, что у родителя или законного представителя ребенка имеется любая карта банка БЦК. Это предоставляет родителям возможность управления финансами своих детей, даже если они являются нерезидентами.'}],
#   'bccpay': [{'вопрос': 'Какой тип/вид пластика у #BCCPAY - зарплатная карта?',
#     'ответ': 'Тип пластика у #BCCPAY - зарплатная карта - Visa Gold.'},
#    {'вопрос': 'Какой вид карты у #BCCPAY - зарплатная карта?',
#     'ответ': '#BCCPAY - зарплатная карта является дебетовой картой.'},
#    {'вопрос': 'В какой валюте ведется счет для #BCCPAY - зарплатная карта?',
#     'ответ': 'Валюта ведения счета для #BCCPAY - зарплатная карта - Тенге.'},
#    {'вопрос': 'Какова стоимость выпуска карты #BCCPAY - зарплатная карта?',
#     'ответ': 'Стоимость выпуска карты #BCCPAY - зарплатная карта - 0 тенге.'},
#    {'вопрос': 'Возможен ли выпуск дополнительной карты для #BCCPAY - зарплатная карта?',
#     'ответ': 'Выпуск дополнительной карты для #BCCPAY - зарплатная карта невозможен.'},
#    {'вопрос': 'Какова стоимость перевыпуска карты #BCCPAY - зарплатная карта при утере/краже/повреждении пластика?',
#     'ответ': 'Стоимость перевыпуска карты #BCCPAY - зарплатная карта составляет 0 тенге.'},
#    {'вопрос': 'Какова стоимость годового обслуживания карты #BCCPAY - зарплатная карта?',
#     'ответ': 'Годовое обслуживание карты #BCCPAY - зарплатная карта составляет 0 тенге.'},
#    {'вопрос': 'Каков срок действия пластика карты #BCCPAY - зарплатная карта?',
#     'ответ': 'Срок действия пластика карты #BCCPAY - зарплатная карта составляет 3 года.'},
#    {'вопрос': 'Доступны ли кредиты для #BCCPAY - зарплатная карта?',
#     'ответ': 'Кредиты для карты #BCCPAY - зарплатная карта не предусмотрены.'},
#    {'вопрос': 'Где можно использовать карту #BCCPAY - зарплатная карта?',
#     'ответ': 'Карту #BCCPAY - зарплатная карта можно использовать во всем мире.'}],
#   'другое': [{'вопрос': 'Я получил/а пуш/смс о том, что моя карта больше не продлевается и будет закрыта, на каком основании вы закрываете карту без моего заявления?',
#     'ответ': "Согласно Закона РК 'О платежах и платежных системах' Статья 29 п.9., Банк вправе отказаться от исполнения договора в случае отсутствия движения денег на банковском счете клиента более одного года. При наличии остатка от 0 до 500 тенге карта будет закрыта в конце месяца, в котором вы получили уведомление о закрытии. В случае остатка от 501 тенге и выше карта будет закрыта через три месяца со дня получения уведомления клиентом. Также вы можете закрыть карту самостоятельно в отеделнии банка в любое Вам удобное время до указанного периода закрытия."},
#    {'вопрос': 'Когда моя карта будет закрыта?',
#     'ответ': "Согласно Закона РК 'О платежах и платежных системах' Статья 29 п.9., Банк вправе отказаться от исполнения договора в случае отсутствия движения денег на банковском счете клиента более одного года. При наличии остатка от 0 до 500 тенге карта будет закрыта в конце месяца, в котором вы получили уведомление о закрытии. В случае остатка от 501 тенге и выше карта будет закрыта через три месяца со дня получения уведомления клиентом. Также вы можете закрыть карту самостоятельно в отеделнии банка в любое Вам удобное время до указанного периода закрытия."},
#    {'вопрос': 'В каком отделении я могу забрать свой остаток средств?',
#     'ответ': 'В любом отделении Банка.'},
#    {'вопрос': 'Если я не успею снять свой остаток в течении трех месяцев?',
#     'ответ': 'В случае, если клиент не успел перевести остаток средств и счет был закрыт, он может обратиться в любое отделение банка с заявлением на возврат. Денежные средства будут возвращены по желанию клиента.'},
#    {'вопрос': 'Срок действия моей карты еще не истек, почему Банк закрывает счет до истечения срока дейсвия карты?',
#     'ответ': "Согласно Закона РК 'О платежах и платежных системах', Банк вправе отказаться от исполнения договора в случае отсутствия движения денег на банковском счете клиента более одного года."}]}}

# %%
answers = []
questions = []
for x in data:
    for k in data[x]:
        for a in data[x][k]:
            questions.append(a['вопрос'])
            answers.append(a['ответ'])

# %%
questions
# Out:
# ['Какова минимальная сумма открытия для депозита "Рахмет" без права пополнения и снятия?',
#  'Разрешены ли дополнительные взносы для депозита "Рахмет"?',
#  'Можно ли осуществить досрочное расторжение депозита "Рахмет"?',
#  'Какие сроки и ставки возвращения применяются при досрочном расторжении депозита "Рахмет"?',
#  'Есть ли различия в ставках в зависимости от того, через что открывается депозит "Рахмет": через приложение или через отделение банка?',
#  'Как производится расчет вознаграждения по депозиту "Рахмет"?',
#  'Продлевается ли вклад "Рахмет" автоматически после окончания срока?',
#  'Допускается ли частичное изъятие средств с депозита "Рахмет"?',
#  'Как часто происходит капитализация по депозиту "Рахмет"?',
#  'Какова минимальная сумма для досрочного расторжения депозита "Рахмет"?',
#  'Какая минимальная сумма открытия для депозита "Чемпион" с правом пополнения и снятия?',
#  'Разрешены ли дополнительные взносы на депозит "Чемпион"?',
#  'Предусмотрено ли частичное изъятие средств с депозита "Чемпион"?',
#  'Можно ли провести досрочное расторжение депозита "Чемпион" и как это происходит?',
#  'Как рассчитывается вознаграждение при досрочном расторжении депозита "Чемпион"?',
#  'Какие условия продления (пролонгации) депозита "Чемпион"?',
#  'Как часто происходит капитализация по депозиту "Чемпион"?',
#  'Каковы ставки при открытии депозита "Чемпион" через приложение BCC.KZ на 13 и 24 месяца?',
#  'Есть ли разница в ставках при открытии депозита "Чемпион" через приложение по сравнению с открытием через отделение банка?',
#  'Как рассчитывается вознаграждение по депозиту "Чемпион"?',
#  'Какова минимальная сумма открытия для депозита "Моя Цель" с правом пополнения и без права снятия?',
#  'Могут ли вноситься дополнительные средства на депозит "Моя Цель" после его открытия?',
#  'Возможно ли частичное снятие с депозита "Моя Цель"?',
#  'Каковы условия досрочного расторжения депозита "Моя Цель"?',
#  'Предусматривается ли автоматическое продление депозита "Моя Цель"?',
#  'Как происходит капитализация по депозиту "Моя Цель"?',
#  'Какие ставки предлагаются при открытии депозита "Моя Цель" через приложение BCC.KZ на сроки 3, 6 и 12 месяцев?',
#  'Как рассчитывается вознаграждение по депозиту "Моя Цель"?',
#  'Если на мои счета наложен арест, вознаграждения по депозиту будут начисляться?',
#  'У моего родственника был депозит, он умер, что делать?',
#  'Я хочу доверить управление мои депозитом родственнику. Что нужно для этого сделать?',
#  'У меня есть депозит Рахмет/Рахмет+ в вашем Банке, и его срок окончания выпадает на выходной/праздничный день, мне нужно его закрыть, что необходимо предпринять?',
#  'Что случится, если я не подойду в назначенный срок по закрытию депозита Рахмет/Рахмет+?',
#  'Как можно закрыть депозит',
#  'Какие документы чтобы закрыть депозит',
#  'Как можно пополнить депозит через КАССА 24, Cash-in банкоматы и ИПТ БЦК?',
#  'Каковы условия пополнения депозита через мобильное приложение BCC.KZ?',
#  'Возможно ли пополнение депозита наличными через кассу в отделении БЦК?',
#  'Существует ли комиссия за пополнение депозита в БЦК?',
#  'Может ли третье лицо пополнить мой депозит?',
#  'Какой тип/вид пластика у #картакарта?',
#  'Какой вид карты у #картакарта?',
#  'В какой валюте ведется счет для #картакарта?',
#  'Какова стоимость выпуска карты #картакарта?',
#  'Возможен ли выпуск дополнительной карты для #картакарта?',
#  'Какова стоимость перевыпуска карты #картакарта при утере/краже/повреждении пластика?',
#  'Какова стоимость годового обслуживания карты #картакарта?',
#  'Каков срок действия пластика карты #картакарта?',
#  'Каков срок действия договора кредитного лимита для #картакарта?',
#  'Где можно использовать карту #картакарта?',
#  'Что такое #картакарта?',
#  'Я получу приветственный бонус?',
#  'Как заработать с #картакарта?',
#  'Что такое кешбэк?',
#  'Как выбирать любимые категории с повышенным кешбэком?',
#  'Могу ли я расплачиваться картой за границей?',
#  'Как пополнять карту?',
#  'Что если я получу карту с нулевым кредитным лимитом, что мне с ней делать и дадут ли мне лимит в будущем?',
#  'Зачем мне нужен кредитный лимит по #картакарта?',
#  'Как я узнаю, что мне установили кредитный лимит?',
#  'Как будут тратиться деньги, если у меня есть и личные деньги и кредитный лимит на карте?',
#  'Как включить и отключить режим рассрочки онлайн в мобильном приложении BCC.KZ?',
#  'Какие сроки рассрочки предусмотрены по карте?',
#  'Есть ли комиссия за рассрочку?',
#  'Я могу покупать в рассрочку за счет личных денег?',
#  'Я могу погашать задолженность по карте досрочно?',
#  'Я не резидент, я могу получить кредитный лимит по карте?',
#  'Как получить виртуальную карту?',
#  'На каком основании Банк увеличивает кредитный лимит без согласия клиента?',
#  'Я НЕ согласен с маленькой суммой лимита.',
#  'Я НЕ согласен с большой суммой лимита!',
#  'Что делать, если клиент обращается с просьбой аннулировать (обнулить) кредитный лимит?',
#  'Можно ли открыть карту в другой валюте, кроме тенге?',
#  'Есть ли целевое назначение кредитного лимита?',
#  'Обязательны ли пенсионные отчисления для рассмотрения?',
#  'Есть ли срок действия у кэшбека?',
#  'Можно ли рассмотреть и выпустить карту онлайн, без посещения отделении?',
#  'По карте имеется страховка?',
#  'Можно ли привлечь созаемщика для рассмотрение кредитного лимита?',
#  'Что такое льготный период по карте?',
#  'Что делать если КЛ не поступил?',
#  'За какие платежи мобильного приложения начисляется кэшбэк в BCC.KZ?',
#  'Возможно ли объединить кэшбэк по стандартным картам и по кредитной карте для быстрого накопления?',
#  'Как начисляется кэшбэк при рассрочке?',
#  'Возможно ли получить кредитный лимит при уже открытой карте без кредитного лимита путем открытия новой карты?',
#  'Какой тип/вид пластика у #IronCard?',
#  'Какой вид карты у #IronCard?',
#  'В каких валютах ведется счет для #IronCard?',
#  'Какова стоимость выпуска карты #IronCard для резидентов и нерезидентов РК?',
#  'Возможен ли выпуск дополнительной карты для #IronCard?',
#  'Какова стоимость перевыпуска карты #IronCard?',
#  'Какова стоимость годового обслуживания карты #IronCard?',
#  'Каков срок действия пластика карты #IronCard?',
#  'Доступны ли кредиты для #IronCard?',
#  'Где можно использовать карту #IronCard?',
#  'Какой тип/вид пластика у #Travel Card?',
#  'Какой вид карты у #Travel Card?',
#  'В каких валютах ведется счет для #Travel Card?',
#  'Какова стоимость выпуска карты #Travel Card для резидентов и нерезидентов РК?',
#  'Возможен ли выпуск дополнительной карты для #Travel Card?',
#  'Какова стоимость перевыпуска карты #Travel Card?',
#  'Какова стоимость годового обслуживания карты #Travel Card?',
#  'Каков срок действия пластика карты #Travel Card?',
#  'Доступны ли кредиты для #Travel Card?',
#  'Где можно использовать карту #Travel Card?',
#  'Какой тип/вид пластика у #ҮлкенгеҚұрмет?',
#  'Какой вид карты у #ҮлкенгеҚұрмет?',
#  'В какой валюте ведется счет для #ҮлкенгеҚұрмет?',
#  'Какова стоимость выпуска карты #ҮлкенгеҚұрмет?',
#  'Возможен ли выпуск дополнительной карты для #ҮлкенгеҚұрмет?',
#  'Какова стоимость перевыпуска карты #ҮлкенгеҚұрмет при утере/краже/повреждении пластика?',
#  'Какова стоимость годового обслуживания карты #ҮлкенгеҚұрмет?',
#  'Каков срок действия пластика карты #ҮлкенгеҚұрмет?',
#  'Доступны ли кредиты для #ҮлкенгеҚұрмет?',
#  'Где можно использовать карту #ҮлкенгеҚұрмет?',
#  'Какие банкоматы принимают Пенсионную карту #ҮлкенгеҚұрмет?',
#  'Могу ли я снимать деньги с Пенсионной карты #ҮлкенгеҚұрмет в банкомате другого Банка?',
#  'Взимается ли комиссия при снятии денег с Пенсионной карты в банкоматах за пределами Казахстана?',
#  'Могу ли я снять деньги в другой валюте с Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Для каких целей предназначена Пенсионная карта #ҮлкенгеҚұрмет?',
#  'Какие преимущества у Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Сколько времени занимает выпуск Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Где я могу ознакомиться с тарифами по Пенсионной карте #ҮлкенгеҚұрмет?',
#  'Что делать, если пенсионная выплата не поступила, несмотря на направленные реквизиты в ЦОН?',
#  'Когда обычно выплачивается пенсия?',
#  'Откроют ли мне Пенсионную карту #ҮлкенгеҚұрмет при наличии арестованных счетов и статуса бездействующего налогоплательщика?',
#  'Какой документ необходим для открытия Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Как узнать о поступлении пенсии на счет?',
#  'Как получить номер счета/IBAN для получения пенсионных выплат?',
#  'Какими способами можно пополнить Пенсионную карту #ҮлкенгеҚұрмет?',
#  'За покупку каких услуг я получаю кэшбек?',
#  'Как мне воспользоваться кэшбеком?',
#  'Сколько стоит перевыпуск Пенсионной карты #ҮлкенгеҚұрмет?',
#  'Какой тип/вид пластика у #JuniorBank?',
#  'Какой вид карты у #JuniorBank?',
#  'В какой валюте ведется счет для #JuniorBank?',
#  'Какова стоимость выпуска карты #JuniorBank?',
#  'Возможен ли выпуск дополнительной карты для #JuniorBank?',
#  'Какова стоимость перевыпуска карты #JuniorBank?',
#  'Какова стоимость годового обслуживания карты #JuniorBank?',
#  'Каков срок действия пластика карты #JuniorBank?',
#  'Доступны ли кредиты для #JuniorBank?',
#  'Где можно использовать карту #JuniorBank?',
#  'Что такое Карта #Junior?',
#  "Что означает термин 'кэшбек'?",
#  'Может ли ребенок самостоятельно осуществить перевод денег?',
#  'Кто имеет право выпустить Карту #Junior?',
#  'Ограничиваются ли возможности выпуска Карты #Junior только родителями?',
#  'Существуют ли возрастные ограничения для открытия карты #Junior?',
#  'Какова стоимость карты #Junior?',
#  'Какие шаги следуют после выпуска виртуальной карты родителем/клиентом?',
#  'Как ребенку осуществлять платежи с помощью смартфона?',
#  'Может ли ребенок использовать и виртуальную, и пластиковую карту одновременно?',
#  'Нужно ли закрывать виртуальную карту при выпуске пластиковой?',
#  'Требуется ли открытие виртуальной карты, если у ребенка уже есть пластиковая карта #Junior?',
#  'Что представляет собой мобильное приложение Junior Bank для детей?',
#  'Видит ли ребенок в приложении Junior Bank средства на карте родителя/клиента?',
#  'Возможно ли для родителя/клиента просматривать карту ребенка в своем приложении BCC.KZ?',
#  'Каковы условия по кешбэку для карты #Junior?',
#  'Может ли родитель/клиент управлять средствами ребенка на карте #Junior?',
#  'Какие ограничения устанавливает банк на использование детских карт?',
#  'Как родитель может управлять картой ребенка?',
#  'Можно ли выпустить карту для детей нерезидентов?',
#  'Какой тип/вид пластика у #BCCPAY - зарплатная карта?',
#  'Какой вид карты у #BCCPAY - зарплатная карта?',
#  'В какой валюте ведется счет для #BCCPAY - зарплатная карта?',
#  'Какова стоимость выпуска карты #BCCPAY - зарплатная карта?',
#  'Возможен ли выпуск дополнительной карты для #BCCPAY - зарплатная карта?',
#  'Какова стоимость перевыпуска карты #BCCPAY - зарплатная карта при утере/краже/повреждении пластика?',
#  'Какова стоимость годового обслуживания карты #BCCPAY - зарплатная карта?',
#  'Каков срок действия пластика карты #BCCPAY - зарплатная карта?',
#  'Доступны ли кредиты для #BCCPAY - зарплатная карта?',
#  'Где можно использовать карту #BCCPAY - зарплатная карта?',
#  'Я получил/а пуш/смс о том, что моя карта больше не продлевается и будет закрыта, на каком основании вы закрываете карту без моего заявления?',
#  'Когда моя карта будет закрыта?',
#  'В каком отделении я могу забрать свой остаток средств?',
#  'Если я не успею снять свой остаток в течении трех месяцев?',
#  'Срок действия моей карты еще не истек, почему Банк закрывает счет до истечения срока дейсвия карты?']

# %%
answers
# Out:
# ['Минимальная сумма открытия составляет 500,000 KZT.',
#  'Дополнительные взносы не допускаются.',
#  'По истечении 30 календарных дней с даты подачи заявления клиента, возвращение выплачивается по ставке вклада до востребования, действующего на дату расторжения Договора.',
#  'Ставки возвращения составляют 0.1% в тенге, долларе США, евро, и российском рубле.',
#  'Cтавки при открытии через приложение BCC.KZ для срока в 3, 6 и 12 месяцев составляют 17.2%, 17.2% и 15.7% соответственно. При открытии через отделение банка ставки составляют 16.1%, 16.1% и 14.6% соответственно.',
#  'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.',
#  'Вклады, открытые до 02.12.2020 года, продлеваются допускается. Вклады, открытые после 02.12.2020 года, автоматически переоформляются на вклад «Чемпион» со сроком размещения 13 месяцев.',
#  'Частичное изъятие не допускается.',
#  'Капитализация происходит 1-го числа каждого месяца.',
#  'Минимальная сумма для досрочного расторжения составляет 500 в тенге, 10 в долларах США, 15 в евро.',
#  'Минимальная сумма открытия составляет 1 000 KZT/RUB, 10 USD/EUR.',
#  'Да, дополнительные взносы допускаются.',
#  'Частичное изъятие разрешено без ограничений, но соблюдая минимальный неснижаемый остаток (1 000 KZT/RUB, 10 USD/EUR).',
#  'Досрочное расторжение возможно "День в день", то есть возвращение вклада в день подачи заявления на расторжение.',
#  'Вознаграждение вычисляется исходя из фактического периода размещения денег на вкладе, без пересчета ранее выплаченного вознаграждения.',
#  'Пролонгация возможна от 13 до 24 месяцев, но не более 2-х раз.',
#  'Капитализация происходит ежемесячно, 1-го числа каждого месяца.',
#  'Ставки составляют 14% и 8.65% в тенге, 0.75% и 0.75% в долларе США, 0.1% и 0.1% в евро, 0.1% и 0.1% в российском рубле соответственно для сроков в 13 и 24 месяца.',
#  'Да, ставки при открытии через приложение на 13 и 24 месяца чуть выше (14% и 8.65% в тенге) по сравнению с открытием через отделение банка (13.1% и 7.7% в тенге). Эффективные ставки также немного выше при открытии через приложение.',
#  'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.',
#  'Минимальная сумма открытия составляет 1 KZT.',
#  'Да, дополнительные взносы допускаются.',
#  'Частичное снятие не допускается.',
#  'Досрочное расторжение возможно "День в день". Если расторжение договора происходит до истечения одного месяца с даты зачисления первой суммы вклада на счет, вознаграждение не начисляется. При расторжении договора после истечения более одного месяца с даты зачисления первой суммы вклада на счет, удерживается штраф в размере 50% от начисленного вознаграждения.',
#  'Да, по вкладам «Моя цель» предусмотрено неограниченное количество пролонгаций.',
#  'Капитализация происходит ежемесячно, 1-го числа каждого месяца.',
#  'Ставки в тенге составляют 14.9% для сроков в 3 и 6 месяцев и 12.9% для срока в 12 месяцев.',
#  'Вознаграждение рассчитывается по формуле: сумма вклада X количество дней начисления процентов по вкладу в месяце X номинальная процентная ставка / 365 дней = сумма вознаграждения.',
#  'Проценты начисляется, даже если на депозит наложен арест. Вы сможете воспользоваться своим депозитом и начисленными процентами, как только арест будет снят.',
#  'Для того чтобы унаследовать вклад, нужно обратиться в ближайшее отделении Банка при себе иметь: Нотариально удостоверенная копия свидетельства о праве наследование счетом по закону и нотариально заверенная копия свидетельства о смерти Вкладчика Уведомление о смерти Вкладчика с ЦОН-а',
#  'Вам необходимо выдать доверенность, с указанием, какие именно действия по депозиту вы доверяете совершать родственнику. Доверенность может быть оформлена у нотариуса или консула от имени РК При обслуживании вашему родственнику всегда необходимо будет предоставлять оригинал доверенности и документ, удостоверяющий его личность',
#  'Так как дата окончания выпадает не на будний день, у Вас будет возможность закрыть вклад на следующий рабочий день. При себе необходимо иметь документ удостоверяющий личность.',
#  'Вклад автоматически пролонгируется, по ставке действующей на момент пролонгации. Как только Ваш вклад будет пролонгирован, Вы сможете снять средства с депозита по истечению такого же срока либо можно написать заявление для досрочного расторжения. По истечении 30 календарных дней с даты подачи заявления, вознаграждение выплачивается по ставке вклада «До востребования», действующего на дату расторжения Договора. А пролонгация по депозитам открытым с 04.12.2020 отсутствует возможность автоматической пролонгации вклада. В день истечения срока действия договора предусмотрено автоматическое переоформление на депозит "Чемпион", со сроком на 13 месяцев.',
#  'Депозит можно закрыть в любом отделении Банка ЦентрКредит в рабочее время или в мобильном приложении BCC.KZ',
#  'Для закрытия вклада при себе необходимо иметь удостоверние личности либо паспорт РК',
#  'Чтобы пополнить депозит, необходимо ввести ИИН вкладчика и последние 4 цифры счета. Комиссия за пополнение не взимается. Средства поступают на счет в течение 15 минут. Максимальная сумма для одного терминала составляет 500 000 тенге, при этом можно внести не более 40 купюр.',
#  'Пополнение депозита через приложение BCC.KZ осуществляется через переводы между своими счетами. Комиссия за перевод не взимается, и средства поступают на счет моментально.',
#  'Пополнение депозита наличными через кассу в отделении БЦК возможно без комиссии. Также пополнить счет может третье лицо.',
#  'Независимо от способа пополнения — через КАССА 24, Cash-in банкоматы, ИПТ БЦК, приложение BCC.KZ или наличными через кассу в отделении — комиссия составляет 0 тенге.',
#  'Третье лицо может пополнить депозит через кассу в отделении БЦК без комиссии.',
#  'Тип пластика у #картакарта - Visa Gold.',
#  '#картакарта является картой рассрочки/кредитной картой/дебетовой картой.',
#  'Валюта ведения счета для #картакарта - Тенге.',
#  'Стоимость выпуска карты #картакарта - 0 тенге.',
#  'Выпуск дополнительной карты для #картакарта невозможен.',
#  'Стоимость перевыпуска карты #картакарта составляет 0 тенге.',
#  'Годовое обслуживание карты #картакарта составляет 0 тенге.',
#  'Срок действия пластика карты #картакарта составляет 5 лет.',
#  'Срок действия договора кредитного лимита для #картакарта составляет 3 года.',
#  'Карту #картакарта можно использовать во всем мире.',
#  '#картакарта - это универсальная карта с кредитным лимитом, которая позволяет оплачивать покупки без процентов в льготный период, покупать в рассрочку без переплат у партнеров Банка и зарабатывать кешбэк.',
#  'За первую покупку по карте мы зачислим на ваш кешбэк-счет приветственный бонус - 10% от суммы покупки (максимум 1 000 Тенге).',
#  'Оплачивайте покупки картой и зарабатывайте кешбэк до 30%.',
#  'Кешбэк за покупки по карте — это вознаграждение от Банка и наших партнеров за использование карты, возвращающее определенную сумму за покупки.',
#  'В начале каждого месяца мы предлагаем новый набор категорий покупок с кешбэком до 10%. Выбор категорий можно делать в мобильном приложении BCC.KZ.',
#  'Картой можно пользоваться по всему миру.',
#  'Пополняйте карту с другой карты или счета, банковским переводом из другого банка, наличными через банкоматы, терминалы или кассу Банка. Пополнение карты - бесплатно!',
#  'С #картакарта вы зарабатываете деньги, когда их тратите. Покупайте за счет личных денег, получайте кешбэк до 30%, и Банк может пересмотреть размер лимита.',
#  'Кредитный лимит - это ваша личная заначка, когда личных денег на покупку оказалось недостаточно.',
#  'Вы получите уведомление от Банка.',
#  'Сначала используются ваши личные деньги, затем кредитный лимит.',
#  'Вы можете включать и отключать режим рассрочки онлайн в мобильном приложении BCC.KZ.',
#  'В сети партнеров Банка предусмотрены сроки рассрочки на 3, 6 или 12 месяцев в зависимости от условий договоренности с партнером.',
#  'Покупки у партнеров Банка осуществляются без процентов и комиссий.',
#  'Покупки в рассрочку возможны за счет кредитного лимита.',
#  'Погашать задолженность по карте досрочно можно в любое время без штрафов и посещения Банка для формирования графиков.',
#  'На данный момент кредитный лимит устанавливается только резидентам РК, но вы можете пользоваться картой за счет личных денег и получать кешбэк до 30%.',
#  'Теперь не нужно закрывать виртуальную #картакарта для открытия физической. Клиент может обратиться в отделение Банка для получения пластика и его привязки к счету виртуальной #картакарта.',
#  'Согласно Заявлению к Договору присоединения (по Кредитным карточкам), заключенному между Банком и клиентом, Банк имеет право без дополнительного согласия клиента изменять сумму кредитного лимита в сторону увеличения, с обязательным уведомлением клиента.',
#  'В мобильном приложении можно подать заявку на увеличение кредитного лимита (функционал доступен раз в 30 дней). Лимит может быть увеличен до 7 миллионов тенге.',
#  'Увеличение лимита - это показатель доверия Банка и запасные деньги, которые всегда будут под рукой.',
#  'Аннулирование только кредитного лимита без закрытия самой #картакарта невозможно. Рекомендуется рассказать о преимуществах #картакарта.',
#  'Открыть карту можно только в тенге.',
#  'Можно использовать на любые потребительские цели.',
#  'Можем рассмотреть без отчислений.',
#  'Срок действия кэшбека 1 год.',
#  'Если клиент открывает впервые #картакарта и хочет открыть виртуальную.',
#  'По картакарта страховка не предусмотрена.',
#  'Привлечь созаемщика для рассмотрение кредитного лимита не предусмотрено.',
#  'Это время, в течение которого вы можете пользоваться деньгами со своей кредитной карты и не платить проценты.',
#  'Зафиксируем обращение.',
#  'Оплата мобильной связи, коммунальные платежи, образование, интернет, TV, транспорт и билеты.',
#  'Объединить кэшбэк по стандартным картам и по кредитной карте для быстрого накопления невозможно.',
#  'На оплаты по рассрочке кэшбэк не начисляется.',
#  'Клиент может подать заявку на увеличение кредитного лимита в мобильном приложении (доступно раз в 30 дней), скоринговая система будет решать сумму кредитного лимита.',
#  'Тип пластика у #IronCard - Visa Infinite.',
#  '#IronCard является дебетовой картой.',
#  'Счет для #IronCard ведется в KZT (основной счет), USD, EUR, RUB.',
#  'Для резидентов РК стоимость выпуска составляет 30 000 тенге, для нерезидентов РК - 100 000 тенге. Гравировка индивидуального изображения стоит 5 000 тенге.',
#  'Выпуск дополнительной карты для #IronCard невозможен.',
#  'Перевыпуск карты по истечении срока действия - 0 тенге, по просьбе клиента или при утере - 80 000 тенге, по инициативе банка - 0 тенге.',
#  'Годовое обслуживание карты #IronCard составляет 10 000 KZT ежемесячно.',
#  'Срок действия пластика карты #IronCard составляет 8 лет.',
#  'Кредиты для карты #IronCard не предусмотрены.',
#  'Карту #IronCard можно использовать во всем мире.',
#  'Тип пластика у #Travel Card - Visa Signature.',
#  '#Travel Card является дебетовой картой.',
#  'Счет для #Travel Card ведется в KZT (основной счет), USD, EUR, RUB.',
#  'Для резидентов РК стоимость выпуска составляет 10 000 KZT, для нерезидентов РК - 50 000 KZT.',
#  'Выпуск дополнительной карты для #Travel Card невозможен.',
#  'Стоимость перевыпуска карты #Travel Card составляет 0 тенге.',
#  'Годовое обслуживание карты #Travel Card составляет 0 тенге.',
#  'Срок действия пластика карты #Travel Card составляет 8 лет.',
#  'Кредиты для карты #Travel Card не предусмотрены.',
#  'Карту #Travel Card можно использовать во всем мире.',
#  'Тип пластика у #ҮлкенгеҚұрмет - Visa Gold.',
#  '#ҮлкенгеҚұрмет является дебетовой картой.',
#  'Валюта ведения счета для #ҮлкенгеҚұрмет - Тенге.',
#  'Стоимость выпуска карты #ҮлкенгеҚұрмет - 0 тенге.',
#  'Выпуск дополнительной карты для #ҮлкенгеҚұрмет невозможен.',
#  'Стоимость перевыпуска карты #ҮлкенгеҚұрмет составляет 0 тенге.',
#  'Годовое обслуживание карты #ҮлкенгеҚұрмет составляет 0 тенге.',
#  'Срок действия пластика карты #ҮлкенгеҚұрмет составляет 3 года.',
#  'Кредиты для карты #ҮлкенгеҚұрмет не предусмотрены.',
#  'Карту #ҮлкенгеҚұрмет можно использовать во всем мире.',
#  'Пенсионная карта принимается в более чем 2 миллионах банкоматов по всему миру.',
#  'Вы можете снимать деньги с Пенсионной карты #ҮлкенгеҚұрмет в банкоматах других банков до 1 500 000 тенге в месяц бесплатно. За суммы свыше этого взимается комиссия 1% от суммы снятия.',
#  'При снятии денег с Пенсионной карты #ҮлкенгеҚұрмет в банкоматах за пределами Казахстана действуют те же условия: до 1 500 000 тенге в месяц без комиссии, сверх этого - комиссия 1% от суммы.',
#  'Вы можете снимать деньги в другой валюте с вашей Пенсионной карты #ҮлкенгеҚұрмет.',
#  'Пенсионная карта #ҮлкенгеҚұрмет предназначена для получения пенсионных выплат, осуществляемых через единый накопительный пенсионный фонд.',
#  'Преимущества включают автоматическую передачу реквизитов в ЦОН для экономии времени, cashback 3% за покупки в аптеках и 2% за продукты питания, а также бесплатную услугу смс-информирования о поступлении пенсии на карту.',
#  'Выпуск Пенсионной карты через отделение банка занимает всего 10 минут, так как карта является мгновенной.',
#  'Ознакомиться с тарифами по Пенсионной карте можно на официальном сайте Банка.',
#  'В таком случае необходимо обратиться в ЦОН по номеру 1414 для выяснения статуса выплаты.',
#  'Пенсия выплачивается ежемесячно с 1-го по 15-е число.',
#  'Даже при наличии арестованных счетов и статуса бездействующего налогоплательщика, вам будет открыта Пенсионная карта.',
#  'Для открытия Пенсионной карты требуется документ, удостоверяющий личность.',
#  'О поступлении пенсии на счет вам придет СМС-сообщение, или вы можете проверить это через мобильное приложение BCC.KZ.',
#  'Получить номер счета/IBAN можно через мобильное приложение BCC.KZ, выбрав Пенсионную карту и перейдя во вкладку Информация, либо через отделение Банка.',
#  'Пополнить Пенсионную карту можно через банкомат с функцией cash-in, платежный терминал, перевод на карту, кассу и другие способы.',
#  'Кэшбек начисляется за покупки в аптеках (3%) и за продукты питания (2%).',
#  'Кэшбек будет начислен на вашу Пенсионную карту, и вы можете контролировать информацию о нем в мобильном приложении BCC.KZ.',
#  'Перевыпуск Пенсионной карты осуществляется бесплатно.',
#  'Тип пластика у #JuniorBank - Visa Gold.',
#  '#JuniorBank является дебетовой картой.',
#  'Валюта ведения счета для #JuniorBank - Тенге.',
#  'Стоимость выпуска карты #JuniorBank - 0 тенге.',
#  'Выпуск дополнительной карты для #JuniorBank невозможен.',
#  'Стоимость перевыпуска карты #JuniorBank составляет 0 тенге.',
#  'Годовое обслуживание карты #JuniorBank составляет 0 тенге.',
#  'Срок действия пластика карты #JuniorBank составляет 8 лет.',
#  'Кредиты для карты #JuniorBank не предусмотрены.',
#  'Карту #JuniorBank можно использовать во всем мире.',
#  'Карта #Junior представляет собой детскую банковскую карту, доступную в двух форматах: виртуальная карта, выпускаемая дистанционно через приложение BCC.KZ родителем, и пластиковая карта мгновенного выпуска, оформляемая в любом отделении банка. Оба вида карт позволяют оплачивать покупки, совершать платежи и переводы, а также снимать деньги в специальных банкоматах.',
#  'Кэшбек представляет собой возврат определенного процента от суммы совершенной покупки по карте, который зачисляется обратно на счет карты.',
#  'Ребенок имеет возможность самостоятельно осуществлять переводы денег с карты на карту через Junior Bank, используя как номер телефона, так и номер карты.',
#  'Карту #Junior может выпустить любой клиент банка, у которого уже есть какая-либо карта БЦК.',
#  'Клиент банка может выпустить Карту #Junior не только для своих детей, но и для племянников, внуков, братьев и сестер, позволяя, например, бабушке оформить карту для внука или дяде - для племянника.',
#  'Карта #Junior предназначена для детей в возрасте от 6 до 18 лет.',
#  'Выпуск и обслуживание карты #Junior осуществляется бесплатно, также как и предоставление СМС/ПУШ-уведомлений как для ребенка, так и для родителя.',
#  'После выпуска виртуальной карты родителем/клиентом, на сотовый номер ребенка отправляется СМС-сообщение со ссылкой на скачивание мобильного приложения Junior Bank. Ребенок должен скачать приложение, зарегистрироваться в нем, используя свой номер телефона, подтвердить действие датой рождения и создать пароль для доступа в приложение.',
#  'Для осуществления платежей с помощью смартфона, ребенок должен использовать телефоны iPhone или Samsung с поддержкой NFC. Реквизиты карты можно запросить в приложении Junior Bank и добавить в электронные кошельки Apple Pay (iPhone) или Samsung Pay (Samsung).',
#  'Ребенок имеет возможность использовать как виртуальную, так и пластиковую карту, поскольку обе карты связаны с одним и тем же счетом, и баланс на них будет единым.',
#  'Нет необходимости закрывать виртуальную карту при выпуске пластиковой, так как ребенок может пользоваться обоими картами для различных целей: виртуальной для оплаты через Apple Pay/Samsung Pay и пластиковой для традиционных покупок.',
#  'Отсутствует необходимость в открытии виртуальной карты, если ребенок уже пользуется пластиковой картой #Junior. Однако, для привязки карты к Apple Pay/Samsung Pay, можно добавить реквизиты пластиковой карты в соответствующие электронные кошельки.',
#  'Мобильное приложение Junior Bank предоставляет ребенку информацию о его карте, доступных средствах, истории покупок, заработанном кешбэке, а также ожидаемых функциях, таких как платежи, переводы и выбор любимых категорий.',
#  'Ребенок имеет доступ только к информации о своей карте и доступных на ней средствах, не видя данных о карте родителя/клиента.',
#  'Родитель/клиент может видеть карту ребенка и операции, совершенные по ней, в своем мобильном приложении BCC.KZ.',
#  'При совершении покупок по карте #Junior начисляется гарантированный кэшбэк в размере 1% на любую сумму покупки, даже на минимальную в 10 тенге, при этом максимальная сумма кэшбэка в месяц составляет 10 000 тенге.',
#  'Родитель не имеет возможности совершать платежи, снимать деньги или переводить средства с детской карты обратно на свою.',
#  'Детские карты обладают автоматическими ограничениями, предотвращающими их использование в торговых точках категории 18+, таких как табачные лавки, алкомаркеты, религиозные магазины, казино, коммерческие спортивные организации, аренда автомобилей и прочее.',
#  'Родители имеют возможность управления картой ребенка посредством различных функций. Они могут блокировать или разблокировать карту в случае необходимости. Также родители могут настраивать лимиты трат по различным направлениям, включая снятие наличных в банкоматах, переводы с детских карт на другие карты, оплату покупок и покупки в интернете. Эти лимиты могут быть скорректированы как в сторону увеличения, так и уменьшения. Кроме того, родители могут сбросить и установить новый ПИН-код для карты ребенка. Дополнительно предусмотрена возможность настройки смс-уведомлений, которые будут поступать на телефон родителя о действиях, совершаемых с детской картой.',
#  'Выпуск карты для детей нерезидентов осуществим при условии, что у родителя или законного представителя ребенка имеется любая карта банка БЦК. Это предоставляет родителям возможность управления финансами своих детей, даже если они являются нерезидентами.',
#  'Тип пластика у #BCCPAY - зарплатная карта - Visa Gold.',
#  '#BCCPAY - зарплатная карта является дебетовой картой.',
#  'Валюта ведения счета для #BCCPAY - зарплатная карта - Тенге.',
#  'Стоимость выпуска карты #BCCPAY - зарплатная карта - 0 тенге.',
#  'Выпуск дополнительной карты для #BCCPAY - зарплатная карта невозможен.',
#  'Стоимость перевыпуска карты #BCCPAY - зарплатная карта составляет 0 тенге.',
#  'Годовое обслуживание карты #BCCPAY - зарплатная карта составляет 0 тенге.',
#  'Срок действия пластика карты #BCCPAY - зарплатная карта составляет 3 года.',
#  'Кредиты для карты #BCCPAY - зарплатная карта не предусмотрены.',
#  'Карту #BCCPAY - зарплатная карта можно использовать во всем мире.',
#  "Согласно Закона РК 'О платежах и платежных системах' Статья 29 п.9., Банк вправе отказаться от исполнения договора в случае отсутствия движения денег на банковском счете клиента более одного года. При наличии остатка от 0 до 500 тенге карта будет закрыта в конце месяца, в котором вы получили уведомление о закрытии. В случае остатка от 501 тенге и выше карта будет закрыта через три месяца со дня получения уведомления клиентом. Также вы можете закрыть карту самостоятельно в отеделнии банка в любое Вам удобное время до указанного периода закрытия.",
#  "Согласно Закона РК 'О платежах и платежных системах' Статья 29 п.9., Банк вправе отказаться от исполнения договора в случае отсутствия движения денег на банковском счете клиента более одного года. При наличии остатка от 0 до 500 тенге карта будет закрыта в конце месяца, в котором вы получили уведомление о закрытии. В случае остатка от 501 тенге и выше карта будет закрыта через три месяца со дня получения уведомления клиентом. Также вы можете закрыть карту самостоятельно в отеделнии банка в любое Вам удобное время до указанного периода закрытия.",
#  'В любом отделении Банка.',
#  'В случае, если клиент не успел перевести остаток средств и счет был закрыт, он может обратиться в любое отделение банка с заявлением на возврат. Денежные средства будут возвращены по желанию клиента.',
#  "Согласно Закона РК 'О платежах и платежных системах', Банк вправе отказаться от исполнения договора в случае отсутствия движения денег на банковском счете клиента более одного года."]

# %% [markdown]
# # Tokenezation

# %%
ans_tok = [list(tokenize(x.lower())) for x in answers].copy()

# %%
ques_tok = [list(tokenize(x.lower())) for x in questions].copy()

# %% [markdown]
# # Lemmatization

# %%
from natasha import (
    Segmenter,
    MorphVocab,
    
    Doc
)
import gensim

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
morph.parse('буквы')
# Out:
# [Parse(word='буквы', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='буква', score=0.565217, methods_stack=((DictionaryAnalyzer(), 'буквы', 599, 1),)),
#  Parse(word='буквы', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='буква', score=0.260869, methods_stack=((DictionaryAnalyzer(), 'буквы', 599, 10),)),
#  Parse(word='буквы', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='буква', score=0.173913, methods_stack=((DictionaryAnalyzer(), 'буквы', 599, 7),))]

# %%
ans = []
que = []
for sentence in ans_tok:
    temp = []
    for word in sentence:
        m = morph.parse(word.text)[0]
        temp.append(m.normal_form)
    sss = ' '.join(temp)
    tt = gensim.utils.simple_preprocess(sss)
    ans.append(tt)

for sentence in ques_tok:
    temp = []
    for word in sentence:
        m = morph.parse(word.text)[0]
        temp.append(m.normal_form)
    sss = ' '.join(temp)
    tt = gensim.utils.simple_preprocess(sss)
    que.append(tt)
#     que.append(temp)

print(ans)
print(que)
# Out:
# [['минимальный', 'сумма', 'открытие', 'составлять', 'kzt'], ['дополнительный', 'взнос', 'не', 'допускаться'], ['по', 'истечение', 'календарный', 'день', 'дата', 'подача', 'заявление', 'клиент', 'возвращение', 'выплачиваться', 'по', 'ставка', 'вклад', 'до', 'востребование', 'действовать', 'на', 'дата', 'расторжение', 'договор'], ['ставка', 'возвращение', 'составлять', 'тенг', 'доллар', 'сша', 'евро', 'российский', 'рубль'], ['тавка', 'при', 'открытие', 'через', 'приложение', 'bcc', 'kz', 'для', 'срок', 'месяц', 'составлять', 'соответственно', 'при', 'открытие', 'через', 'отделение', 'банк', 'ставка', 'составлять', 'соответственно'], ['вознаграждение', 'рассчитываться', 'по', 'формула', 'сумма', 'вклад', 'количество', 'день', 'начисление', 'процент', 'по', 'вклад', 'месяц', 'номинальный', 'процентный', 'ставка', 'день', 'сумма', 'вознаграждение'], ['вклад', 'открытый', 'до', 'год', 'продлеваться', 'допускаться', 'вклад', 'открытый', 'после', 'год', 'автоматически', 'переоформляться', 'на', 'вклад', 'чемпион', 'срок', 'размещение', 'месяц'], ['частичный', 'изъятие', 'не', 'допускаться'], ['капитализация', 'происходить', 'число', 'каждый', 'месяц'], ['минимальный', 'сумма', 'для', 'досрочный', 'расторжение', 'составлять', 'тенг', 'доллар', 'сша', 'евро'], ['минимальный', 'сумма', 'открытие', 'составлять', 'kzt', 'rub', 'usd', 'eur'], ['да', 'дополнительный', 'взнос', 'допускаться'], ['частичный', 'изъятие', 'разрешить', 'без', 'ограничение', 'но', 'соблюдать', 'минимальный', 'неснижать', 'остаток', 'kzt', 'rub', 'usd', 'eur'], ['досрочный', 'расторжение', 'возможно', 'день', 'день', 'то', 'есть', 'возвращение', 'вклад', 'день', 'подача', 'заявление', 'на', 'расторжение'], ['вознаграждение', 'вычисляться', 'исходить', 'из', 'фактический', 'период', 'размещение', 'деньга', 'на', 'вклад', 'без', 'пересчёт', 'ранее', 'выплатить', 'вознаграждение'], ['пролонгация', 'возможный', 'от', 'до', 'месяц', 'но', 'не', 'более', 'раз'], ['капитализация', 'происходить', 'ежемесячно', 'число', 'каждый', 'месяц'], ['ставка', 'составлять', 'тенг', 'доллар', 'сша', 'евро', 'российский', 'рубль', 'соответственно', 'для', 'срок', 'месяц'], ['да', 'ставка', 'при', 'открытие', 'через', 'приложение', 'на', 'месяц', 'чуть', 'выше', 'тенг', 'по', 'сравнение', 'открытие', 'через', 'отделение', 'банк', 'тенг', 'эффективный', 'ставка', 'также', 'немного', 'выше', 'при', 'открытие', 'через', 'приложение'], ['вознаграждение', 'рассчитываться', 'по', 'формула', 'сумма', 'вклад', 'количество', 'день', 'начисление', 'процент', 'по', 'вклад', 'месяц', 'номинальный', 'процентный', 'ставка', 'день', 'сумма', 'вознаграждение'], ['минимальный', 'сумма', 'открытие', 'составлять', 'kzt'], ['да', 'дополнительный', 'взнос', 'допускаться'], ['частичный', 'снятие', 'не', 'допускаться'], ['досрочный', 'расторжение', 'возможно', 'день', 'день', 'если', 'расторжение', 'договор', 'происходить', 'до', 'истечение', 'один', 'месяц', 'дата', 'зачисление', 'первый', 'сумма', 'вклад', 'на', 'счёт', 'вознаграждение', 'не', 'начисляться', 'при', 'расторжение', 'договор', 'после', 'истечение', 'более', 'один', 'месяц', 'дата', 'зачисление', 'первый', 'сумма', 'вклад', 'на', 'счёт', 'удерживаться', 'штраф', 'размер', 'от', 'начислить', 'вознаграждение'], ['да', 'по', 'вклад', 'мой', 'цель', 'предусмотреть', 'неограниченный', 'количество', 'пролонгация'], ['капитализация', 'происходить', 'ежемесячно', 'число', 'каждый', 'месяц'], ['ставка', 'тенг', 'составлять', 'для', 'срок', 'месяц', 'для', 'срок', 'месяц'], ['вознаграждение', 'рассчитываться', 'по', 'формула', 'сумма', 'вклад', 'количество', 'день', 'начисление', 'процент', 'по', 'вклад', 'месяц', 'номинальный', 'процентный', 'ставка', 'день', 'сумма', 'вознаграждение'], ['процент', 'начисляться', 'даже', 'если', 'на', 'депозит', 'наложить', 'арест', 'вы', 'смочь', 'воспользоваться', 'свой', 'депозит', 'начислить', 'процент', 'как', 'только', 'арест', 'быть', 'снятой'], ['для', 'тот', 'чтобы', 'унаследовать', 'вклад', 'нужно', 'обратитьс ...
# [['каков', 'минимальный', 'сумма', 'открытие', 'для', 'депозит', 'рахмет', 'без', 'право', 'пополнение', 'снятие'], ['разрешить', 'ли', 'дополнительный', 'взнос', 'для', 'депозит', 'рахмет'], ['можно', 'ли', 'осуществить', 'досрочный', 'расторжение', 'депозит', 'рахмет'], ['какой', 'срок', 'ставка', 'возвращение', 'применяться', 'при', 'досрочный', 'расторжение', 'депозит', 'рахмет'], ['есть', 'ли', 'различие', 'ставка', 'зависимость', 'от', 'тот', 'через', 'что', 'открываться', 'депозит', 'рахмет', 'через', 'приложение', 'или', 'через', 'отделение', 'банк'], ['как', 'производиться', 'расчёт', 'вознаграждение', 'по', 'депозит', 'рахмет'], ['продлеваться', 'ли', 'вклад', 'рахмет', 'автоматически', 'после', 'окончание', 'срок'], ['допускаться', 'ли', 'частичный', 'изъятие', 'средство', 'депозит', 'рахмет'], ['как', 'часто', 'происходить', 'капитализация', 'по', 'депозит', 'рахмет'], ['каков', 'минимальный', 'сумма', 'для', 'досрочный', 'расторжение', 'депозит', 'рахмет'], ['какой', 'минимальный', 'сумма', 'открытие', 'для', 'депозит', 'чемпион', 'право', 'пополнение', 'снятие'], ['разрешить', 'ли', 'дополнительный', 'взнос', 'на', 'депозит', 'чемпион'], ['предусмотреть', 'ли', 'частичный', 'изъятие', 'средство', 'депозит', 'чемпион'], ['можно', 'ли', 'провести', 'досрочный', 'расторжение', 'депозит', 'чемпион', 'как', 'это', 'происходить'], ['как', 'рассчитываться', 'вознаграждение', 'при', 'досрочный', 'расторжение', 'депозит', 'чемпион'], ['какой', 'условие', 'продление', 'пролонгация', 'депозит', 'чемпион'], ['как', 'часто', 'происходить', 'капитализация', 'по', 'депозит', 'чемпион'], ['каков', 'ставка', 'при', 'открытие', 'депозит', 'чемпион', 'через', 'приложение', 'bcc', 'kz', 'на', 'месяц'], ['есть', 'ли', 'разница', 'ставка', 'при', 'открытие', 'депозит', 'чемпион', 'через', 'приложение', 'по', 'сравнение', 'открытие', 'через', 'отделение', 'банк'], ['как', 'рассчитываться', 'вознаграждение', 'по', 'депозит', 'чемпион'], ['каков', 'минимальный', 'сумма', 'открытие', 'для', 'депозит', 'мой', 'цель', 'право', 'пополнение', 'без', 'право', 'снятие'], ['мочь', 'ли', 'вноситься', 'дополнительный', 'средство', 'на', 'депозит', 'мой', 'цель', 'после', 'он', 'открытие'], ['возможно', 'ли', 'частичный', 'снятие', 'депозит', 'мой', 'цель'], ['каков', 'условие', 'досрочный', 'расторжение', 'депозит', 'мой', 'цель'], ['ли', 'автоматический', 'продление', 'депозит', 'мой', 'цель'], ['как', 'происходить', 'капитализация', 'по', 'депозит', 'мой', 'цель'], ['какой', 'ставка', 'предлагаться', 'при', 'открытие', 'депозит', 'мой', 'цель', 'через', 'приложение', 'bcc', 'kz', 'на', 'срок', 'месяц'], ['как', 'рассчитываться', 'вознаграждение', 'по', 'депозит', 'мой', 'цель'], ['если', 'на', 'мой', 'счёт', 'наложить', 'арест', 'вознаграждение', 'по', 'депозит', 'быть', 'начисляться'], ['мой', 'родственник', 'быть', 'депозит', 'он', 'умереть', 'что', 'делать'], ['хотеть', 'доверить', 'управление', 'мой', 'депозит', 'родственник', 'что', 'нужно', 'для', 'это', 'сделать'], ['есть', 'депозит', 'рахмет', 'рахмет', 'ваш', 'банк', 'он', 'срок', 'окончание', 'выпадать', 'на', 'выходной', 'праздничный', 'день', 'нужно', 'он', 'закрыть', 'что', 'необходимо', 'предпринять'], ['что', 'случиться', 'если', 'не', 'подойти', 'назначить', 'срок', 'по', 'закрытие', 'депозит', 'рахмет', 'рахмет'], ['как', 'можно', 'закрыть', 'депозит'], ['какой', 'документ', 'чтобы', 'закрыть', 'депозит'], ['как', 'можно', 'пополнить', 'депозит', 'через', 'касса', 'cash', 'in', 'банкомат', 'ипт', 'бцк'], ['каков', 'условие', 'пополнение', 'депозит', 'через', 'мобильный', 'приложение', 'bcc', 'kz'], ['возможно', 'ли', 'пополнение', 'депозит', 'наличные', 'через', 'касса', 'отделение', 'бцк'], ['существовать', 'ли', 'комиссия', 'за', 'пополнение', 'депозит', 'бцк'], ['мочь', 'ли', 'третий', 'лицо', 'пополнить', 'мой', 'депозит'], ['какой', 'тип', 'вид', 'пластика', 'картакарта'], ['какой', 'вид', 'карта', 'картакарта'], ['какой', 'валюта', 'вестись', 'счёт', 'для', 'картакарта'],  ...

# %%
sw = "c а алло без белый близко более больше большой будем будет будете будешь будто буду будут будь бы бывает бывь был была были было быть в важная важное важные важный вам вами вас ваш ваша ваше ваши вверх вдали вдруг ведь везде вернуться весь вечер взгляд взять вид видел видеть вместе вне вниз внизу во вода война вокруг вон вообще вопрос восемнадцатый восемнадцать восемь восьмой вот впрочем времени время все все еще всегда всего всем всеми всему всех всею всю всюду вся всё второй вы выйти г где главный глаз говорил говорит говорить год года году голова голос город да давать давно даже далекий далеко дальше даром дать два двадцатый двадцать две двенадцатый двенадцать дверь двух девятнадцатый девятнадцать девятый девять действительно дел делал делать делаю дело день деньги десятый десять для до довольно долго должен должно должный дом дорога друг другая другие других друго другое другой думать душа е его ее ей ему если есть еще ещё ею её ж ждать же жена женщина жизнь жить за занят занята занято заняты затем зато зачем здесь земля знать значит значить и иди идти из или им имеет имел именно иметь ими имя иногда их к каждая каждое каждые каждый кажется казаться как какая какой кем книга когда кого ком комната кому конец конечно которая которого которой которые который которых кроме кругом кто куда лежать лет ли лицо лишь лучше любить люди м маленький мало мать машина между меля менее меньше меня место миллионов мимо минута мир мира мне много многочисленная многочисленное многочисленные многочисленный мной мною мог могу могут мож может может быть можно можхо мои мой мор москва мочь моя моё мы на наверху над надо назад наиболее найти наконец нам нами народ нас начала начать наш наша наше наши не него недавно недалеко нее ней некоторый нельзя нем немного нему непрерывно нередко несколько нет нею неё ни нибудь ниже низко никакой никогда никто никуда ним ними них ничего ничто но новый нога ночь ну нужно нужный нх о об оба обычно один одиннадцатый одиннадцать однажды однако одного одной оказаться окно около он она они оно опять особенно остаться от ответить отец откуда отовсюду отсюда очень первый перед писать плечо по под подойди подумать пожалуйста позже пойти пока пол получить помнить понимать понять пор пора после последний посмотреть посреди потом потому почему почти правда прекрасно при про просто против процентов путь пятнадцатый пятнадцать пятый пять работа работать раз разве рано раньше ребенок решить россия рука русский ряд рядом с с кем сам сама сами самим самими самих само самого самой самом самому саму самый свет свое своего своей свои своих свой свою сделать сеаой себе себя сегодня седьмой сейчас семнадцатый семнадцать семь сидеть сила сих сказал сказала сказать сколько слишком слово случай смотреть сначала снова со собой собою советский совсем спасибо спросить сразу стал старый стать стол сторона стоять страна суть считать т та так такая также таки такие такое такой там твои твой твоя твоё те тебе тебя тем теми теперь тех то тобой тобою товарищ тогда того тоже только том тому тот тою третий три тринадцатый тринадцать ту туда тут ты тысяч у увидеть уж уже улица уметь утро хороший хорошо хотел бы хотеть хоть хотя хочешь час часто часть чаще чего человек чем чему через четвертый четыре четырнадцатый четырнадцать что чтоб чтобы чуть шестнадцатый шестнадцать шестой шесть эта эти этим этими этих это этого этой этом этому этот эту я являюсь".split()

# %% [markdown]
# # StopWords

# %%
import nltk
from nltk.corpus import stopwords
sw_nltk = stopwords.words('russian')
# ans = []
# que = []
# [[w for w in ans[x] if w.lower() not in ] for x in range(len(ans))]
print(sw_nltk)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']

# %%
ans = [[w for w in ans[x] if w not in sw_nltk] for x in range(len(ans))]
que = [[w for w in que[x] if w not in sw_nltk] for x in range(len(que))]

# %%
model_ans = gensim.models.Word2Vec (ans, vector_size=100, window=10, min_count=0, workers=10)
model_ans.train(ans,total_examples=len(ans),epochs=10)
# Out:
# (14381, 20180)

# %%
model_ans.wv.most_similar (positive='деньга')
# Out:
# [('ребёнок', 0.9977453351020813),
#  ('случай', 0.9975194931030273),
#  ('карта', 0.99741530418396),
#  ('покупка', 0.9971142411231995),
#  ('банк', 0.9971056580543518),
#  ('средство', 0.9970918893814087),
#  ('мочь', 0.9970740675926208),
#  ('лимит', 0.9967578053474426),
#  ('детский', 0.996659517288208),
#  ('pay', 0.9966544508934021)]

# %%
model_que = gensim.models.Word2Vec (que, vector_size=100, window=10, min_count=0, workers=10)
model_que.train(que,total_examples=len(que),epochs=10)
# Out:
# (5574, 10030)

# %%
from sklearn.metrics.pairwise import cosine_similarity
# cosine_similarity(model_que.wv['предлагаться'].reshape(1-1), model_que.wv['разница'].reshape(1, -1))

# %%
model_que.wv.most_similar (positive='карта')
# Out:
# [('депозит', 0.7792866826057434),
#  ('открытие', 0.7574871182441711),
#  ('приложение', 0.739783763885498),
#  ('рахмет', 0.7329490780830383),
#  ('мочь', 0.7268040776252747),
#  ('лимит', 0.7134137153625488),
#  ('пенсионный', 0.7019906640052795),
#  ('нужно', 0.6810591220855713),
#  ('закрывать', 0.6752114295959473),
#  ('банкомат', 0.6686736345291138)]

# %%
import numpy as np

# %%
sm = 0
for a in ans[0]:
    sm += model_ans.wv[a]
mean_ans = sm/len(ans[0])

sm = 0
for q in que[0]:
    sm += model_que.wv[q]
mean_que = sm/len(que[0])
# mean_que.shape
print(np.dot(mean_ans, mean_que)/np.sqrt(np.sum(mean_ans**2) * np.sum(mean_que**2)))
# Out:
# 0.86729896

# %%
def metric(v1, v2):
    return np.dot(v1, v2)/np.sqrt(np.sum(v1**2) * np.sum(v2**2))

# %%
from gensim.similarities import SparseMatrixSimilarity

# %%
# import random
# rand = random.randint(0, len(que))
rand = 0
# print(rand)
sm = 0
for q in que[rand]:
    sm += model_que.wv[q]
mean_que = sm/len(que[rand])
res = []
for i, x in enumerate(ans):
    sm = 0
#     print(x)
    for a in x:
        sm += model_ans.wv[a]
    mean = sm/len(ans[i])
    met = metric(mean_que, mean)
    
    res.append((met,i))
#     mean_vector = np.mean([word_vectors[word] for word in words_in_vocab], axis=0)

# res.sort()
# res.reverse()
# print(res)
# print(sorted(res)[0])

# %%
# res

# %%
len(ans)
# Out:
# 178

# %%
print(que[rand], ans[104])
# Out:
# ['каков', 'минимальный', 'сумма', 'открытие', 'депозит', 'рахмет', 'право', 'пополнение', 'снятие'] ['карта', 'travel', 'card', 'использовать', 'весь', 'мир']

# %%
sorted(res, reverse = True)
# Out:
# [(0.8780149, 135),
#  (0.8770601, 136),
#  (0.8764699, 95),
#  (0.8751364, 101),
#  (0.87509185, 94),
#  (0.8750281, 85),
#  (0.87485886, 139),
#  (0.8747819, 104),
#  (0.87473583, 100),
#  (0.8746204, 115),
#  (0.8744918, 89),
#  (0.874456, 72),
#  (0.8744383, 142),
#  (0.8744088, 93),
#  (0.87440455, 138),
#  (0.87435424, 108),
#  (0.8742148, 99),
#  (0.8741597, 103),
#  (0.874155, 107),
#  (0.87402505, 51),
#  (0.8738599, 137),
#  (0.8737826, 43),
#  (0.8737239, 141),
#  (0.87365407, 90),
#  (0.8735505, 55),
#  (0.87353396, 97),
#  (0.8735302, 87),
#  (0.8734254, 119),
#  (0.8733385, 166),
#  (0.8732124, 64),
#  (0.8732041, 42),
#  (0.8731955, 36),
#  (0.8731727, 122),
#  (0.8731475, 165),
#  (0.8731436, 86),
#  (0.8729485, 121),
#  (0.87286204, 96),
#  (0.87285864, 88),
#  (0.87274194, 151),
#  (0.87269944, 52),
#  (0.87265533, 92),
#  (0.87263805, 111),
#  (0.87260795, 102),
#  (0.8725601, 153),
#  (0.8722527, 56),
#  (0.87222886, 169),
#  (0.872206, 145),
#  (0.8721446, 57),
#  (0.87211514, 110),
#  (0.8721127, 140),
#  (0.8720623, 46),
#  (0.87202173, 53),
#  (0.8720106, 134),
#  (0.8719392, 70),
#  (0.8718859, 168),
#  (0.8717118, 158),
#  (0.87170607, 154),
#  (0.8716593, 91),
#  (0.87162304, 114),
#  (0.8715736, 63),
#  (0.8715422, 45),
#  (0.87147903, 125),
#  (0.87147576, 26),
#  (0.8714639, 58),
#  (0.8714537, 69),
#  (0.87145126, 59),
#  (0.8714352, 143),
#  (0.87134796, 172),
#  (0.8712943, 159),
#  (0.8712838, 132),
#  (0.87125164, 133),
#  (0.8711507, 162),
#  (0.8710763, 60),
#  (0.87098813, 155),
#  (0.870971, 167),
#  (0.87090737, 118),
#  (0.87089336, 49),
#  (0.8708785, 116),
#  (0.8708606, 54),
#  (0.8708581, 129),
#  (0.8707933, 66),
#  (0.87075955, 109),
#  (0.87075424, 35),
#  (0.87072563, 161),
#  (0.8705837, 170),
#  (0.87053436, 171),
#  (0.8704538, 148),
#  (0.8704061, 144),
#  (0.870334, 152),
#  (0.8703128, 61),
#  (0.87029964, 112),
#  (0.8702897, 38),
#  (0.87025404, 113),
#  (0.87023884, 117),
#  (0.8702373, 149),
#  (0.8702341, 44),
#  (0.8702175, 62),
#  (0.87019485, 79),
#  (0.87016493, 157),
#  (0.87012583, 156),
#  (0.8700834, 128),
#  (0.8700814, 175),
#  (0.86999303, 126),
#  (0.8699549, 12),
#  (0.8699343, 82),
#  (0.86990136, 50),
#  (0.86982846, 131),
#  (0.8698107, 47),
#  (0.8697429, 164),
#  (0.86971325, 41),
#  (0.869696, 18),
#  (0.86966014, 65),
#  (0.86964405, 163),
#  (0.8695962, 123),
#  (0.86958385, 39),
#  (0.86954, 37),
#  (0.8695105, 78),
#  (0.8694964, 150),
#  (0.86937565, 176),
#  (0.8691525, 33),
#  (0.8691465, 174),
#  (0.8691465, 173),
#  (0.869049, 147),
#  (0.8689615, 83),
#  (0.8688558, 28),
#  (0.86882055, 73),
#  (0.86879414, 106),
#  (0.86874044, 67),
#  (0.86873966, 68),
#  (0.8687277, 127),
#  (0.86870503, 4),
#  (0.86865705, 98),
#  (0.8684991, 17),
#  (0.8684555, 120),
#  (0.8684306, 146),
#  (0.86838305, 3),
#  (0.86828476, 84),
#  (0.8682485, 29),
#  (0.8681885, 10),
#  (0.86802745, 177),
#  (0.8679269, 75),
#  (0.8678538, 71),
#  (0.8675715, 76),
#  (0.86729896, 20),
#  (0.86729896, 0),
#  (0.867212, 30),
#  (0.86714166, 130),
#  (0.8670552, 9),
#  (0.8670105, 48),
#  (0.86632335, 105),
#  (0.86606526, 24),
#  (0.8659976, 15),
#  (0.8659604, 81),
#  (0.8657271, 40),
#  (0.86550707, 32),
#  (0.8654388, 34),
#  (0.86492413, 14),
#  (0.8646965, 23),
#  (0.86463, 6),
#  (0.864491, 160),
#  (0.86433923, 7),
#  (0.8641681, 31),
#  (0.8632224, 22),
#  (0.8629415, 74),
#  (0.86269045, 27),
#  (0.86269045, 19),
#  (0.86269045, 5),
#  (0.86235094, 2),
#  (0.8619604, 8),
#  (0.8618309, 77),
#  (0.8605283, 25),
#  (0.8605283, 16),
#  (0.86025, 13),
#  (0.85936916, 124),
#  (0.85222507, 21),
#  (0.85222507, 11),
#  (0.85222507, 1),
#  (0.46068257, 80)]

# %%
np.dot(model_que.wv['карта'], model_que.wv['депозит'])/np.sqrt(np.sum(model_que.wv['карта']**2)*np.sum(model_que.wv['депозит']**2))
# Out:
# 0.7300956

# %%
import gensim.downloader as api

# %%
info = api.info()

# %%
wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv.most_similar('tea')
# Out:
# [('Tea', 0.7009038329124451),
#  ('teas', 0.6727380156517029),
#  ('shape_Angius', 0.6323482990264893),
#  ('activist_Jamie_Radtke', 0.5863859057426453),
#  ('decaffeinated_brew', 0.5839536190032959),
#  ('planter_bungalow', 0.5758289098739624),
#  ('herbal_tea', 0.5731173753738403),
#  ('coffee', 0.5635291934013367),
#  ('jasmine_tea', 0.5483394265174866),
#  ('Tea_NASDAQ_PEET', 0.5402544140815735)]

# %%
glove = api.load('glove-twitter-50')
# Out:
# [==================================================] 100.0% 199.5/199.5MB downloaded

# %%
fasttext = api.load('fasttext-wiki-news-subwords-300')
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %%
wv.most_similar('tea')
# Out:
# [('Tea', 0.7009038329124451),
#  ('teas', 0.6727380156517029),
#  ('shape_Angius', 0.6323482990264893),
#  ('activist_Jamie_Radtke', 0.5863859057426453),
#  ('decaffeinated_brew', 0.5839536190032959),
#  ('planter_bungalow', 0.5758289098739624),
#  ('herbal_tea', 0.5731173753738403),
#  ('coffee', 0.5635291934013367),
#  ('jasmine_tea', 0.5483394265174866),
#  ('Tea_NASDAQ_PEET', 0.5402544140815735)]

# %%
glove.most_similar('tea')
# Out:
# [('coffee', 0.8929038643836975),
#  ('milk', 0.8667818903923035),
#  ('wine', 0.8507667183876038),
#  ('cream', 0.8502467274665833),
#  ('ice', 0.8362607955932617),
#  ('juice', 0.8177550435066223),
#  ('beer', 0.8157103657722473),
#  ('sugar', 0.8099126219749451),
#  ('cake', 0.8080539703369141),
#  ('drink', 0.800037682056427)]

# %%
# imports needed and set up logging
import gensim 
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# C:\Users\aliha\anaconda3\envs\nlpenv\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# !pip install python-Levenshtein
# Out:
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.21.1-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.21.1
#   Downloading Levenshtein-0.21.1-cp36-cp36m-win_amd64.whl (100 kB)
# Collecting rapidfuzz<4.0.0,>=2.3.0
#   Downloading rapidfuzz-2.11.1-cp36-cp36m-win_amd64.whl (981 kB)
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.21.1 python-Levenshtein-0.21.1 rapidfuzz-2.11.1
